# %%
import pandas as pd
import numpy as np
import datetime
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
data0 = pd.read_csv("data/1019_SP.csv").dropna()
data1 = pd.read_csv("data/1019_CL.csv").dropna()
data2 = pd.read_csv("data/1019_OVX.csv").dropna()
data3 = pd.read_csv("data/1019_GC.csv").dropna()
data4 = pd.read_csv("data/1019_GVZ.csv").dropna()
Date = data0.get("Date")
Date = pd.to_datetime(Date)
Close = data0.get("Close")
Close_cl = data1.get("Close")
Close_ovx = data2.get("Close")
Close_gc = data3.get("Close")
Close_gvz = data4.get("Close")
dict = {"Date": Date,
        "close": Close, 
        "close_cl": Close_cl, 
        "close_ovx": Close_ovx,
        "close_gc": Close_gc, 
        "close_gvz": Close_gvz,
       }
df = pd.DataFrame(dict)
df.set_index('Date', inplace=True)
df = df.dropna()
print("總共:%d個交易時間點" % (len(Date)))
print("去除空白值後剩下:%d個交易時間點" % (len(df)))
df.tail(10)
# Out:
# 總共:2493個交易時間點
# 去除空白值後剩下:2493個交易時間點
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                   close   close_cl  close_ovx     close_gc  close_gvz
# Date
# 2019-12-13  3168.800049  60.070000  26.760000  1475.599976      10.39
# 2019-12-16  3191.449951  60.209999  26.510000  1475.000000      10.39
# 2019-12-17  3192.520020  60.939999  26.330000  1474.599976      10.03
# 2019-12-18  3191.139893  60.930000  26.770000  1472.599976      10.04
# 2019-12-19  3205.370117  61.220001  24.799999  1478.199951      10.39
# 2019-12-20  3221.219971  60.439999  25.540001  1474.699951       9.69
# 2019-12-23  3224.010010  60.520000  25.110001  1482.500000      10.56
# 2019-12-26  3239.909912  61.680000  24.080000  1509.300049      13.33
# 2019-12-27  3240.020020  61.720001  25.160000  1513.800049      12.32
# 2019-12-30  3221.290039  61.680000  25.860001  1514.500000      12.56

# %%
dataset = pd.DataFrame({
    'Close':df['close'],
    #'Close_CL':df['close_cl'],
    #'Close_OVX':df['close_ovx'],
    'Close_GC':df['close_gc'],
    'Close_GVZ':df['close_gvz'],
    'return': df['close'],
})

feature_names = list(dataset.columns[:-1])

# %%
print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)
# Out:
# before dropping NaN (2493, 4)
# after dropping NaN (2493, 4)

# %%
from sklearn.preprocessing import MinMaxScaler

ss = MinMaxScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
#dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()
# Out:
#              Close     Close_GC    Close_GVZ       return
# count  2493.000000  2493.000000  2493.000000  2493.000000
# mean      0.422965     0.353032     0.261824     0.422965
# std       0.265162     0.213666     0.156178     0.265162
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.161118     0.207304     0.142903     0.161118
# 50%       0.434046     0.289533     0.246540     0.434046
# 75%       0.636121     0.457453     0.347602     0.636121
# max       1.000000     1.000000     1.000000     1.000000

# %%
from keras.utils import np_utils
#每張圖包含幾天的資料
time_period = 20
#預設幾日後的漲跌
day = 10

cnn_x = []
cnn_y = []
indexs = []
dataset_scaled_x= dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-time_period-1-day)):
    cnn_x.append(dataset_scaled_x.iloc[i:i+time_period].values)
    r = dataset_scaled['return'].iloc[i+time_period-1+day]/dataset_scaled['return'].iloc[i+time_period-1]
    if r > 1:
        r = 0
    else:
        r = 1
    rr = np_utils.to_categorical(r, num_classes=2)
    cnn_y.append(rr)
    indexs.append(dataset_scaled.index[i+time_period-1])
    
cnn_x = np.array(cnn_x)
cnn_y = np.array(cnn_y)
indexes = np.array(indexs)
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# HBox(children=(IntProgress(value=0, max=2462), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars

# %%
#2010~2018年為訓練和測試，2019年則為驗證
import datetime
cnn_x_t = cnn_x[indexes < datetime.datetime(2019,1,1)]
cnn_y_t = cnn_y[indexes < datetime.datetime(2019,1,1)]
cnn_x_validation = cnn_x[indexes > datetime.datetime(2019,1,1)]
cnn_y_validation = cnn_y[indexes > datetime.datetime(2019,1,1)]

# %%
from sklearn.model_selection import train_test_split
cnn_x_train, cnn_x_test, cnn_y_train, cnn_y_test = train_test_split(cnn_x_t, cnn_y_t, 
                                                                    test_size=0.2,
                                                                    random_state =7,
                                                                    stratify=cnn_y_t,
                                                                    shuffle = True)

# %%
cnn_x_train = np.stack((cnn_x_train,)*3,axis=-1)
cnn_x_test = np.stack((cnn_x_test,)*3,axis=-1)
cnn_x_validation = np.stack((cnn_x_validation,)*3,axis=-1)

# %%
fig = plt.figure(figsize = (15,15))
columns = rows = 5
for i in range(1,columns*rows+1):
  index = np.random.randint(len(cnn_x_train))
  img = cnn_x_train[index]
  fig.add_subplot(rows,columns,i)
  plt.axis("off")
  plt.title(str(index)+' class = '+str(np.argmax(cnn_y_train[index])))
  plt.subplots_adjust(wspace=0.2,hspace=0.2)
  plt.imshow(img)
plt.show()

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.initializers import he_normal

input_shape = cnn_x_train[0].shape

model = Sequential()
model.add(layers.Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same",
                        input_shape=input_shape))
model.add(layers.Conv2D(filters=64, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same"))
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Dropout(0.25))
model.add(layers.Flatten())
model.add(layers.Dense(units=128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=2, activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer="Adam", metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 20, 3, 32)         896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 3, 64)         18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 1, 64)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 1, 64)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 640)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               82048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 101,698
# Trainable params: 101,698
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

history = model.fit(cnn_x_train, cnn_y_train,
                    batch_size=100,
                    epochs=250,
                    verbose=1,
                    validation_data=(cnn_x_test,cnn_y_test),
                    callbacks=[earlystop],
                    )
# Out:
# Epoch 1/250
# 18/18 [==============================] - 0s 26ms/step - loss: 0.6702 - accuracy: 0.6163 - val_loss: 0.6524 - val_accuracy: 0.6300
# Epoch 2/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6568 - accuracy: 0.6303 - val_loss: 0.6506 - val_accuracy: 0.6300
# Epoch 3/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6598 - accuracy: 0.6309 - val_loss: 0.6472 - val_accuracy: 0.6300
# Epoch 4/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6550 - accuracy: 0.6309 - val_loss: 0.6458 - val_accuracy: 0.6300
# Epoch 5/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6512 - accuracy: 0.6309 - val_loss: 0.6450 - val_accuracy: 0.6300
# Epoch 6/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6497 - accuracy: 0.6337 - val_loss: 0.6431 - val_accuracy: 0.6300
# Epoch 7/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6505 - accuracy: 0.6331 - val_loss: 0.6469 - val_accuracy: 0.6435
# Epoch 8/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6522 - accuracy: 0.6388 - val_loss: 0.6484 - val_accuracy: 0.6435
# Epoch 9/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6497 - accuracy: 0.6393 - val_loss: 0.6418 - val_accuracy: 0.6457
# Epoch 10/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6474 - accuracy: 0.6421 - val_loss: 0.6399 - val_accuracy: 0.6457
# Epoch 11/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6429 - accuracy: 0.6427 - val_loss: 0.6405 - val_accuracy: 0.6323
# Epoch 12/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6387 - accuracy: 0.6438 - val_loss: 0.6340 - val_accuracy: 0.6457
# Epoch 13/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6388 - accuracy: 0.6416 - val_loss: 0.6374 - val_accuracy: 0.6345
# Epoch 14/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6338 - accuracy: 0.6410 - val_loss: 0.6322 - val_accuracy: 0.6435
# Epoch 15/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6370 - accuracy: 0.6494 - val_loss: 0.6294 - val_accuracy: 0.6457
# Epoch 16/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6319 - accuracy: 0.6433 - val_loss: 0.6321 - val_accuracy: 0.6480
# Epoch 17/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6290 - accuracy: 0.6506 - val_loss: 0.6237 - val_accuracy: 0.6457
# Epoch 18/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6344 - accuracy: 0.6472 - val_loss: 0.6225 - val_accuracy: 0.6435
# Epoch 19/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6304 - accuracy: 0.6494 - val_loss: 0.6196 - val_accuracy: 0.6547
# Epoch 20/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6221 - accuracy: 0.6567 - val_loss: 0.6110 - val_accuracy: 0.6525
# Epoch 21/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6163 - accuracy: 0.6539 - val_loss: 0.6119 - val_accuracy: 0.6570
# Epoch 22/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6152 - accuracy: 0.6545 - val_loss: 0.6069 - val_accuracy: 0.6547
# Epoch 23/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6111 - accuracy: 0.6669 - val_loss: 0.6043 - val_accuracy: 0.6525
# Epoch 24/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6161 - accuracy: 0.6573 - val_loss: 0.6031 - val_accuracy: 0.6480
# Epoch 25/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6151 - accuracy: 0.6551 - val_loss: 0.6055 - val_accuracy: 0.6480
# Epoch 26/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6143 - accuracy: 0.6449 - val_loss: 0.6025 - val_accuracy: 0.6525
# Epoch 27/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6039 - accuracy: 0.6646 - val_loss: 0.5939 - val_accuracy: 0.6592
# Epoch 28/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5967 - accuracy: 0.6781 - val_loss: 0.6033 - val_accuracy: 0.6457
# Epoch 29/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6013 - accuracy: 0.6697 - val_loss: 0.6010 - val_accuracy: 0.6726
# Epoch 30/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6048 - accuracy: 0.6691 - val_loss: 0.5867 - val_accuracy: 0.6726
# Epoch 31/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.5937 - accuracy: 0.6635 - val_loss: 0.5827 - val_accuracy: 0.6704
# Epoch 32/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5907 - accuracy: 0.6702 - val_loss: 0.5837 - val_accuracy: 0.6592
# Epoch 33/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5868 - accuracy: 0.6865 - val_loss: 0.5731 - val_accuracy: 0.6614
# Epoch 34/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5826 - accuracy: 0.6787 - val_loss: 0.5874 - val_accuracy: 0.6928
# Epoch 35/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5860 - accuracy: 0.6764 - val_loss: 0.5713 - val_accuracy: 0.6749
# Epoch 36/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5808 - accuracy: 0.6837 - val_loss: 0.5713 - val_accuracy: 0.6704
# Epoch 37/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5756 - accuracy: 0.6860 - val_loss: 0.5784 - val_accuracy: 0.6704
# Epoch 38/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.5767 - accuracy: 0.6927 - val_loss: 0.5666 - val_accuracy: 0.6816
# Epoch 39/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5755 - accuracy: 0.6888 - val_loss: 0.5631 - val_accuracy: 0.6839
# Epoch 40/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5692 - accuracy: 0.6972 - val_loss: 0.5546 - val_accuracy: 0.7040
# Epoch 41/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5607 - accuracy: 0.7112 - val_loss: 0.5594 - val_accuracy: 0.6816
# Epoch 42/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5619 - accuracy: 0.6994 - val_loss: 0.5515 - val_accuracy: 0.6996
# Epoch 43/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.5706 - accuracy: 0.6899 - val_loss: 0.5630 - val_accuracy: 0.6883
# Epoch 44/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5660 - accuracy: 0.7056 - val_loss: 0.5539 - val_accuracy: 0.6973
# Epoch 45/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5606 - accuracy: 0.7051 - val_loss: 0.5488 - val_accuracy: 0.6771
# Epoch 46/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5376 - accuracy: 0.7348 - val_loss: 0.5399 - val_accuracy: 0.7130
# Epoch 47/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5424 - accuracy: 0.7101 - val_loss: 0.5434 - val_accuracy: 0.7152
# Epoch 48/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5472 - accuracy: 0.7225 - val_loss: 0.5658 - val_accuracy: 0.6794
# Epoch 49/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5496 - accuracy: 0.7084 - val_loss: 0.5322 - val_accuracy: 0.7242
# Epoch 50/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5386 - accuracy: 0.7163 - val_loss: 0.5308 - val_accuracy: 0.7108
# Epoch 51/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5309 - accuracy: 0.7371 - val_loss: 0.5372 - val_accuracy: 0.6928
# Epoch 52/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5382 - accuracy: 0.7213 - val_loss: 0.5377 - val_accuracy: 0.7108
# Epoch 53/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5225 - accuracy: 0.7404 - val_loss: 0.5307 - val_accuracy: 0.7242
# Epoch 54/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5327 - accuracy: 0.7303 - val_loss: 0.5324 - val_accuracy: 0.7220
# Epoch 55/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5306 - accuracy: 0.7309 - val_loss: 0.5243 - val_accuracy: 0.7108
# Epoch 56/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5260 - accuracy: 0.7146 - val_loss: 0.5209 - val_accuracy: 0.7197
# Epoch 57/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5193 - accuracy: 0.7449 - val_loss: 0.5255 - val_accuracy: 0.7242
# Epoch 58/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5138 - accuracy: 0.7393 - val_loss: 0.5158 - val_accuracy: 0.7130
# Epoch 59/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5223 - accuracy: 0.7298 - val_loss: 0.5325 - val_accuracy: 0.7287
# Epoch 60/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5088 - accuracy: 0.7461 - val_loss: 0.5122 - val_accuracy: 0.7309
# Epoch 61/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5101 - accuracy: 0.7455 - val_loss: 0.5042 - val_accuracy: 0.7332
# Epoch 62/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5043 - accuracy: 0.7584 - val_loss: 0.5175 - val_accuracy: 0.7309
# Epoch 63/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5093 - accuracy: 0.7472 - val_loss: 0.5102 - val_accuracy: 0.7354
# Epoch 64/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5100 - accuracy: 0.7539 - val_loss: 0.5228 - val_accuracy: 0.7399
# Epoch 65/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5063 - accuracy: 0.7483 - val_loss: 0.5102 - val_accuracy: 0.7197
# Epoch 66/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4972 - accuracy: 0.7483 - val_loss: 0.5116 - val_accuracy: 0.7466
# Epoch 67/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4964 - accuracy: 0.7567 - val_loss: 0.4966 - val_accuracy: 0.7287
# Epoch 68/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4934 - accuracy: 0.7466 - val_loss: 0.4943 - val_accuracy: 0.7556
# Epoch 69/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4875 - accuracy: 0.7579 - val_loss: 0.5030 - val_accuracy: 0.7399
# Epoch 70/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4868 - accuracy: 0.7680 - val_loss: 0.5100 - val_accuracy: 0.7511
# Epoch 71/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4923 - accuracy: 0.7607 - val_loss: 0.5040 - val_accuracy: 0.7489
# Epoch 72/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4936 - accuracy: 0.7607 - val_loss: 0.4999 - val_accuracy: 0.7354
# Epoch 73/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4793 - accuracy: 0.7612 - val_loss: 0.4949 - val_accuracy: 0.7511
# Epoch 74/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4718 - accuracy: 0.7770 - val_loss: 0.4870 - val_accuracy: 0.7534
# Epoch 75/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4725 - accuracy: 0.7596 - val_loss: 0.4850 - val_accuracy: 0.7623
# Epoch 76/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4708 - accuracy: 0.7742 - val_loss: 0.4881 - val_accuracy: 0.7444
# Epoch 77/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4783 - accuracy: 0.7719 - val_loss: 0.4917 - val_accuracy: 0.7466
# Epoch 78/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4753 - accuracy: 0.7809 - val_loss: 0.4937 - val_accuracy: 0.7489
# Epoch 79/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4770 - accuracy: 0.7815 - val_loss: 0.5130 - val_accuracy: 0.7377
# Epoch 80/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4648 - accuracy: 0.7758 - val_loss: 0.4782 - val_accuracy: 0.7601
# Epoch 81/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4651 - accuracy: 0.7770 - val_loss: 0.4730 - val_accuracy: 0.7489
# Epoch 82/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4724 - accuracy: 0.7713 - val_loss: 0.4860 - val_accuracy: 0.7713
# Epoch 83/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4585 - accuracy: 0.7809 - val_loss: 0.4687 - val_accuracy: 0.7691
# Epoch 84/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4482 - accuracy: 0.7770 - val_loss: 0.4737 - val_accuracy: 0.7668
# Epoch 85/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4499 - accuracy: 0.7910 - val_loss: 0.4760 - val_accuracy: 0.7534
# Epoch 86/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4524 - accuracy: 0.7781 - val_loss: 0.4989 - val_accuracy: 0.7444
# Epoch 87/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4479 - accuracy: 0.7820 - val_loss: 0.4714 - val_accuracy: 0.7780
# Epoch 88/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4510 - accuracy: 0.7815 - val_loss: 0.4778 - val_accuracy: 0.7691
# Epoch 89/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4431 - accuracy: 0.7916 - val_loss: 0.4544 - val_accuracy: 0.7982
# Epoch 90/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4516 - accuracy: 0.7815 - val_loss: 0.4760 - val_accuracy: 0.7758
# Epoch 91/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4428 - accuracy: 0.7961 - val_loss: 0.4683 - val_accuracy: 0.7735
# Epoch 92/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4397 - accuracy: 0.7888 - val_loss: 0.4591 - val_accuracy: 0.7803
# Epoch 93/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4451 - accuracy: 0.7882 - val_loss: 0.4606 - val_accuracy: 0.7735
# Epoch 94/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4270 - accuracy: 0.8006 - val_loss: 0.4547 - val_accuracy: 0.7915
# Epoch 95/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4343 - accuracy: 0.7927 - val_loss: 0.4504 - val_accuracy: 0.7758
# Epoch 96/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4396 - accuracy: 0.7904 - val_loss: 0.4667 - val_accuracy: 0.7601
# Epoch 97/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4218 - accuracy: 0.8090 - val_loss: 0.4527 - val_accuracy: 0.7825
# Epoch 98/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4203 - accuracy: 0.8051 - val_loss: 0.4668 - val_accuracy: 0.7713
# Epoch 99/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4295 - accuracy: 0.7989 - val_loss: 0.4692 - val_accuracy: 0.7713
# Epoch 100/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4230 - accuracy: 0.8051 - val_loss: 0.4513 - val_accuracy: 0.7892
# Epoch 101/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4303 - accuracy: 0.7989 - val_loss: 0.4601 - val_accuracy: 0.7870
# Epoch 102/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4273 - accuracy: 0.7938 - val_loss: 0.4457 - val_accuracy: 0.8004
# Epoch 103/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4359 - accuracy: 0.7972 - val_loss: 0.4551 - val_accuracy: 0.7825
# Epoch 104/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4283 - accuracy: 0.8045 - val_loss: 0.4668 - val_accuracy: 0.7982
# Epoch 105/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4173 - accuracy: 0.8034 - val_loss: 0.4808 - val_accuracy: 0.7780
# Epoch 106/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4184 - accuracy: 0.8034 - val_loss: 0.4485 - val_accuracy: 0.7937
# Epoch 107/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4122 - accuracy: 0.8118 - val_loss: 0.4532 - val_accuracy: 0.7982
# Epoch 108/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4073 - accuracy: 0.8028 - val_loss: 0.4612 - val_accuracy: 0.8027
# Epoch 109/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4055 - accuracy: 0.8146 - val_loss: 0.4353 - val_accuracy: 0.8049
# Epoch 110/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4049 - accuracy: 0.8051 - val_loss: 0.4445 - val_accuracy: 0.7892
# Epoch 111/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4042 - accuracy: 0.8213 - val_loss: 0.4448 - val_accuracy: 0.7982
# Epoch 112/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4023 - accuracy: 0.8230 - val_loss: 0.4469 - val_accuracy: 0.7892
# Epoch 113/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3935 - accuracy: 0.8326 - val_loss: 0.4391 - val_accuracy: 0.8049
# Epoch 114/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4010 - accuracy: 0.8197 - val_loss: 0.4228 - val_accuracy: 0.8049
# Epoch 115/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3979 - accuracy: 0.8129 - val_loss: 0.4366 - val_accuracy: 0.8004
# Epoch 116/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3903 - accuracy: 0.8247 - val_loss: 0.4623 - val_accuracy: 0.7758
# Epoch 117/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4193 - accuracy: 0.8051 - val_loss: 0.4415 - val_accuracy: 0.7960
# Epoch 118/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3962 - accuracy: 0.8219 - val_loss: 0.4694 - val_accuracy: 0.7870
# Epoch 119/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4088 - accuracy: 0.8163 - val_loss: 0.4466 - val_accuracy: 0.8049
# Epoch 120/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3933 - accuracy: 0.8337 - val_loss: 0.4358 - val_accuracy: 0.8139
# Epoch 121/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3764 - accuracy: 0.8371 - val_loss: 0.4524 - val_accuracy: 0.8139
# Epoch 122/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3840 - accuracy: 0.8219 - val_loss: 0.4420 - val_accuracy: 0.8072
# Epoch 123/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3780 - accuracy: 0.8382 - val_loss: 0.4233 - val_accuracy: 0.8117
# Epoch 124/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3781 - accuracy: 0.8365 - val_loss: 0.4212 - val_accuracy: 0.8251
# Epoch 125/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3698 - accuracy: 0.8309 - val_loss: 0.4598 - val_accuracy: 0.8094
# Epoch 126/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3732 - accuracy: 0.8416 - val_loss: 0.4453 - val_accuracy: 0.8094
# Epoch 127/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3688 - accuracy: 0.8399 - val_loss: 0.4482 - val_accuracy: 0.7982
# Epoch 128/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3648 - accuracy: 0.8388 - val_loss: 0.4543 - val_accuracy: 0.8206
# Epoch 129/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3852 - accuracy: 0.8320 - val_loss: 0.4477 - val_accuracy: 0.8049
# Epoch 130/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3632 - accuracy: 0.8466 - val_loss: 0.4352 - val_accuracy: 0.8004
# Epoch 131/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3761 - accuracy: 0.8309 - val_loss: 0.4130 - val_accuracy: 0.8206
# Epoch 132/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3837 - accuracy: 0.8230 - val_loss: 0.4193 - val_accuracy: 0.8251
# Epoch 133/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3734 - accuracy: 0.8320 - val_loss: 0.4638 - val_accuracy: 0.8161
# Epoch 134/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3595 - accuracy: 0.8371 - val_loss: 0.4357 - val_accuracy: 0.8072
# Epoch 135/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3581 - accuracy: 0.8360 - val_loss: 0.4172 - val_accuracy: 0.8094
# Epoch 136/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3620 - accuracy: 0.8433 - val_loss: 0.4185 - val_accuracy: 0.8184
# Epoch 137/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3615 - accuracy: 0.8388 - val_loss: 0.4437 - val_accuracy: 0.8004
# Epoch 138/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3741 - accuracy: 0.8247 - val_loss: 0.4390 - val_accuracy: 0.8027
# Epoch 139/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3617 - accuracy: 0.8472 - val_loss: 0.4234 - val_accuracy: 0.8274
# Epoch 140/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3577 - accuracy: 0.8399 - val_loss: 0.4352 - val_accuracy: 0.8161
# Epoch 141/250
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3705 - accuracy: 0.8427 - val_loss: 0.4291 - val_accuracy: 0.8139
# Epoch 00141: early stopping

# %%
o_loss,o_accuracy = model.evaluate(cnn_x_train,cnn_y_train)
print("對訓練資料的：\nLoss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
n_loss,n_accuracy = model.evaluate(cnn_x_test,cnn_y_test)
print("對測試資料的：\nLoss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
# Out:
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2956 - accuracy: 0.8910
# 對訓練資料的：
# Loss: 0.30, Accuracy: 0.89
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4412 - accuracy: 0.8139
# 對測試資料的：
# Loss: 0.44, Accuracy: 0.81

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(np.log(history.history['loss']), color = 'green', label='Loss')
plt.plot(np.log(history.history['val_loss']), color = 'blue', label='Val_Loss')
plt.legend()
plt.title('Training loss based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], color = 'green', label='accuracy')
plt.plot(history.history['val_accuracy'], color = 'blue', label='Val_accuracy')
plt.legend()
plt.title('Accuracy based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()

# %%
pre = model.predict_classes(cnn_x_test)
pre = pd.Series(pre)
# Out:
# WARNING:tensorflow:From <ipython-input-15-be91e944df7f>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_test = np.argmax(cnn_y_test, axis=1)
xcnn_y_test = pd.Series(cnn_y_test)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_test, pre)

t_size = len(cnn_y_test)
t_size1 = (cnn_y_test<1).sum()
t_guess = ((cnn_y_test<1).sum())/(len(cnn_y_test))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 253.00, FN: 28.00, FP: 55.00, TN: 110.00
# 對訓練集資料的：Loss: 0.30, Accuracy: 0.89
# 對測試集資料的：Loss: 0.44, Accuracy: 0.81
#
# 測試資料總共：446.00 筆, 其中漲的筆數為: 281.00, 全部猜漲猜對的機率是: 0.63
# 該測試集資料的：
# Accuracy: 0.81, Precision: 0.82, Recall: 0.90
# F1 score: 0.86

# %%
pre = model.predict_classes(cnn_x_validation)
pre = pd.Series(pre)
pre.hist()

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_validation = np.argmax(cnn_y_validation, axis=1)
xcnn_y_validation = pd.Series(cnn_y_validation)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_validation, pre)

t_size = len(cnn_y_validation)
t_size1 = (cnn_y_validation<1).sum()
t_guess = ((cnn_y_validation<1).sum())/(len(cnn_y_validation))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 120.00, FN: 52.00, FP: 46.00, TN: 18.00
# 對訓練集資料的：Loss: 0.30, Accuracy: 0.89
# 對測試集資料的：Loss: 0.44, Accuracy: 0.81
#
# 測試資料總共：236.00 筆, 其中漲的筆數為: 172.00, 全部猜漲猜對的機率是: 0.73
# 該測試集資料的：
# Accuracy: 0.58, Precision: 0.72, Recall: 0.70
# F1 score: 0.71
