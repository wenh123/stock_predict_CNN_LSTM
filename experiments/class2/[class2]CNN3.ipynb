# %%
import pandas as pd
import numpy as np
import datetime
import tqdm #進度條
import talib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
data = pd.read_csv('data/1019_SP.csv')
Date = data.get("Date")
Date = pd.to_datetime(Date)
Open = data.get("Open")
High = data.get("High")
Low = data.get("Low")
Close = data.get("Close")

dict = {"Date": Date,
        "open": Open,
        "high": High,
        "low": Low, 
        "close": Close
       }
df = pd.DataFrame(dict)
df.set_index('Date', inplace=True)
df = df.dropna()
print("總共:%d個交易時間點" % (len(Date)))
print("去除空白值後剩下:%d個交易時間點" % (len(df)))
df.tail(10)
# Out:
# 總共:2493個交易時間點
# 去除空白值後剩下:2493個交易時間點
#                    open         high          low        close
# Date
# 2019-12-13  3166.649902  3182.679932  3156.510010  3168.800049
# 2019-12-16  3183.629883  3197.709961  3183.629883  3191.449951
# 2019-12-17  3195.399902  3198.219971  3191.030029  3192.520020
# 2019-12-18  3195.209961  3198.479980  3191.139893  3191.139893
# 2019-12-19  3192.320068  3205.479980  3192.320068  3205.370117
# 2019-12-20  3223.330078  3225.649902  3216.030029  3221.219971
# 2019-12-23  3226.050049  3227.780029  3222.300049  3224.010010
# 2019-12-26  3227.199951  3240.080078  3227.199951  3239.909912
# 2019-12-27  3247.229980  3247.929932  3234.370117  3240.020020
# 2019-12-30  3240.090088  3240.919922  3216.570068  3221.290039

# %%
ema = talib.EMA(df['close'])
sma = talib.SMA(df['close'])
roc = talib.ROC(df['close'])
macd, macdsignal, macdhist = talib.MACD(df['close'])

dataset = pd.DataFrame({
    'Close':df['close'],    
    'EMA':ema,
    'SMA':sma,
    'ROC':roc,
    'MACD':macd,
    'return': df['close']
})

feature_names = list(dataset.columns[:-1])

# %%
print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)
# Out:
# before dropping NaN (2493, 6)
# after dropping NaN (2460, 6)

# %%
from sklearn.preprocessing import MinMaxScaler

ss = MinMaxScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
#dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()
# Out:
#              Close          EMA  ...         MACD       return
# count  2460.000000  2460.000000  ...  2460.000000  2460.000000
# mean      0.428129     0.424185  ...     0.641694     0.428129
# std       0.263129     0.278491  ...     0.134407     0.263129
# min       0.000000     0.000000  ...     0.000000     0.000000
# 25%       0.170140     0.147477  ...     0.573992     0.170140
# 50%       0.437414     0.435432  ...     0.665200     0.437414
# 75%       0.638417     0.647352  ...     0.726499     0.638417
# max       1.000000     1.000000  ...     1.000000     1.000000
#
# [8 rows x 6 columns]

# %%
from keras.utils import np_utils
#每張圖包含幾天的資料
time_period = 20
#預設幾日後的漲跌
day = 10

cnn_x = []
cnn_y = []
indexs = []
dataset_scaled_x= dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-time_period-1-day)):
    cnn_x.append(dataset_scaled_x.iloc[i:i+time_period].values)
    r = dataset_scaled['return'].iloc[i+time_period-1+day]/dataset_scaled['return'].iloc[i+time_period-1]
    if r > 1:
        r = 0
    else:
        r = 1
    rr = np_utils.to_categorical(r, num_classes=2)
    cnn_y.append(rr)
    indexs.append(dataset_scaled.index[i+time_period-1])
    
cnn_x = np.array(cnn_x)
cnn_y = np.array(cnn_y)
indexes = np.array(indexs)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# HBox(children=(IntProgress(value=0, max=2429), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars

# %%
#2010~2018年為訓練和測試，2019年則為驗證
import datetime
cnn_x_t = cnn_x[indexes < datetime.datetime(2019,1,1)]
cnn_y_t = cnn_y[indexes < datetime.datetime(2019,1,1)]

# %%
cnn_x_validation = cnn_x[indexes > datetime.datetime(2019,1,1)]
cnn_y_validation = cnn_y[indexes > datetime.datetime(2019,1,1)]

# %%
from sklearn.model_selection import train_test_split
cnn_x_train, cnn_x_test, cnn_y_train, cnn_y_test = train_test_split(cnn_x_t, cnn_y_t, test_size=0.2,random_state =1,stratify=cnn_y_t,shuffle = True)

# %%
cnn_x_train = np.stack((cnn_x_train,)*3,axis=-1)
cnn_x_test = np.stack((cnn_x_test,)*3,axis=-1)
cnn_x_validation = np.stack((cnn_x_validation,)*3,axis=-1)

# %%
fig = plt.figure(figsize = (15,15))
columns = rows = 5
for i in range(1,columns*rows+1):
  index = np.random.randint(len(cnn_x_train))
  img = cnn_x_train[index]
  fig.add_subplot(rows,columns,i)
  plt.axis("off")
  plt.title(str(index)+' class = '+str(np.argmax(cnn_y_train[index])))
  plt.subplots_adjust(wspace=0.2,hspace=0.2)
  plt.imshow(img)
plt.show()

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.initializers import he_normal

input_shape = cnn_x_train[0].shape

model = Sequential()
model.add(layers.Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same",
                        input_shape=input_shape))
model.add(layers.Conv2D(filters=64, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same"))
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Dropout(0.25))
model.add(layers.Flatten())
model.add(layers.Dense(units=128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=2, activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer="Adam", metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 20, 5, 32)         896
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 5, 64)         18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 2, 64)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 10, 2, 64)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               163968
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 183,618
# Trainable params: 183,618
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

history = model.fit(cnn_x_train, cnn_y_train,
                    batch_size=100,
                    epochs=250,
                    verbose=1,
                    validation_data=(cnn_x_test,cnn_y_test),
                    callbacks=[earlystop],
                    )
# Out:
# Epoch 1/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6728 - accuracy: 0.6060 - val_loss: 0.6624 - val_accuracy: 0.6264
# Epoch 2/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6633 - accuracy: 0.6254 - val_loss: 0.6618 - val_accuracy: 0.6264
# Epoch 3/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6671 - accuracy: 0.6254 - val_loss: 0.6626 - val_accuracy: 0.6264
# Epoch 4/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6596 - accuracy: 0.6254 - val_loss: 0.6622 - val_accuracy: 0.6264
# Epoch 5/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6643 - accuracy: 0.6254 - val_loss: 0.6604 - val_accuracy: 0.6264
# Epoch 6/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6633 - accuracy: 0.6254 - val_loss: 0.6610 - val_accuracy: 0.6264
# Epoch 7/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6650 - accuracy: 0.6254 - val_loss: 0.6605 - val_accuracy: 0.6264
# Epoch 8/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6615 - accuracy: 0.6254 - val_loss: 0.6635 - val_accuracy: 0.6264
# Epoch 9/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6634 - accuracy: 0.6254 - val_loss: 0.6591 - val_accuracy: 0.6264
# Epoch 10/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6620 - accuracy: 0.6254 - val_loss: 0.6589 - val_accuracy: 0.6264
# Epoch 11/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6574 - accuracy: 0.6260 - val_loss: 0.6583 - val_accuracy: 0.6264
# Epoch 12/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6593 - accuracy: 0.6260 - val_loss: 0.6569 - val_accuracy: 0.6173
# Epoch 13/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6584 - accuracy: 0.6277 - val_loss: 0.6552 - val_accuracy: 0.6264
# Epoch 14/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6541 - accuracy: 0.6277 - val_loss: 0.6566 - val_accuracy: 0.6173
# Epoch 15/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6559 - accuracy: 0.6300 - val_loss: 0.6536 - val_accuracy: 0.6196
# Epoch 16/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6564 - accuracy: 0.6231 - val_loss: 0.6553 - val_accuracy: 0.6264
# Epoch 17/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6541 - accuracy: 0.6254 - val_loss: 0.6515 - val_accuracy: 0.6287
# Epoch 18/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6487 - accuracy: 0.6260 - val_loss: 0.6503 - val_accuracy: 0.6196
# Epoch 19/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6520 - accuracy: 0.6283 - val_loss: 0.6526 - val_accuracy: 0.6173
# Epoch 20/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6501 - accuracy: 0.6277 - val_loss: 0.6483 - val_accuracy: 0.6241
# Epoch 21/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6446 - accuracy: 0.6277 - val_loss: 0.6502 - val_accuracy: 0.6287
# Epoch 22/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6418 - accuracy: 0.6340 - val_loss: 0.6469 - val_accuracy: 0.6219
# Epoch 23/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6401 - accuracy: 0.6340 - val_loss: 0.6417 - val_accuracy: 0.6287
# Epoch 24/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6371 - accuracy: 0.6431 - val_loss: 0.6389 - val_accuracy: 0.6287
# Epoch 25/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6396 - accuracy: 0.6300 - val_loss: 0.6412 - val_accuracy: 0.6287
# Epoch 26/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6387 - accuracy: 0.6345 - val_loss: 0.6400 - val_accuracy: 0.6287
# Epoch 27/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6270 - accuracy: 0.6397 - val_loss: 0.6362 - val_accuracy: 0.6492
# Epoch 28/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6246 - accuracy: 0.6528 - val_loss: 0.6449 - val_accuracy: 0.6128
# Epoch 29/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6285 - accuracy: 0.6454 - val_loss: 0.6382 - val_accuracy: 0.6287
# Epoch 30/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6348 - accuracy: 0.6454 - val_loss: 0.6505 - val_accuracy: 0.5513
# Epoch 31/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6265 - accuracy: 0.6522 - val_loss: 0.6330 - val_accuracy: 0.6333
# Epoch 32/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6273 - accuracy: 0.6568 - val_loss: 0.6336 - val_accuracy: 0.5968
# Epoch 33/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6244 - accuracy: 0.6517 - val_loss: 0.6403 - val_accuracy: 0.6219
# Epoch 34/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6218 - accuracy: 0.6499 - val_loss: 0.6327 - val_accuracy: 0.6333
# Epoch 35/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6210 - accuracy: 0.6517 - val_loss: 0.6336 - val_accuracy: 0.6355
# Epoch 36/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6146 - accuracy: 0.6591 - val_loss: 0.6280 - val_accuracy: 0.6401
# Epoch 37/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6156 - accuracy: 0.6517 - val_loss: 0.6266 - val_accuracy: 0.6355
# Epoch 38/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6127 - accuracy: 0.6534 - val_loss: 0.6255 - val_accuracy: 0.6310
# Epoch 39/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6098 - accuracy: 0.6522 - val_loss: 0.6262 - val_accuracy: 0.6310
# Epoch 40/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6053 - accuracy: 0.6602 - val_loss: 0.6228 - val_accuracy: 0.6173
# Epoch 41/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5922 - accuracy: 0.6659 - val_loss: 0.6340 - val_accuracy: 0.6128
# Epoch 42/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5988 - accuracy: 0.6551 - val_loss: 0.6348 - val_accuracy: 0.6196
# Epoch 43/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5928 - accuracy: 0.6733 - val_loss: 0.6187 - val_accuracy: 0.6287
# Epoch 44/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5933 - accuracy: 0.6625 - val_loss: 0.6164 - val_accuracy: 0.6469
# Epoch 45/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5857 - accuracy: 0.6847 - val_loss: 0.6182 - val_accuracy: 0.6219
# Epoch 46/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5942 - accuracy: 0.6699 - val_loss: 0.6166 - val_accuracy: 0.6082
# Epoch 47/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5854 - accuracy: 0.6716 - val_loss: 0.6175 - val_accuracy: 0.6333
# Epoch 48/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5934 - accuracy: 0.6796 - val_loss: 0.6225 - val_accuracy: 0.6310
# Epoch 49/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5802 - accuracy: 0.6733 - val_loss: 0.6120 - val_accuracy: 0.6219
# Epoch 50/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5846 - accuracy: 0.6830 - val_loss: 0.6373 - val_accuracy: 0.6082
# Epoch 51/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5883 - accuracy: 0.6750 - val_loss: 0.6106 - val_accuracy: 0.6651
# Epoch 52/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5816 - accuracy: 0.6682 - val_loss: 0.6061 - val_accuracy: 0.6310
# Epoch 53/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5683 - accuracy: 0.6916 - val_loss: 0.6094 - val_accuracy: 0.6401
# Epoch 54/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5706 - accuracy: 0.6899 - val_loss: 0.6084 - val_accuracy: 0.6492
# Epoch 55/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5678 - accuracy: 0.6921 - val_loss: 0.6063 - val_accuracy: 0.6287
# Epoch 56/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5620 - accuracy: 0.6864 - val_loss: 0.6115 - val_accuracy: 0.6355
# Epoch 57/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5539 - accuracy: 0.6961 - val_loss: 0.6379 - val_accuracy: 0.5923
# Epoch 58/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5692 - accuracy: 0.6870 - val_loss: 0.6090 - val_accuracy: 0.6424
# Epoch 59/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5573 - accuracy: 0.6984 - val_loss: 0.5971 - val_accuracy: 0.6310
# Epoch 60/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5493 - accuracy: 0.6995 - val_loss: 0.6007 - val_accuracy: 0.6583
# Epoch 61/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5534 - accuracy: 0.7075 - val_loss: 0.6010 - val_accuracy: 0.6401
# Epoch 62/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5494 - accuracy: 0.6859 - val_loss: 0.5993 - val_accuracy: 0.6515
# Epoch 63/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5477 - accuracy: 0.6956 - val_loss: 0.5894 - val_accuracy: 0.6424
# Epoch 64/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5430 - accuracy: 0.6927 - val_loss: 0.5943 - val_accuracy: 0.6560
# Epoch 65/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5397 - accuracy: 0.7189 - val_loss: 0.5962 - val_accuracy: 0.6583
# Epoch 66/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5435 - accuracy: 0.7030 - val_loss: 0.5959 - val_accuracy: 0.6811
# Epoch 67/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5438 - accuracy: 0.7195 - val_loss: 0.6049 - val_accuracy: 0.6583
# Epoch 68/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5365 - accuracy: 0.7109 - val_loss: 0.5898 - val_accuracy: 0.6446
# Epoch 69/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5369 - accuracy: 0.7030 - val_loss: 0.5969 - val_accuracy: 0.6310
# Epoch 70/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5419 - accuracy: 0.7149 - val_loss: 0.5829 - val_accuracy: 0.6492
# Epoch 71/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5300 - accuracy: 0.7138 - val_loss: 0.5854 - val_accuracy: 0.6538
# Epoch 72/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5401 - accuracy: 0.7030 - val_loss: 0.5816 - val_accuracy: 0.6674
# Epoch 73/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5364 - accuracy: 0.7172 - val_loss: 0.5844 - val_accuracy: 0.6743
# Epoch 74/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5267 - accuracy: 0.7166 - val_loss: 0.5861 - val_accuracy: 0.6515
# Epoch 75/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5257 - accuracy: 0.7206 - val_loss: 0.5825 - val_accuracy: 0.6674
# Epoch 76/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5232 - accuracy: 0.7286 - val_loss: 0.5773 - val_accuracy: 0.6424
# Epoch 77/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5337 - accuracy: 0.7178 - val_loss: 0.5825 - val_accuracy: 0.6515
# Epoch 78/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5342 - accuracy: 0.7132 - val_loss: 0.5924 - val_accuracy: 0.6697
# Epoch 79/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5380 - accuracy: 0.7047 - val_loss: 0.5780 - val_accuracy: 0.6743
# Epoch 80/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5111 - accuracy: 0.7275 - val_loss: 0.5692 - val_accuracy: 0.6811
# Epoch 81/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5066 - accuracy: 0.7389 - val_loss: 0.5785 - val_accuracy: 0.6720
# Epoch 82/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5036 - accuracy: 0.7360 - val_loss: 0.5707 - val_accuracy: 0.6765
# Epoch 83/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4992 - accuracy: 0.7440 - val_loss: 0.5738 - val_accuracy: 0.6674
# Epoch 84/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5006 - accuracy: 0.7366 - val_loss: 0.5797 - val_accuracy: 0.6697
# Epoch 85/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4948 - accuracy: 0.7497 - val_loss: 0.5657 - val_accuracy: 0.6651
# Epoch 86/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4897 - accuracy: 0.7554 - val_loss: 0.5784 - val_accuracy: 0.6765
# Epoch 87/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4970 - accuracy: 0.7474 - val_loss: 0.5682 - val_accuracy: 0.6720
# Epoch 88/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4930 - accuracy: 0.7480 - val_loss: 0.5691 - val_accuracy: 0.6948
# Epoch 89/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4872 - accuracy: 0.7480 - val_loss: 0.5683 - val_accuracy: 0.6856
# Epoch 90/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4927 - accuracy: 0.7457 - val_loss: 0.5882 - val_accuracy: 0.6902
# Epoch 91/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4935 - accuracy: 0.7320 - val_loss: 0.5630 - val_accuracy: 0.6970
# Epoch 92/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4880 - accuracy: 0.7503 - val_loss: 0.5562 - val_accuracy: 0.6879
# Epoch 93/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4907 - accuracy: 0.7605 - val_loss: 0.5649 - val_accuracy: 0.6811
# Epoch 94/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4813 - accuracy: 0.7520 - val_loss: 0.5839 - val_accuracy: 0.6743
# Epoch 95/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4798 - accuracy: 0.7634 - val_loss: 0.5660 - val_accuracy: 0.6856
# Epoch 96/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4873 - accuracy: 0.7548 - val_loss: 0.5688 - val_accuracy: 0.6993
# Epoch 97/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4882 - accuracy: 0.7583 - val_loss: 0.5688 - val_accuracy: 0.6970
# Epoch 98/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4746 - accuracy: 0.7531 - val_loss: 0.5581 - val_accuracy: 0.6834
# Epoch 99/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4593 - accuracy: 0.7748 - val_loss: 0.5573 - val_accuracy: 0.6948
# Epoch 100/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4765 - accuracy: 0.7617 - val_loss: 0.5527 - val_accuracy: 0.7084
# Epoch 101/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4738 - accuracy: 0.7491 - val_loss: 0.5586 - val_accuracy: 0.6902
# Epoch 102/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4787 - accuracy: 0.7531 - val_loss: 0.5544 - val_accuracy: 0.7198
# Epoch 103/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4792 - accuracy: 0.7640 - val_loss: 0.5629 - val_accuracy: 0.6697
# Epoch 104/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4616 - accuracy: 0.7617 - val_loss: 0.5574 - val_accuracy: 0.6948
# Epoch 105/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4587 - accuracy: 0.7759 - val_loss: 0.5633 - val_accuracy: 0.7175
# Epoch 106/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4640 - accuracy: 0.7708 - val_loss: 0.5458 - val_accuracy: 0.7221
# Epoch 107/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4619 - accuracy: 0.7742 - val_loss: 0.5494 - val_accuracy: 0.7084
# Epoch 108/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4525 - accuracy: 0.7799 - val_loss: 0.5564 - val_accuracy: 0.6925
# Epoch 109/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4654 - accuracy: 0.7640 - val_loss: 0.5450 - val_accuracy: 0.7153
# Epoch 110/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4622 - accuracy: 0.7600 - val_loss: 0.5459 - val_accuracy: 0.7107
# Epoch 111/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4619 - accuracy: 0.7691 - val_loss: 0.5785 - val_accuracy: 0.6788
# Epoch 112/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4714 - accuracy: 0.7571 - val_loss: 0.5467 - val_accuracy: 0.6902
# Epoch 113/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4587 - accuracy: 0.7680 - val_loss: 0.5477 - val_accuracy: 0.7130
# Epoch 114/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4537 - accuracy: 0.7856 - val_loss: 0.5512 - val_accuracy: 0.7084
# Epoch 115/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4581 - accuracy: 0.7788 - val_loss: 0.5551 - val_accuracy: 0.6948
# Epoch 116/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4492 - accuracy: 0.7799 - val_loss: 0.5732 - val_accuracy: 0.6948
# Epoch 117/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4477 - accuracy: 0.7834 - val_loss: 0.5359 - val_accuracy: 0.7221
# Epoch 118/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4462 - accuracy: 0.7970 - val_loss: 0.5340 - val_accuracy: 0.7153
# Epoch 119/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4463 - accuracy: 0.7839 - val_loss: 0.5466 - val_accuracy: 0.7153
# Epoch 120/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4373 - accuracy: 0.7999 - val_loss: 0.5726 - val_accuracy: 0.7198
# Epoch 121/250
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4502 - accuracy: 0.7805 - val_loss: 0.5457 - val_accuracy: 0.7221
# Epoch 122/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4394 - accuracy: 0.7862 - val_loss: 0.5519 - val_accuracy: 0.7084
# Epoch 123/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4499 - accuracy: 0.7754 - val_loss: 0.5340 - val_accuracy: 0.7312
# Epoch 124/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4174 - accuracy: 0.7959 - val_loss: 0.5461 - val_accuracy: 0.7244
# Epoch 125/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4210 - accuracy: 0.7970 - val_loss: 0.5384 - val_accuracy: 0.7198
# Epoch 126/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4238 - accuracy: 0.7987 - val_loss: 0.5359 - val_accuracy: 0.7175
# Epoch 127/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4179 - accuracy: 0.7987 - val_loss: 0.5481 - val_accuracy: 0.7198
# Epoch 128/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4255 - accuracy: 0.8033 - val_loss: 0.5364 - val_accuracy: 0.7380
# Epoch 00128: early stopping

# %%
o_loss,o_accuracy = model.evaluate(cnn_x_train,cnn_y_train)
print("對訓練資料的：\nLoss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
n_loss,n_accuracy = model.evaluate(cnn_x_test,cnn_y_test)
print("對測試資料的：\nLoss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
# Out:
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3702 - accuracy: 0.8409
# 對訓練資料的：
# Loss: 0.37, Accuracy: 0.84
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5242 - accuracy: 0.7380
# 對測試資料的：
# Loss: 0.52, Accuracy: 0.74

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(np.log(history.history['loss']), color = 'green', label='Loss')
plt.plot(np.log(history.history['val_loss']), color = 'blue', label='Val_Loss')
plt.legend()
plt.title('Training loss based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], color = 'green', label='accuracy')
plt.plot(history.history['val_accuracy'], color = 'blue', label='Val_accuracy')
plt.legend()
plt.title('Accuracy based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()

# %%
pre = model.predict_classes(cnn_x_test)
pre = pd.Series(pre)

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_test = np.argmax(cnn_y_test, axis=1)
xcnn_y_test = pd.Series(cnn_y_test)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_test, pre)

t_size = len(cnn_y_test)
t_size1 = (cnn_y_test<1).sum()
t_guess = ((cnn_y_test<1).sum())/(len(cnn_y_test))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 237.00, FN: 38.00, FP: 77.00, TN: 87.00
# 對訓練集資料的：Loss: 0.37, Accuracy: 0.84
# 對測試集資料的：Loss: 0.52, Accuracy: 0.74
#
# 測試資料總共：439.00 筆, 其中漲的筆數為: 275.00, 全部猜漲猜對的機率是: 0.63
# 該測試集資料的：
# Accuracy: 0.74, Precision: 0.75, Recall: 0.86
# F1 score: 0.80

# %%
pre = model.predict_classes(cnn_x_validation)
pre = pd.Series(pre)
pre.hist()

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_validation = np.argmax(cnn_y_validation, axis=1)
xcnn_y_validation = pd.Series(cnn_y_validation)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_validation, pre)

t_size = len(cnn_y_validation)
t_size1 = (cnn_y_validation<1).sum()
t_guess = ((cnn_y_validation<1).sum())/(len(cnn_y_validation))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 101.00, FN: 71.00, FP: 42.00, TN: 22.00
# 對訓練集資料的：Loss: 0.37, Accuracy: 0.84
# 對測試集資料的：Loss: 0.52, Accuracy: 0.74
#
# 測試資料總共：236.00 筆, 其中漲的筆數為: 172.00, 全部猜漲猜對的機率是: 0.73
# 該測試集資料的：
# Accuracy: 0.52, Precision: 0.71, Recall: 0.59
# F1 score: 0.64
