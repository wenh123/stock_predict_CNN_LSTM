# %%
import pandas as pd
import numpy as np
import datetime
import tqdm #進度條
import talib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
data = pd.read_csv('data/1019_SP.csv')
Date = data.get("Date")
Date = pd.to_datetime(Date)
Open = data.get("Open")
High = data.get("High")
Low = data.get("Low")
Close = data.get("Close")

dict = {"Date": Date,
        "open": Open,
        "high": High,
        "low": Low, 
        "close": Close
       }
df = pd.DataFrame(dict)
df.set_index('Date', inplace=True)
df = df.dropna()
print("總共:%d個交易時間點" % (len(Date)))
print("去除空白值後剩下:%d個交易時間點" % (len(df)))
df.tail(10)
# Out:
# 總共:2493個交易時間點
# 去除空白值後剩下:2493個交易時間點
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                    open         high          low        close
# Date
# 2019-12-13  3166.649902  3182.679932  3156.510010  3168.800049
# 2019-12-16  3183.629883  3197.709961  3183.629883  3191.449951
# 2019-12-17  3195.399902  3198.219971  3191.030029  3192.520020
# 2019-12-18  3195.209961  3198.479980  3191.139893  3191.139893
# 2019-12-19  3192.320068  3205.479980  3192.320068  3205.370117
# 2019-12-20  3223.330078  3225.649902  3216.030029  3221.219971
# 2019-12-23  3226.050049  3227.780029  3222.300049  3224.010010
# 2019-12-26  3227.199951  3240.080078  3227.199951  3239.909912
# 2019-12-27  3247.229980  3247.929932  3234.370117  3240.020020
# 2019-12-30  3240.090088  3240.919922  3216.570068  3221.290039

# %%
ema = talib.EMA(df['close'])
sma = talib.SMA(df['close'])

dataset = pd.DataFrame({
    'Close':df['close'],    
    'EMA':ema,
    'SMA':sma,
    'return': df['close']
})

feature_names = list(dataset.columns[:-1])

# %%
print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)
# Out:
# before dropping NaN (2493, 4)
# after dropping NaN (2464, 4)

# %%
from sklearn.preprocessing import MinMaxScaler

ss = MinMaxScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
#dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()
# Out:
#              Close          EMA          SMA       return
# count  2464.000000  2464.000000  2464.000000  2464.000000
# mean      0.427493     0.423518     0.424978     0.427493
# std       0.263389     0.278755     0.279087     0.263389
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.169630     0.147058     0.150741     0.169630
# 50%       0.436382     0.435048     0.433609     0.436382
# 75%       0.638309     0.647281     0.651904     0.638309
# max       1.000000     1.000000     1.000000     1.000000

# %%
from keras.utils import np_utils
#每張圖包含幾天的資料
time_period = 20
#預設幾日後的漲跌
day = 10

cnn_x = []
cnn_y = []
indexs = []
dataset_scaled_x= dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-time_period-1-day)):
    cnn_x.append(dataset_scaled_x.iloc[i:i+time_period].values)
    r = dataset_scaled['return'].iloc[i+time_period-1+day]/dataset_scaled['return'].iloc[i+time_period-1]
    if r > 1.007:
        r = 0
    else:
        r = 1
    rr = np_utils.to_categorical(r, num_classes=2)
    cnn_y.append(rr)
    indexs.append(dataset_scaled.index[i+time_period-1])
    
cnn_x = np.array(cnn_x)
cnn_y = np.array(cnn_y)
indexes = np.array(indexs)
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# HBox(children=(IntProgress(value=0, max=2433), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars

# %%
#2010~2018年為訓練和測試，2019年則為驗證
import datetime
cnn_x_t = cnn_x[indexes < datetime.datetime(2019,1,1)]
cnn_y_t = cnn_y[indexes < datetime.datetime(2019,1,1)]

# %%
cnn_x_validation = cnn_x[indexes > datetime.datetime(2019,1,1)]
cnn_y_validation = cnn_y[indexes > datetime.datetime(2019,1,1)]

# %%
from sklearn.model_selection import train_test_split
cnn_x_train, cnn_x_test, cnn_y_train, cnn_y_test = train_test_split(cnn_x_t, cnn_y_t, test_size=0.2,random_state =7,stratify=cnn_y_t,shuffle = True)

# %%
cnn_x_train = np.stack((cnn_x_train,)*3,axis=-1)
cnn_x_test = np.stack((cnn_x_test,)*3,axis=-1)
cnn_x_validation = np.stack((cnn_x_validation,)*3,axis=-1)

# %%
fig = plt.figure(figsize = (15,15))
columns = rows = 5
for i in range(1,columns*rows+1):
  index = np.random.randint(len(cnn_x_train))
  img = cnn_x_train[index]
  fig.add_subplot(rows,columns,i)
  plt.axis("off")
  plt.title(str(index)+' class = '+str(np.argmax(cnn_y_train[index])))
  plt.subplots_adjust(wspace=0.2,hspace=0.2)
  plt.imshow(img)
plt.show()

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.initializers import he_normal

input_shape = cnn_x_train[0].shape

model = Sequential()
model.add(layers.Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same",
                        input_shape=input_shape))
model.add(layers.Conv2D(filters=64, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same"))
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Dropout(0.25))
model.add(layers.Flatten())
model.add(layers.Dense(units=128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=2, activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer="Adam", metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 20, 3, 32)         896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 3, 64)         18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 1, 64)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 1, 64)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 640)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               82048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 101,698
# Trainable params: 101,698
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

history = model.fit(cnn_x_train, cnn_y_train,
                    batch_size=100,
                    epochs=250,
                    verbose=1,
                    validation_data=(cnn_x_test,cnn_y_test),
                    callbacks=[earlystop],
                    )
# Out:
# Epoch 1/250
# 18/18 [==============================] - 0s 18ms/step - loss: 0.6932 - accuracy: 0.5538 - val_loss: 0.6902 - val_accuracy: 0.5886
# Epoch 2/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6935 - accuracy: 0.5441 - val_loss: 0.6873 - val_accuracy: 0.5614
# Epoch 3/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6856 - accuracy: 0.5629 - val_loss: 0.6831 - val_accuracy: 0.5614
# Epoch 4/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6839 - accuracy: 0.5623 - val_loss: 0.6818 - val_accuracy: 0.5614
# Epoch 5/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6842 - accuracy: 0.5606 - val_loss: 0.6812 - val_accuracy: 0.5614
# Epoch 6/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6836 - accuracy: 0.5623 - val_loss: 0.6812 - val_accuracy: 0.5614
# Epoch 7/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6824 - accuracy: 0.5583 - val_loss: 0.6800 - val_accuracy: 0.5614
# Epoch 8/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6828 - accuracy: 0.5618 - val_loss: 0.6806 - val_accuracy: 0.5614
# Epoch 9/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6844 - accuracy: 0.5492 - val_loss: 0.6809 - val_accuracy: 0.5614
# Epoch 10/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6829 - accuracy: 0.5623 - val_loss: 0.6810 - val_accuracy: 0.5614
# Epoch 11/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6847 - accuracy: 0.5623 - val_loss: 0.6795 - val_accuracy: 0.5614
# Epoch 12/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6826 - accuracy: 0.5623 - val_loss: 0.6796 - val_accuracy: 0.5614
# Epoch 13/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6822 - accuracy: 0.5612 - val_loss: 0.6790 - val_accuracy: 0.5614
# Epoch 14/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6824 - accuracy: 0.5595 - val_loss: 0.6792 - val_accuracy: 0.5614
# Epoch 15/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6836 - accuracy: 0.5595 - val_loss: 0.6794 - val_accuracy: 0.5614
# Epoch 16/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6818 - accuracy: 0.5623 - val_loss: 0.6795 - val_accuracy: 0.5614
# Epoch 17/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6829 - accuracy: 0.5623 - val_loss: 0.6790 - val_accuracy: 0.5614
# Epoch 18/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6826 - accuracy: 0.5629 - val_loss: 0.6792 - val_accuracy: 0.5614
# Epoch 19/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6806 - accuracy: 0.5623 - val_loss: 0.6788 - val_accuracy: 0.5614
# Epoch 20/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6807 - accuracy: 0.5652 - val_loss: 0.6789 - val_accuracy: 0.5614
# Epoch 21/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6829 - accuracy: 0.5640 - val_loss: 0.6790 - val_accuracy: 0.5614
# Epoch 22/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6824 - accuracy: 0.5646 - val_loss: 0.6790 - val_accuracy: 0.5614
# Epoch 23/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6811 - accuracy: 0.5583 - val_loss: 0.6786 - val_accuracy: 0.5614
# Epoch 24/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6814 - accuracy: 0.5583 - val_loss: 0.6798 - val_accuracy: 0.5614
# Epoch 25/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6816 - accuracy: 0.5618 - val_loss: 0.6781 - val_accuracy: 0.5614
# Epoch 26/250
# 18/18 [==============================] - 0s 7ms/step - loss: 0.6810 - accuracy: 0.5521 - val_loss: 0.6779 - val_accuracy: 0.5614
# Epoch 27/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6820 - accuracy: 0.5635 - val_loss: 0.6785 - val_accuracy: 0.5614
# Epoch 28/250
# 18/18 [==============================] - 0s 7ms/step - loss: 0.6814 - accuracy: 0.5629 - val_loss: 0.6772 - val_accuracy: 0.5614
# Epoch 29/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6796 - accuracy: 0.5629 - val_loss: 0.6766 - val_accuracy: 0.5614
# Epoch 30/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6803 - accuracy: 0.5640 - val_loss: 0.6777 - val_accuracy: 0.5614
# Epoch 31/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6812 - accuracy: 0.5612 - val_loss: 0.6761 - val_accuracy: 0.5614
# Epoch 32/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6794 - accuracy: 0.5606 - val_loss: 0.6754 - val_accuracy: 0.5614
# Epoch 33/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6785 - accuracy: 0.5623 - val_loss: 0.6737 - val_accuracy: 0.5614
# Epoch 34/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6808 - accuracy: 0.5635 - val_loss: 0.6760 - val_accuracy: 0.5614
# Epoch 35/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6773 - accuracy: 0.5629 - val_loss: 0.6715 - val_accuracy: 0.5614
# Epoch 36/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6780 - accuracy: 0.5629 - val_loss: 0.6738 - val_accuracy: 0.5614
# Epoch 37/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6779 - accuracy: 0.5623 - val_loss: 0.6728 - val_accuracy: 0.5614
# Epoch 38/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6769 - accuracy: 0.5623 - val_loss: 0.6684 - val_accuracy: 0.5614
# Epoch 39/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6744 - accuracy: 0.5612 - val_loss: 0.6686 - val_accuracy: 0.5614
# Epoch 40/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6744 - accuracy: 0.5646 - val_loss: 0.6646 - val_accuracy: 0.5614
# Epoch 41/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6754 - accuracy: 0.5418 - val_loss: 0.6642 - val_accuracy: 0.5614
# Epoch 42/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6733 - accuracy: 0.5623 - val_loss: 0.6643 - val_accuracy: 0.5614
# Epoch 43/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6720 - accuracy: 0.5629 - val_loss: 0.6606 - val_accuracy: 0.5659
# Epoch 44/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6727 - accuracy: 0.5652 - val_loss: 0.6595 - val_accuracy: 0.5682
# Epoch 45/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6690 - accuracy: 0.5692 - val_loss: 0.6574 - val_accuracy: 0.5682
# Epoch 46/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6692 - accuracy: 0.5669 - val_loss: 0.6566 - val_accuracy: 0.5682
# Epoch 47/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6699 - accuracy: 0.5657 - val_loss: 0.6609 - val_accuracy: 0.5682
# Epoch 48/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6691 - accuracy: 0.5703 - val_loss: 0.6573 - val_accuracy: 0.5705
# Epoch 49/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6679 - accuracy: 0.5714 - val_loss: 0.6506 - val_accuracy: 0.5727
# Epoch 50/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6652 - accuracy: 0.5686 - val_loss: 0.6503 - val_accuracy: 0.5750
# Epoch 51/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6644 - accuracy: 0.5669 - val_loss: 0.6538 - val_accuracy: 0.5705
# Epoch 52/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6644 - accuracy: 0.5720 - val_loss: 0.6500 - val_accuracy: 0.5773
# Epoch 53/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6653 - accuracy: 0.5726 - val_loss: 0.6462 - val_accuracy: 0.5750
# Epoch 54/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6640 - accuracy: 0.5692 - val_loss: 0.6562 - val_accuracy: 0.5773
# Epoch 55/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6639 - accuracy: 0.5743 - val_loss: 0.6444 - val_accuracy: 0.5795
# Epoch 56/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6621 - accuracy: 0.5766 - val_loss: 0.6473 - val_accuracy: 0.5773
# Epoch 57/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6619 - accuracy: 0.5692 - val_loss: 0.6434 - val_accuracy: 0.5750
# Epoch 58/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6644 - accuracy: 0.5714 - val_loss: 0.6535 - val_accuracy: 0.5727
# Epoch 59/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6628 - accuracy: 0.5703 - val_loss: 0.6468 - val_accuracy: 0.5773
# Epoch 60/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6624 - accuracy: 0.5743 - val_loss: 0.6465 - val_accuracy: 0.5750
# Epoch 61/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6589 - accuracy: 0.5737 - val_loss: 0.6406 - val_accuracy: 0.5795
# Epoch 62/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6596 - accuracy: 0.5754 - val_loss: 0.6420 - val_accuracy: 0.5773
# Epoch 63/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6611 - accuracy: 0.5748 - val_loss: 0.6516 - val_accuracy: 0.5705
# Epoch 64/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6563 - accuracy: 0.5692 - val_loss: 0.6400 - val_accuracy: 0.5795
# Epoch 65/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6572 - accuracy: 0.5834 - val_loss: 0.6508 - val_accuracy: 0.5750
# Epoch 66/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6618 - accuracy: 0.5652 - val_loss: 0.6376 - val_accuracy: 0.5773
# Epoch 67/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6575 - accuracy: 0.5754 - val_loss: 0.6407 - val_accuracy: 0.5795
# Epoch 68/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6560 - accuracy: 0.5760 - val_loss: 0.6417 - val_accuracy: 0.5750
# Epoch 69/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6560 - accuracy: 0.5845 - val_loss: 0.6425 - val_accuracy: 0.5727
# Epoch 70/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6558 - accuracy: 0.5743 - val_loss: 0.6335 - val_accuracy: 0.5795
# Epoch 71/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6534 - accuracy: 0.5783 - val_loss: 0.6389 - val_accuracy: 0.5750
# Epoch 72/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6518 - accuracy: 0.5828 - val_loss: 0.6448 - val_accuracy: 0.5795
# Epoch 73/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6539 - accuracy: 0.5748 - val_loss: 0.6364 - val_accuracy: 0.5773
# Epoch 74/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6515 - accuracy: 0.5828 - val_loss: 0.6546 - val_accuracy: 0.5682
# Epoch 75/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6546 - accuracy: 0.5834 - val_loss: 0.6468 - val_accuracy: 0.5727
# Epoch 76/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6634 - accuracy: 0.5817 - val_loss: 0.6366 - val_accuracy: 0.5750
# Epoch 77/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6515 - accuracy: 0.5777 - val_loss: 0.6394 - val_accuracy: 0.5773
# Epoch 78/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6544 - accuracy: 0.5857 - val_loss: 0.6419 - val_accuracy: 0.5773
# Epoch 79/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6520 - accuracy: 0.5811 - val_loss: 0.6407 - val_accuracy: 0.5705
# Epoch 80/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6512 - accuracy: 0.5868 - val_loss: 0.6360 - val_accuracy: 0.5727
# Epoch 00080: early stopping

# %%
o_loss,o_accuracy = model.evaluate(cnn_x_train,cnn_y_train)
print("對訓練資料的：\nLoss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
n_loss,n_accuracy = model.evaluate(cnn_x_test,cnn_y_test)
print("對測試資料的：\nLoss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
# Out:
# 55/55 [==============================] - 0s 2ms/step - loss: 0.6454 - accuracy: 0.5851
# 對訓練資料的：
# Loss: 0.65, Accuracy: 0.59
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6372 - accuracy: 0.5727
# 對測試資料的：
# Loss: 0.64, Accuracy: 0.57

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(np.log(history.history['loss']), color = 'green', label='Loss')
plt.plot(np.log(history.history['val_loss']), color = 'blue', label='Val_Loss')
plt.legend()
plt.title('Training loss based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], color = 'green', label='accuracy')
plt.plot(history.history['val_accuracy'], color = 'blue', label='Val_accuracy')
plt.legend()
plt.title('Accuracy based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()

# %%
pre = model.predict_classes(cnn_x_test)
pre = pd.Series(pre)
# Out:
# WARNING:tensorflow:From <ipython-input-18-be91e944df7f>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_test = np.argmax(cnn_y_test, axis=1)
xcnn_y_test = pd.Series(cnn_y_test)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_test, pre)

t_size = len(cnn_y_test)
t_size1 = (cnn_y_test<1).sum()
t_guess = ((cnn_y_test<1).sum())/(len(cnn_y_test))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 239.00, FN: 8.00, FP: 180.00, TN: 13.00
# 對訓練集資料的：Loss: 0.65, Accuracy: 0.59
# 對測試集資料的：Loss: 0.64, Accuracy: 0.57
#
# 測試資料總共：440.00 筆, 其中漲的筆數為: 247.00, 全部猜漲猜對的機率是: 0.56
# 該測試集資料的：
# Accuracy: 0.57, Precision: 0.57, Recall: 0.97
# F1 score: 0.72

# %%
pre = model.predict_classes(cnn_x_validation)
pre = pd.Series(pre)
pre.hist()

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_validation = np.argmax(cnn_y_validation, axis=1)
xcnn_y_validation = pd.Series(cnn_y_validation)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_validation, pre)

t_size = len(cnn_y_validation)
t_size1 = (cnn_y_validation<1).sum()
t_guess = ((cnn_y_validation<1).sum())/(len(cnn_y_validation))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 160.00, FN: 0.00, FP: 76.00, TN: 0.00
# 對訓練集資料的：Loss: 0.65, Accuracy: 0.59
# 對測試集資料的：Loss: 0.64, Accuracy: 0.57
#
# 測試資料總共：236.00 筆, 其中漲的筆數為: 160.00, 全部猜漲猜對的機率是: 0.68
# 該測試集資料的：
# Accuracy: 0.68, Precision: 0.68, Recall: 1.00
# F1 score: 0.81
