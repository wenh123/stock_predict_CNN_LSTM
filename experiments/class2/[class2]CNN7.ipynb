# %%
import pandas as pd
import numpy as np
import datetime
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
data0 = pd.read_csv("data/1019_SP.csv").dropna()
data1 = pd.read_csv("data/1019_CL.csv").dropna()
data2 = pd.read_csv("data/1019_OVX.csv").dropna()
data3 = pd.read_csv("data/1019_GC.csv").dropna()
data4 = pd.read_csv("data/1019_GVZ.csv").dropna()
Date = data0.get("Date")
Date = pd.to_datetime(Date)
Close = data0.get("Close")
Close_cl = data1.get("Close")
Close_ovx = data2.get("Close")
Close_gc = data3.get("Close")
Close_gvz = data4.get("Close")
dict = {"Date": Date,
        "close": Close, 
        "close_cl": Close_cl, 
        "close_ovx": Close_ovx,
        "close_gc": Close_gc, 
        "close_gvz": Close_gvz,
       }
df = pd.DataFrame(dict)
df.set_index('Date', inplace=True)
df = df.dropna()
print("總共:%d個交易時間點" % (len(Date)))
print("去除空白值後剩下:%d個交易時間點" % (len(df)))
df.tail(10)
# Out:
# 總共:2493個交易時間點
# 去除空白值後剩下:2493個交易時間點
#                   close   close_cl  close_ovx     close_gc  close_gvz
# Date
# 2019-12-13  3168.800049  60.070000  26.760000  1475.599976      10.39
# 2019-12-16  3191.449951  60.209999  26.510000  1475.000000      10.39
# 2019-12-17  3192.520020  60.939999  26.330000  1474.599976      10.03
# 2019-12-18  3191.139893  60.930000  26.770000  1472.599976      10.04
# 2019-12-19  3205.370117  61.220001  24.799999  1478.199951      10.39
# 2019-12-20  3221.219971  60.439999  25.540001  1474.699951       9.69
# 2019-12-23  3224.010010  60.520000  25.110001  1482.500000      10.56
# 2019-12-26  3239.909912  61.680000  24.080000  1509.300049      13.33
# 2019-12-27  3240.020020  61.720001  25.160000  1513.800049      12.32
# 2019-12-30  3221.290039  61.680000  25.860001  1514.500000      12.56

# %%
dataset = pd.DataFrame({
    'Close':df['close'],
    'Close_CL':df['close_cl'],
    'Close_OVX':df['close_ovx'],
    'Close_GC':df['close_gc'],
    'Close_GVZ':df['close_gvz'],
    'return': df['close'],
})

feature_names = list(dataset.columns[:-1])

# %%
print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)
# Out:
# before dropping NaN (2493, 6)
# after dropping NaN (2493, 6)

# %%
from sklearn.preprocessing import MinMaxScaler

ss = MinMaxScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
#dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()
# Out:
#              Close     Close_CL  ...    Close_GVZ       return
# count  2493.000000  2493.000000  ...  2493.000000  2493.000000
# mean      0.422965     0.527754  ...     0.261824     0.422965
# std       0.265162     0.249914  ...     0.156178     0.265162
# min       0.000000     0.000000  ...     0.000000     0.000000
# 25%       0.161118     0.298108  ...     0.142903     0.161118
# 50%       0.434046     0.514706  ...     0.246540     0.434046
# 75%       0.636121     0.767556  ...     0.347602     0.636121
# max       1.000000     1.000000  ...     1.000000     1.000000
#
# [8 rows x 6 columns]

# %%
from keras.utils import np_utils
#每張圖包含幾天的資料
time_period = 20
#預設幾日後的漲跌
day = 10

cnn_x = []
cnn_y = []
indexs = []
dataset_scaled_x= dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-time_period-1-day)):
    cnn_x.append(dataset_scaled_x.iloc[i:i+time_period].values)
    r = dataset_scaled['return'].iloc[i+time_period-1+day]/dataset_scaled['return'].iloc[i+time_period-1]
    if r > 1:
        r = 0
    else:
        r = 1
    rr = np_utils.to_categorical(r, num_classes=2)
    cnn_y.append(rr)
    indexs.append(dataset_scaled.index[i+time_period-1])
    
cnn_x = np.array(cnn_x)
cnn_y = np.array(cnn_y)
indexes = np.array(indexs)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# HBox(children=(IntProgress(value=0, max=2462), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars

# %%
#2010~2018年為訓練和測試，2019年則為驗證
import datetime
cnn_x_t = cnn_x[indexes < datetime.datetime(2019,1,1)]
cnn_y_t = cnn_y[indexes < datetime.datetime(2019,1,1)]
cnn_x_validation = cnn_x[indexes > datetime.datetime(2019,1,1)]
cnn_y_validation = cnn_y[indexes > datetime.datetime(2019,1,1)]

# %%
from sklearn.model_selection import train_test_split
cnn_x_train, cnn_x_test, cnn_y_train, cnn_y_test = train_test_split(cnn_x_t, cnn_y_t, test_size=0.2)

# %%
cnn_x_train = np.stack((cnn_x_train,)*3,axis=-1)
cnn_x_test = np.stack((cnn_x_test,)*3,axis=-1)
cnn_x_validation = np.stack((cnn_x_validation,)*3,axis=-1)

# %%
fig = plt.figure(figsize = (15,15))
columns = rows = 5
for i in range(1,columns*rows+1):
  index = np.random.randint(len(cnn_x_train))
  img = cnn_x_train[index]
  fig.add_subplot(rows,columns,i)
  plt.axis("off")
  plt.title(str(index)+' class = '+str(np.argmax(cnn_y_train[index])))
  plt.subplots_adjust(wspace=0.2,hspace=0.2)
  plt.imshow(img)
plt.show()

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.initializers import he_normal

input_shape = cnn_x_train[0].shape

model = Sequential()
model.add(layers.Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same",
                        input_shape=input_shape))
model.add(layers.Conv2D(filters=64, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same"))
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Dropout(0.25))
model.add(layers.Flatten())
model.add(layers.Dense(units=128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=2, activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer="Adam", metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 20, 5, 32)         896
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 5, 64)         18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 2, 64)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 10, 2, 64)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               163968
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 183,618
# Trainable params: 183,618
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

history = model.fit(cnn_x_train, cnn_y_train,
                    batch_size=100,
                    epochs=250,
                    verbose=1,
                    validation_data=(cnn_x_test,cnn_y_test),
                    callbacks=[earlystop],
                    )
# Out:
# Epoch 1/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6718 - accuracy: 0.6163 - val_loss: 0.6466 - val_accuracy: 0.6502
# Epoch 2/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6641 - accuracy: 0.6258 - val_loss: 0.6470 - val_accuracy: 0.6502
# Epoch 3/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6596 - accuracy: 0.6258 - val_loss: 0.6521 - val_accuracy: 0.6502
# Epoch 4/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6578 - accuracy: 0.6258 - val_loss: 0.6486 - val_accuracy: 0.6502
# Epoch 5/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6566 - accuracy: 0.6258 - val_loss: 0.6456 - val_accuracy: 0.6502
# Epoch 6/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6537 - accuracy: 0.6253 - val_loss: 0.6375 - val_accuracy: 0.6502
# Epoch 7/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6518 - accuracy: 0.6264 - val_loss: 0.6437 - val_accuracy: 0.6570
# Epoch 8/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6468 - accuracy: 0.6292 - val_loss: 0.6359 - val_accuracy: 0.6592
# Epoch 9/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6447 - accuracy: 0.6354 - val_loss: 0.6324 - val_accuracy: 0.6614
# Epoch 10/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6406 - accuracy: 0.6404 - val_loss: 0.6310 - val_accuracy: 0.6883
# Epoch 11/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6336 - accuracy: 0.6399 - val_loss: 0.6311 - val_accuracy: 0.6704
# Epoch 12/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6287 - accuracy: 0.6522 - val_loss: 0.6167 - val_accuracy: 0.6726
# Epoch 13/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6292 - accuracy: 0.6416 - val_loss: 0.6120 - val_accuracy: 0.6816
# Epoch 14/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6250 - accuracy: 0.6584 - val_loss: 0.6129 - val_accuracy: 0.6726
# Epoch 15/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6164 - accuracy: 0.6607 - val_loss: 0.6134 - val_accuracy: 0.6973
# Epoch 16/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6148 - accuracy: 0.6567 - val_loss: 0.6018 - val_accuracy: 0.6951
# Epoch 17/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6059 - accuracy: 0.6652 - val_loss: 0.5988 - val_accuracy: 0.6704
# Epoch 18/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5972 - accuracy: 0.6674 - val_loss: 0.5831 - val_accuracy: 0.6883
# Epoch 19/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5905 - accuracy: 0.6742 - val_loss: 0.5676 - val_accuracy: 0.6928
# Epoch 20/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5916 - accuracy: 0.6663 - val_loss: 0.5992 - val_accuracy: 0.6547
# Epoch 21/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5870 - accuracy: 0.6685 - val_loss: 0.5774 - val_accuracy: 0.6951
# Epoch 22/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5832 - accuracy: 0.6865 - val_loss: 0.5585 - val_accuracy: 0.7152
# Epoch 23/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5728 - accuracy: 0.6888 - val_loss: 0.5762 - val_accuracy: 0.7018
# Epoch 24/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5690 - accuracy: 0.6815 - val_loss: 0.5532 - val_accuracy: 0.7175
# Epoch 25/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5589 - accuracy: 0.6972 - val_loss: 0.5532 - val_accuracy: 0.7197
# Epoch 26/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5519 - accuracy: 0.7006 - val_loss: 0.5504 - val_accuracy: 0.7399
# Epoch 27/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5411 - accuracy: 0.7163 - val_loss: 0.5305 - val_accuracy: 0.7735
# Epoch 28/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5394 - accuracy: 0.7270 - val_loss: 0.5323 - val_accuracy: 0.7578
# Epoch 29/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5426 - accuracy: 0.7247 - val_loss: 0.5310 - val_accuracy: 0.7780
# Epoch 30/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5325 - accuracy: 0.7388 - val_loss: 0.5305 - val_accuracy: 0.7534
# Epoch 31/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5308 - accuracy: 0.7315 - val_loss: 0.5258 - val_accuracy: 0.7713
# Epoch 32/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5208 - accuracy: 0.7382 - val_loss: 0.5115 - val_accuracy: 0.7758
# Epoch 33/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5143 - accuracy: 0.7343 - val_loss: 0.5095 - val_accuracy: 0.7713
# Epoch 34/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5014 - accuracy: 0.7478 - val_loss: 0.5089 - val_accuracy: 0.7735
# Epoch 35/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4906 - accuracy: 0.7612 - val_loss: 0.4995 - val_accuracy: 0.7848
# Epoch 36/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4996 - accuracy: 0.7579 - val_loss: 0.4956 - val_accuracy: 0.8004
# Epoch 37/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4983 - accuracy: 0.7624 - val_loss: 0.5004 - val_accuracy: 0.7915
# Epoch 38/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4866 - accuracy: 0.7573 - val_loss: 0.4941 - val_accuracy: 0.7892
# Epoch 39/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4803 - accuracy: 0.7685 - val_loss: 0.5104 - val_accuracy: 0.7444
# Epoch 40/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4745 - accuracy: 0.7708 - val_loss: 0.4982 - val_accuracy: 0.7982
# Epoch 41/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4670 - accuracy: 0.7843 - val_loss: 0.4762 - val_accuracy: 0.8139
# Epoch 42/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4665 - accuracy: 0.7848 - val_loss: 0.4922 - val_accuracy: 0.7848
# Epoch 43/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4569 - accuracy: 0.7843 - val_loss: 0.4821 - val_accuracy: 0.7848
# Epoch 44/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4623 - accuracy: 0.7826 - val_loss: 0.4743 - val_accuracy: 0.7870
# Epoch 45/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4559 - accuracy: 0.7860 - val_loss: 0.4855 - val_accuracy: 0.7780
# Epoch 46/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4491 - accuracy: 0.7820 - val_loss: 0.4968 - val_accuracy: 0.7892
# Epoch 47/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4469 - accuracy: 0.7910 - val_loss: 0.4640 - val_accuracy: 0.8161
# Epoch 48/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4323 - accuracy: 0.7916 - val_loss: 0.4575 - val_accuracy: 0.8094
# Epoch 49/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4302 - accuracy: 0.8067 - val_loss: 0.4574 - val_accuracy: 0.8229
# Epoch 50/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4345 - accuracy: 0.8000 - val_loss: 0.4830 - val_accuracy: 0.7982
# Epoch 51/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4309 - accuracy: 0.8028 - val_loss: 0.4569 - val_accuracy: 0.8049
# Epoch 52/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4162 - accuracy: 0.8169 - val_loss: 0.4644 - val_accuracy: 0.8161
# Epoch 53/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4142 - accuracy: 0.8096 - val_loss: 0.4554 - val_accuracy: 0.8341
# Epoch 54/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4173 - accuracy: 0.8124 - val_loss: 0.4404 - val_accuracy: 0.8184
# Epoch 55/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3969 - accuracy: 0.8202 - val_loss: 0.4521 - val_accuracy: 0.8251
# Epoch 56/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3931 - accuracy: 0.8225 - val_loss: 0.4519 - val_accuracy: 0.8318
# Epoch 57/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4122 - accuracy: 0.8112 - val_loss: 0.4587 - val_accuracy: 0.8117
# Epoch 58/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3981 - accuracy: 0.8152 - val_loss: 0.4540 - val_accuracy: 0.8318
# Epoch 59/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4046 - accuracy: 0.8073 - val_loss: 0.4456 - val_accuracy: 0.8318
# Epoch 60/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3974 - accuracy: 0.8163 - val_loss: 0.4298 - val_accuracy: 0.8520
# Epoch 61/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3869 - accuracy: 0.8230 - val_loss: 0.4350 - val_accuracy: 0.8632
# Epoch 62/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4029 - accuracy: 0.8219 - val_loss: 0.4592 - val_accuracy: 0.8229
# Epoch 63/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3900 - accuracy: 0.8169 - val_loss: 0.4361 - val_accuracy: 0.8520
# Epoch 64/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3804 - accuracy: 0.8326 - val_loss: 0.4384 - val_accuracy: 0.8498
# Epoch 65/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3646 - accuracy: 0.8348 - val_loss: 0.4500 - val_accuracy: 0.8430
# Epoch 66/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3627 - accuracy: 0.8433 - val_loss: 0.4414 - val_accuracy: 0.8430
# Epoch 67/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3655 - accuracy: 0.8315 - val_loss: 0.4475 - val_accuracy: 0.8655
# Epoch 68/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3534 - accuracy: 0.8421 - val_loss: 0.4484 - val_accuracy: 0.8565
# Epoch 69/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3631 - accuracy: 0.8382 - val_loss: 0.4883 - val_accuracy: 0.8408
# Epoch 70/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3741 - accuracy: 0.8152 - val_loss: 0.4566 - val_accuracy: 0.8408
# Epoch 00070: early stopping

# %%
o_loss,o_accuracy = model.evaluate(cnn_x_train,cnn_y_train)
print("對訓練資料的：\nLoss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
n_loss,n_accuracy = model.evaluate(cnn_x_test,cnn_y_test)
print("對測試資料的：\nLoss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
# Out:
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3163 - accuracy: 0.8635
# 對訓練資料的：
# Loss: 0.32, Accuracy: 0.86
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4720 - accuracy: 0.8408
# 對測試資料的：
# Loss: 0.47, Accuracy: 0.84

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(np.log(history.history['loss']), color = 'green', label='Loss')
plt.plot(np.log(history.history['val_loss']), color = 'blue', label='Val_Loss')
plt.legend()
plt.title('Training loss based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], color = 'green', label='accuracy')
plt.plot(history.history['val_accuracy'], color = 'blue', label='Val_accuracy')
plt.legend()
plt.title('Accuracy based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()

# %%
pre = model.predict_classes(cnn_x_test)
pre = pd.Series(pre)

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_test = np.argmax(cnn_y_test, axis=1)
xcnn_y_test = pd.Series(cnn_y_test)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_test, pre)

t_size = len(cnn_y_test)
t_size1 = (cnn_y_test<1).sum()
t_guess = ((cnn_y_test<1).sum())/(len(cnn_y_test))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 262.00, FN: 28.00, FP: 43.00, TN: 113.00
# 對訓練集資料的：Loss: 0.32, Accuracy: 0.86
# 對測試集資料的：Loss: 0.47, Accuracy: 0.84
#
# 測試資料總共：446.00 筆, 其中漲的筆數為: 290.00, 全部猜漲猜對的機率是: 0.65
# 該測試集資料的：
# Accuracy: 0.84, Precision: 0.86, Recall: 0.90
# F1 score: 0.88

# %%
pre = model.predict_classes(cnn_x_validation)
pre = pd.Series(pre)
pre.hist()

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_validation = np.argmax(cnn_y_validation, axis=1)
xcnn_y_validation = pd.Series(cnn_y_validation)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_validation, pre)

t_size = len(cnn_y_validation)
t_size1 = (cnn_y_validation<1).sum()
t_guess = ((cnn_y_validation<1).sum())/(len(cnn_y_validation))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 156.00, FN: 16.00, FP: 64.00, TN: 0.00
# 對訓練集資料的：Loss: 0.32, Accuracy: 0.86
# 對測試集資料的：Loss: 0.47, Accuracy: 0.84
#
# 測試資料總共：236.00 筆, 其中漲的筆數為: 172.00, 全部猜漲猜對的機率是: 0.73
# 該測試集資料的：
# Accuracy: 0.66, Precision: 0.71, Recall: 0.91
# F1 score: 0.80
