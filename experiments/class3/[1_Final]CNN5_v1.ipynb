# %%
import pandas as pd
import numpy as np
import datetime
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
data0 = pd.read_csv("data/1019_SP.csv").dropna()
data1 = pd.read_csv("data/1019_CL.csv").dropna()
data2 = pd.read_csv("data/1019_OVX.csv").dropna()
data3 = pd.read_csv("data/1019_GC.csv").dropna()
data4 = pd.read_csv("data/1019_GVZ.csv").dropna()
Date = data0.get("Date")
Date = pd.to_datetime(Date)
Close = data0.get("Close")
Close_cl = data1.get("Close")
Close_ovx = data2.get("Close")
Close_gc = data3.get("Close")
Close_gvz = data4.get("Close")
dict = {"Date": Date,
        "close": Close, 
        "close_cl": Close_cl, 
        "close_ovx": Close_ovx,
        "close_gc": Close_gc, 
        "close_gvz": Close_gvz,
       }
df = pd.DataFrame(dict)
df.set_index('Date', inplace=True)
df = df.dropna()
print("總共:%d個交易時間點" % (len(Date)))
print("去除空白值後剩下:%d個交易時間點" % (len(df)))
df.tail(10)
# Out:
# 總共:2493個交易時間點
# 去除空白值後剩下:2493個交易時間點
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                   close   close_cl  close_ovx     close_gc  close_gvz
# Date
# 2019-12-13  3168.800049  60.070000  26.760000  1475.599976      10.39
# 2019-12-16  3191.449951  60.209999  26.510000  1475.000000      10.39
# 2019-12-17  3192.520020  60.939999  26.330000  1474.599976      10.03
# 2019-12-18  3191.139893  60.930000  26.770000  1472.599976      10.04
# 2019-12-19  3205.370117  61.220001  24.799999  1478.199951      10.39
# 2019-12-20  3221.219971  60.439999  25.540001  1474.699951       9.69
# 2019-12-23  3224.010010  60.520000  25.110001  1482.500000      10.56
# 2019-12-26  3239.909912  61.680000  24.080000  1509.300049      13.33
# 2019-12-27  3240.020020  61.720001  25.160000  1513.800049      12.32
# 2019-12-30  3221.290039  61.680000  25.860001  1514.500000      12.56

# %%
dataset = pd.DataFrame({
    'Close':df['close'],
    'Close_CL':df['close_cl'],
    'Close_OVX':df['close_ovx'],
    #'Close_GC':df['close_gc'],
    #'Close_GVZ':df['close_gvz'],
    'return': df['close'],
})

feature_names = list(dataset.columns[:-1])

# %%
print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)
# Out:
# before dropping NaN (2493, 4)
# after dropping NaN (2493, 4)

# %%
from sklearn.preprocessing import MinMaxScaler

ss = MinMaxScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
#dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()
# Out:
#              Close     Close_CL    Close_OVX       return
# count  2493.000000  2493.000000  2493.000000  2493.000000
# mean      0.422965     0.527754     0.290049     0.422965
# std       0.265162     0.249914     0.156572     0.265162
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.161118     0.298108     0.187839     0.161118
# 50%       0.434046     0.514706     0.269117     0.434046
# 75%       0.636121     0.767556     0.375989     0.636121
# max       1.000000     1.000000     1.000000     1.000000

# %%
from keras.utils import np_utils
#每張圖包含幾天的資料
time_period = 20
#預設幾日後的漲跌
day = 10

cnn_x = []
cnn_y = []
indexs = []
dataset_scaled_x= dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-time_period-1-day)):
    cnn_x.append(dataset_scaled_x.iloc[i:i+time_period].values)
    r = dataset_scaled['return'].iloc[i+time_period-1+day]/dataset_scaled['return'].iloc[i+time_period-1]
    if r > 1:
        r = 0
    else:
        r = 1
    rr = np_utils.to_categorical(r, num_classes=2)
    cnn_y.append(rr)
    indexs.append(dataset_scaled.index[i+time_period-1])
    
cnn_x = np.array(cnn_x)
cnn_y = np.array(cnn_y)
indexes = np.array(indexs)
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# HBox(children=(IntProgress(value=0, max=2462), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars

# %%
#2010~2018年為訓練和測試，2019年則為驗證
import datetime
cnn_x_t = cnn_x[indexes < datetime.datetime(2019,1,1)]
cnn_y_t = cnn_y[indexes < datetime.datetime(2019,1,1)]
cnn_x_validation = cnn_x[indexes > datetime.datetime(2019,1,1)]
cnn_y_validation = cnn_y[indexes > datetime.datetime(2019,1,1)]

# %%
from sklearn.model_selection import train_test_split
cnn_x_train, cnn_x_test, cnn_y_train, cnn_y_test = train_test_split(cnn_x_t, cnn_y_t, 
                                                                    test_size=0.2,
                                                                    random_state =7,
                                                                    stratify=cnn_y_t,
                                                                    shuffle = True)

# %%
cnn_x_train = np.stack((cnn_x_train,)*3,axis=-1)
cnn_x_test = np.stack((cnn_x_test,)*3,axis=-1)
cnn_x_validation = np.stack((cnn_x_validation,)*3,axis=-1)

# %%
fig = plt.figure(figsize = (15,15))
columns = rows = 5
for i in range(1,columns*rows+1):
  index = np.random.randint(len(cnn_x_train))
  img = cnn_x_train[index]
  fig.add_subplot(rows,columns,i)
  plt.axis("off")
  plt.title(str(index)+' class = '+str(np.argmax(cnn_y_train[index])))
  plt.subplots_adjust(wspace=0.2,hspace=0.2)
  plt.imshow(img)
plt.show()

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.initializers import he_normal

input_shape = cnn_x_train[0].shape

model = Sequential()
model.add(layers.Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same",
                        input_shape=input_shape))
model.add(layers.Conv2D(filters=64, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same"))
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Dropout(0.25))
model.add(layers.Flatten())
model.add(layers.Dense(units=128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=2, activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer="Adam", metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 20, 3, 32)         896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 3, 64)         18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 1, 64)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 1, 64)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 640)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               82048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 101,698
# Trainable params: 101,698
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

history = model.fit(cnn_x_train, cnn_y_train,
                    batch_size=100,
                    epochs=250,
                    verbose=1,
                    validation_data=(cnn_x_test,cnn_y_test),
                    callbacks=[earlystop],
                    )
# Out:
# Epoch 1/250
# 18/18 [==============================] - 0s 18ms/step - loss: 0.6734 - accuracy: 0.6230 - val_loss: 0.6566 - val_accuracy: 0.6300
# Epoch 2/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6620 - accuracy: 0.6309 - val_loss: 0.6510 - val_accuracy: 0.6300
# Epoch 3/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6672 - accuracy: 0.6309 - val_loss: 0.6607 - val_accuracy: 0.6300
# Epoch 4/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6620 - accuracy: 0.6309 - val_loss: 0.6503 - val_accuracy: 0.6300
# Epoch 5/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6573 - accuracy: 0.6309 - val_loss: 0.6484 - val_accuracy: 0.6300
# Epoch 6/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6603 - accuracy: 0.6309 - val_loss: 0.6541 - val_accuracy: 0.6300
# Epoch 7/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6566 - accuracy: 0.6309 - val_loss: 0.6459 - val_accuracy: 0.6300
# Epoch 8/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6558 - accuracy: 0.6309 - val_loss: 0.6452 - val_accuracy: 0.6300
# Epoch 9/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6544 - accuracy: 0.6309 - val_loss: 0.6438 - val_accuracy: 0.6300
# Epoch 10/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6508 - accuracy: 0.6315 - val_loss: 0.6398 - val_accuracy: 0.6300
# Epoch 11/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6513 - accuracy: 0.6315 - val_loss: 0.6396 - val_accuracy: 0.6300
# Epoch 12/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6508 - accuracy: 0.6315 - val_loss: 0.6440 - val_accuracy: 0.6300
# Epoch 13/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6494 - accuracy: 0.6303 - val_loss: 0.6366 - val_accuracy: 0.6300
# Epoch 14/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6499 - accuracy: 0.6326 - val_loss: 0.6342 - val_accuracy: 0.6413
# Epoch 15/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6463 - accuracy: 0.6354 - val_loss: 0.6360 - val_accuracy: 0.6323
# Epoch 16/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6456 - accuracy: 0.6354 - val_loss: 0.6333 - val_accuracy: 0.6435
# Epoch 17/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6417 - accuracy: 0.6287 - val_loss: 0.6300 - val_accuracy: 0.6390
# Epoch 18/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6427 - accuracy: 0.6360 - val_loss: 0.6298 - val_accuracy: 0.6435
# Epoch 19/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6390 - accuracy: 0.6410 - val_loss: 0.6268 - val_accuracy: 0.6413
# Epoch 20/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6361 - accuracy: 0.6433 - val_loss: 0.6240 - val_accuracy: 0.6502
# Epoch 21/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6373 - accuracy: 0.6388 - val_loss: 0.6214 - val_accuracy: 0.6547
# Epoch 22/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6397 - accuracy: 0.6466 - val_loss: 0.6210 - val_accuracy: 0.6368
# Epoch 23/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6374 - accuracy: 0.6427 - val_loss: 0.6212 - val_accuracy: 0.6368
# Epoch 24/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6420 - accuracy: 0.6399 - val_loss: 0.6263 - val_accuracy: 0.6413
# Epoch 25/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6390 - accuracy: 0.6410 - val_loss: 0.6232 - val_accuracy: 0.6390
# Epoch 26/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6358 - accuracy: 0.6455 - val_loss: 0.6214 - val_accuracy: 0.6323
# Epoch 27/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6309 - accuracy: 0.6455 - val_loss: 0.6194 - val_accuracy: 0.6614
# Epoch 28/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6312 - accuracy: 0.6433 - val_loss: 0.6111 - val_accuracy: 0.6525
# Epoch 29/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6271 - accuracy: 0.6601 - val_loss: 0.6101 - val_accuracy: 0.6457
# Epoch 30/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6320 - accuracy: 0.6438 - val_loss: 0.6098 - val_accuracy: 0.6614
# Epoch 31/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6232 - accuracy: 0.6517 - val_loss: 0.6111 - val_accuracy: 0.6525
# Epoch 32/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6200 - accuracy: 0.6539 - val_loss: 0.6095 - val_accuracy: 0.6547
# Epoch 33/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6292 - accuracy: 0.6483 - val_loss: 0.6131 - val_accuracy: 0.6570
# Epoch 34/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6238 - accuracy: 0.6607 - val_loss: 0.6010 - val_accuracy: 0.6659
# Epoch 35/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6218 - accuracy: 0.6522 - val_loss: 0.5988 - val_accuracy: 0.6861
# Epoch 36/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6173 - accuracy: 0.6562 - val_loss: 0.6094 - val_accuracy: 0.6637
# Epoch 37/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6167 - accuracy: 0.6567 - val_loss: 0.6052 - val_accuracy: 0.6480
# Epoch 38/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6153 - accuracy: 0.6657 - val_loss: 0.6085 - val_accuracy: 0.6614
# Epoch 39/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6135 - accuracy: 0.6646 - val_loss: 0.5958 - val_accuracy: 0.6682
# Epoch 40/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6147 - accuracy: 0.6674 - val_loss: 0.5926 - val_accuracy: 0.6682
# Epoch 41/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6121 - accuracy: 0.6652 - val_loss: 0.5913 - val_accuracy: 0.6726
# Epoch 42/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6032 - accuracy: 0.6719 - val_loss: 0.5849 - val_accuracy: 0.6749
# Epoch 43/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6120 - accuracy: 0.6652 - val_loss: 0.5944 - val_accuracy: 0.6592
# Epoch 44/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6101 - accuracy: 0.6680 - val_loss: 0.5853 - val_accuracy: 0.6928
# Epoch 45/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6125 - accuracy: 0.6820 - val_loss: 0.5872 - val_accuracy: 0.6726
# Epoch 46/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6061 - accuracy: 0.6787 - val_loss: 0.5889 - val_accuracy: 0.6771
# Epoch 47/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6038 - accuracy: 0.6803 - val_loss: 0.5875 - val_accuracy: 0.6816
# Epoch 48/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5998 - accuracy: 0.6871 - val_loss: 0.5814 - val_accuracy: 0.7040
# Epoch 49/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5985 - accuracy: 0.6865 - val_loss: 0.5749 - val_accuracy: 0.7108
# Epoch 50/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5941 - accuracy: 0.6792 - val_loss: 0.5783 - val_accuracy: 0.6973
# Epoch 51/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5987 - accuracy: 0.6831 - val_loss: 0.5805 - val_accuracy: 0.6951
# Epoch 52/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5999 - accuracy: 0.6753 - val_loss: 0.5805 - val_accuracy: 0.7152
# Epoch 53/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5934 - accuracy: 0.6882 - val_loss: 0.5669 - val_accuracy: 0.7152
# Epoch 54/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5849 - accuracy: 0.6933 - val_loss: 0.5675 - val_accuracy: 0.7063
# Epoch 55/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5896 - accuracy: 0.6848 - val_loss: 0.5668 - val_accuracy: 0.7040
# Epoch 56/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5847 - accuracy: 0.6944 - val_loss: 0.5671 - val_accuracy: 0.7063
# Epoch 57/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5825 - accuracy: 0.6944 - val_loss: 0.5701 - val_accuracy: 0.7197
# Epoch 58/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5800 - accuracy: 0.6882 - val_loss: 0.5691 - val_accuracy: 0.7108
# Epoch 59/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5862 - accuracy: 0.6871 - val_loss: 0.5631 - val_accuracy: 0.7175
# Epoch 60/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5770 - accuracy: 0.6966 - val_loss: 0.5579 - val_accuracy: 0.7220
# Epoch 61/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5680 - accuracy: 0.7124 - val_loss: 0.5579 - val_accuracy: 0.7197
# Epoch 62/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5801 - accuracy: 0.6882 - val_loss: 0.5686 - val_accuracy: 0.7152
# Epoch 63/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5714 - accuracy: 0.7017 - val_loss: 0.5591 - val_accuracy: 0.7242
# Epoch 64/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5672 - accuracy: 0.7101 - val_loss: 0.5534 - val_accuracy: 0.7309
# Epoch 65/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5687 - accuracy: 0.7129 - val_loss: 0.5528 - val_accuracy: 0.7220
# Epoch 66/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5680 - accuracy: 0.6989 - val_loss: 0.5575 - val_accuracy: 0.7152
# Epoch 67/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5739 - accuracy: 0.6972 - val_loss: 0.5498 - val_accuracy: 0.7287
# Epoch 68/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5573 - accuracy: 0.7090 - val_loss: 0.5417 - val_accuracy: 0.7332
# Epoch 69/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5589 - accuracy: 0.7163 - val_loss: 0.5498 - val_accuracy: 0.7063
# Epoch 70/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5643 - accuracy: 0.7090 - val_loss: 0.5481 - val_accuracy: 0.7152
# Epoch 71/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5696 - accuracy: 0.6961 - val_loss: 0.5537 - val_accuracy: 0.6996
# Epoch 72/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5556 - accuracy: 0.7140 - val_loss: 0.5412 - val_accuracy: 0.7354
# Epoch 73/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5475 - accuracy: 0.7146 - val_loss: 0.5522 - val_accuracy: 0.7309
# Epoch 74/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5590 - accuracy: 0.7051 - val_loss: 0.5495 - val_accuracy: 0.7175
# Epoch 75/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5448 - accuracy: 0.7180 - val_loss: 0.5400 - val_accuracy: 0.7242
# Epoch 76/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5422 - accuracy: 0.7225 - val_loss: 0.5383 - val_accuracy: 0.7220
# Epoch 77/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5491 - accuracy: 0.7084 - val_loss: 0.5353 - val_accuracy: 0.7309
# Epoch 78/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5546 - accuracy: 0.7045 - val_loss: 0.5310 - val_accuracy: 0.7377
# Epoch 79/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5414 - accuracy: 0.7292 - val_loss: 0.5261 - val_accuracy: 0.7377
# Epoch 80/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5414 - accuracy: 0.7270 - val_loss: 0.5297 - val_accuracy: 0.7377
# Epoch 81/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5399 - accuracy: 0.7303 - val_loss: 0.5402 - val_accuracy: 0.7130
# Epoch 82/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5433 - accuracy: 0.7253 - val_loss: 0.5273 - val_accuracy: 0.7332
# Epoch 83/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5257 - accuracy: 0.7410 - val_loss: 0.5158 - val_accuracy: 0.7578
# Epoch 84/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5347 - accuracy: 0.7208 - val_loss: 0.5186 - val_accuracy: 0.7309
# Epoch 85/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5256 - accuracy: 0.7264 - val_loss: 0.5201 - val_accuracy: 0.7578
# Epoch 86/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5300 - accuracy: 0.7343 - val_loss: 0.5314 - val_accuracy: 0.7422
# Epoch 87/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5368 - accuracy: 0.7264 - val_loss: 0.5156 - val_accuracy: 0.7578
# Epoch 88/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5153 - accuracy: 0.7461 - val_loss: 0.5135 - val_accuracy: 0.7354
# Epoch 89/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5204 - accuracy: 0.7444 - val_loss: 0.5211 - val_accuracy: 0.7601
# Epoch 90/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5219 - accuracy: 0.7421 - val_loss: 0.5057 - val_accuracy: 0.7399
# Epoch 91/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5226 - accuracy: 0.7393 - val_loss: 0.5175 - val_accuracy: 0.7534
# Epoch 92/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5201 - accuracy: 0.7388 - val_loss: 0.5180 - val_accuracy: 0.7623
# Epoch 93/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5154 - accuracy: 0.7393 - val_loss: 0.5137 - val_accuracy: 0.7780
# Epoch 94/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5060 - accuracy: 0.7376 - val_loss: 0.5005 - val_accuracy: 0.7556
# Epoch 95/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5141 - accuracy: 0.7466 - val_loss: 0.4986 - val_accuracy: 0.7601
# Epoch 96/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5070 - accuracy: 0.7511 - val_loss: 0.5050 - val_accuracy: 0.7466
# Epoch 97/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5086 - accuracy: 0.7511 - val_loss: 0.5119 - val_accuracy: 0.7556
# Epoch 98/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5095 - accuracy: 0.7500 - val_loss: 0.5095 - val_accuracy: 0.7534
# Epoch 99/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5123 - accuracy: 0.7489 - val_loss: 0.4951 - val_accuracy: 0.7578
# Epoch 100/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4947 - accuracy: 0.7618 - val_loss: 0.4996 - val_accuracy: 0.7668
# Epoch 101/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4938 - accuracy: 0.7652 - val_loss: 0.5016 - val_accuracy: 0.7466
# Epoch 102/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5100 - accuracy: 0.7483 - val_loss: 0.5036 - val_accuracy: 0.7511
# Epoch 103/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4905 - accuracy: 0.7719 - val_loss: 0.5006 - val_accuracy: 0.7780
# Epoch 104/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5027 - accuracy: 0.7584 - val_loss: 0.4891 - val_accuracy: 0.7825
# Epoch 105/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4903 - accuracy: 0.7652 - val_loss: 0.4935 - val_accuracy: 0.7735
# Epoch 106/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4932 - accuracy: 0.7483 - val_loss: 0.4860 - val_accuracy: 0.7668
# Epoch 107/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4896 - accuracy: 0.7455 - val_loss: 0.5066 - val_accuracy: 0.7691
# Epoch 108/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5056 - accuracy: 0.7466 - val_loss: 0.4989 - val_accuracy: 0.7758
# Epoch 109/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5005 - accuracy: 0.7528 - val_loss: 0.4872 - val_accuracy: 0.7623
# Epoch 110/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4813 - accuracy: 0.7697 - val_loss: 0.4883 - val_accuracy: 0.7601
# Epoch 111/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4656 - accuracy: 0.7815 - val_loss: 0.4809 - val_accuracy: 0.7870
# Epoch 112/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4753 - accuracy: 0.7685 - val_loss: 0.4831 - val_accuracy: 0.7848
# Epoch 113/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4787 - accuracy: 0.7697 - val_loss: 0.4855 - val_accuracy: 0.7601
# Epoch 114/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4758 - accuracy: 0.7725 - val_loss: 0.4767 - val_accuracy: 0.7691
# Epoch 115/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4656 - accuracy: 0.7730 - val_loss: 0.4760 - val_accuracy: 0.7892
# Epoch 116/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4639 - accuracy: 0.7730 - val_loss: 0.4831 - val_accuracy: 0.7646
# Epoch 117/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4745 - accuracy: 0.7787 - val_loss: 0.4824 - val_accuracy: 0.7668
# Epoch 118/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4675 - accuracy: 0.7787 - val_loss: 0.4764 - val_accuracy: 0.7713
# Epoch 119/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4610 - accuracy: 0.7725 - val_loss: 0.4747 - val_accuracy: 0.7646
# Epoch 120/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4655 - accuracy: 0.7730 - val_loss: 0.4715 - val_accuracy: 0.7758
# Epoch 121/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4640 - accuracy: 0.7680 - val_loss: 0.4759 - val_accuracy: 0.7780
# Epoch 122/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4572 - accuracy: 0.7770 - val_loss: 0.4725 - val_accuracy: 0.7623
# Epoch 123/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4669 - accuracy: 0.7674 - val_loss: 0.4704 - val_accuracy: 0.7735
# Epoch 124/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4490 - accuracy: 0.7899 - val_loss: 0.4744 - val_accuracy: 0.7713
# Epoch 125/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4505 - accuracy: 0.7742 - val_loss: 0.4760 - val_accuracy: 0.7825
# Epoch 126/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4580 - accuracy: 0.7837 - val_loss: 0.4753 - val_accuracy: 0.7511
# Epoch 127/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4572 - accuracy: 0.7882 - val_loss: 0.4675 - val_accuracy: 0.7691
# Epoch 128/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4493 - accuracy: 0.7854 - val_loss: 0.4594 - val_accuracy: 0.7848
# Epoch 129/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4478 - accuracy: 0.7955 - val_loss: 0.4670 - val_accuracy: 0.7780
# Epoch 130/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4426 - accuracy: 0.7910 - val_loss: 0.4541 - val_accuracy: 0.7758
# Epoch 131/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4471 - accuracy: 0.7921 - val_loss: 0.4676 - val_accuracy: 0.7758
# Epoch 132/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4604 - accuracy: 0.7781 - val_loss: 0.4681 - val_accuracy: 0.7601
# Epoch 133/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4561 - accuracy: 0.7826 - val_loss: 0.4556 - val_accuracy: 0.7892
# Epoch 134/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4455 - accuracy: 0.7893 - val_loss: 0.4588 - val_accuracy: 0.7713
# Epoch 135/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4501 - accuracy: 0.7831 - val_loss: 0.4605 - val_accuracy: 0.7646
# Epoch 136/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4476 - accuracy: 0.7899 - val_loss: 0.4474 - val_accuracy: 0.7960
# Epoch 137/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4287 - accuracy: 0.8090 - val_loss: 0.4554 - val_accuracy: 0.7780
# Epoch 138/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4350 - accuracy: 0.7949 - val_loss: 0.4606 - val_accuracy: 0.7758
# Epoch 139/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4317 - accuracy: 0.7989 - val_loss: 0.4609 - val_accuracy: 0.7735
# Epoch 140/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4252 - accuracy: 0.8006 - val_loss: 0.4524 - val_accuracy: 0.7848
# Epoch 141/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4289 - accuracy: 0.7927 - val_loss: 0.4557 - val_accuracy: 0.7848
# Epoch 142/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4255 - accuracy: 0.8129 - val_loss: 0.4512 - val_accuracy: 0.7825
# Epoch 143/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4429 - accuracy: 0.7921 - val_loss: 0.4447 - val_accuracy: 0.7915
# Epoch 144/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4274 - accuracy: 0.8034 - val_loss: 0.4499 - val_accuracy: 0.8139
# Epoch 145/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4219 - accuracy: 0.8090 - val_loss: 0.4537 - val_accuracy: 0.7892
# Epoch 146/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4277 - accuracy: 0.7972 - val_loss: 0.4490 - val_accuracy: 0.7825
# Epoch 147/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4140 - accuracy: 0.8062 - val_loss: 0.4415 - val_accuracy: 0.7848
# Epoch 148/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4164 - accuracy: 0.8084 - val_loss: 0.4444 - val_accuracy: 0.7937
# Epoch 149/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4164 - accuracy: 0.8163 - val_loss: 0.4373 - val_accuracy: 0.7892
# Epoch 150/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4259 - accuracy: 0.8107 - val_loss: 0.4542 - val_accuracy: 0.7937
# Epoch 151/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4162 - accuracy: 0.8124 - val_loss: 0.4682 - val_accuracy: 0.7803
# Epoch 152/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4213 - accuracy: 0.8090 - val_loss: 0.4451 - val_accuracy: 0.7892
# Epoch 153/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4236 - accuracy: 0.8028 - val_loss: 0.4455 - val_accuracy: 0.7892
# Epoch 154/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4124 - accuracy: 0.8101 - val_loss: 0.4557 - val_accuracy: 0.7780
# Epoch 155/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4140 - accuracy: 0.8051 - val_loss: 0.4471 - val_accuracy: 0.7803
# Epoch 156/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4057 - accuracy: 0.8169 - val_loss: 0.4267 - val_accuracy: 0.7848
# Epoch 157/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4080 - accuracy: 0.8096 - val_loss: 0.4326 - val_accuracy: 0.8206
# Epoch 158/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4084 - accuracy: 0.8124 - val_loss: 0.4471 - val_accuracy: 0.8049
# Epoch 159/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4363 - accuracy: 0.7904 - val_loss: 0.4214 - val_accuracy: 0.7937
# Epoch 160/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4139 - accuracy: 0.8140 - val_loss: 0.4384 - val_accuracy: 0.7960
# Epoch 161/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4090 - accuracy: 0.7983 - val_loss: 0.4243 - val_accuracy: 0.8072
# Epoch 162/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3966 - accuracy: 0.8180 - val_loss: 0.4268 - val_accuracy: 0.8049
# Epoch 163/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4025 - accuracy: 0.8180 - val_loss: 0.4254 - val_accuracy: 0.8139
# Epoch 164/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4027 - accuracy: 0.8180 - val_loss: 0.4480 - val_accuracy: 0.7848
# Epoch 165/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3939 - accuracy: 0.8202 - val_loss: 0.4344 - val_accuracy: 0.8049
# Epoch 166/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4113 - accuracy: 0.8140 - val_loss: 0.4346 - val_accuracy: 0.8027
# Epoch 167/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4125 - accuracy: 0.8101 - val_loss: 0.4328 - val_accuracy: 0.8004
# Epoch 168/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3996 - accuracy: 0.8140 - val_loss: 0.4427 - val_accuracy: 0.8004
# Epoch 169/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3957 - accuracy: 0.8146 - val_loss: 0.4211 - val_accuracy: 0.8161
# Epoch 170/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3831 - accuracy: 0.8202 - val_loss: 0.4118 - val_accuracy: 0.8251
# Epoch 171/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3901 - accuracy: 0.8213 - val_loss: 0.4265 - val_accuracy: 0.8229
# Epoch 172/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3880 - accuracy: 0.8258 - val_loss: 0.4242 - val_accuracy: 0.8229
# Epoch 173/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3771 - accuracy: 0.8298 - val_loss: 0.4135 - val_accuracy: 0.8251
# Epoch 174/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3849 - accuracy: 0.8292 - val_loss: 0.4103 - val_accuracy: 0.8363
# Epoch 175/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3806 - accuracy: 0.8337 - val_loss: 0.4304 - val_accuracy: 0.8049
# Epoch 176/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3751 - accuracy: 0.8388 - val_loss: 0.4203 - val_accuracy: 0.8274
# Epoch 177/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3834 - accuracy: 0.8326 - val_loss: 0.4374 - val_accuracy: 0.8161
# Epoch 178/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3770 - accuracy: 0.8264 - val_loss: 0.4361 - val_accuracy: 0.8049
# Epoch 179/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3894 - accuracy: 0.8146 - val_loss: 0.4206 - val_accuracy: 0.8206
# Epoch 180/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3732 - accuracy: 0.8320 - val_loss: 0.4124 - val_accuracy: 0.8117
# Epoch 181/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3708 - accuracy: 0.8354 - val_loss: 0.4192 - val_accuracy: 0.8072
# Epoch 182/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3830 - accuracy: 0.8270 - val_loss: 0.4336 - val_accuracy: 0.8072
# Epoch 183/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3613 - accuracy: 0.8388 - val_loss: 0.4129 - val_accuracy: 0.8094
# Epoch 184/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3762 - accuracy: 0.8399 - val_loss: 0.4104 - val_accuracy: 0.8274
# Epoch 00184: early stopping

# %%
o_loss,o_accuracy = model.evaluate(cnn_x_train,cnn_y_train)
print("對訓練資料的：\nLoss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
n_loss,n_accuracy = model.evaluate(cnn_x_test,cnn_y_test)
print("對測試資料的：\nLoss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
# Out:
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3042 - accuracy: 0.8860
# 對訓練資料的：
# Loss: 0.30, Accuracy: 0.89
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4219 - accuracy: 0.8274
# 對測試資料的：
# Loss: 0.42, Accuracy: 0.83

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(np.log(history.history['loss']), color = 'green', label='Loss')
plt.plot(np.log(history.history['val_loss']), color = 'blue', label='Val_Loss')
plt.legend()
plt.title('Training loss based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], color = 'green', label='accuracy')
plt.plot(history.history['val_accuracy'], color = 'blue', label='Val_accuracy')
plt.legend()
plt.title('Accuracy based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()

# %%
pre = model.predict_classes(cnn_x_test)
pre = pd.Series(pre)
# Out:
# WARNING:tensorflow:From <ipython-input-15-be91e944df7f>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_test = np.argmax(cnn_y_test, axis=1)
xcnn_y_test = pd.Series(cnn_y_test)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_test, pre)

t_size = len(cnn_y_test)
t_size1 = (cnn_y_test<1).sum()
t_guess = ((cnn_y_test<1).sum())/(len(cnn_y_test))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 257.00, FN: 24.00, FP: 53.00, TN: 112.00
# 對訓練集資料的：Loss: 0.30, Accuracy: 0.89
# 對測試集資料的：Loss: 0.42, Accuracy: 0.83
#
# 測試資料總共：446.00 筆, 其中漲的筆數為: 281.00, 全部猜漲猜對的機率是: 0.63
# 該測試集資料的：
# Accuracy: 0.83, Precision: 0.83, Recall: 0.91
# F1 score: 0.87

# %%
pre = model.predict_classes(cnn_x_validation)
pre = pd.Series(pre)
pre.hist()

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_validation = np.argmax(cnn_y_validation, axis=1)
xcnn_y_validation = pd.Series(cnn_y_validation)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_validation, pre)

t_size = len(cnn_y_validation)
t_size1 = (cnn_y_validation<1).sum()
t_guess = ((cnn_y_validation<1).sum())/(len(cnn_y_validation))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 132.00, FN: 40.00, FP: 47.00, TN: 17.00
# 對訓練集資料的：Loss: 0.30, Accuracy: 0.89
# 對測試集資料的：Loss: 0.42, Accuracy: 0.83
#
# 測試資料總共：236.00 筆, 其中漲的筆數為: 172.00, 全部猜漲猜對的機率是: 0.73
# 該測試集資料的：
# Accuracy: 0.63, Precision: 0.74, Recall: 0.77
# F1 score: 0.75
