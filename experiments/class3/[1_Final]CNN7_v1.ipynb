# %%
import pandas as pd
import numpy as np
import datetime
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
data0 = pd.read_csv("data/1019_SP.csv").dropna()
data1 = pd.read_csv("data/1019_CL.csv").dropna()
data2 = pd.read_csv("data/1019_OVX.csv").dropna()
data3 = pd.read_csv("data/1019_GC.csv").dropna()
data4 = pd.read_csv("data/1019_GVZ.csv").dropna()
Date = data0.get("Date")
Date = pd.to_datetime(Date)
Close = data0.get("Close")
Close_cl = data1.get("Close")
Close_ovx = data2.get("Close")
Close_gc = data3.get("Close")
Close_gvz = data4.get("Close")
dict = {"Date": Date,
        "close": Close, 
        "close_cl": Close_cl, 
        "close_ovx": Close_ovx,
        "close_gc": Close_gc, 
        "close_gvz": Close_gvz,
       }
df = pd.DataFrame(dict)
df.set_index('Date', inplace=True)
df = df.dropna()
print("總共:%d個交易時間點" % (len(Date)))
print("去除空白值後剩下:%d個交易時間點" % (len(df)))
df.tail(10)
# Out:
# 總共:2493個交易時間點
# 去除空白值後剩下:2493個交易時間點
#                   close   close_cl  close_ovx     close_gc  close_gvz
# Date
# 2019-12-13  3168.800049  60.070000  26.760000  1475.599976      10.39
# 2019-12-16  3191.449951  60.209999  26.510000  1475.000000      10.39
# 2019-12-17  3192.520020  60.939999  26.330000  1474.599976      10.03
# 2019-12-18  3191.139893  60.930000  26.770000  1472.599976      10.04
# 2019-12-19  3205.370117  61.220001  24.799999  1478.199951      10.39
# 2019-12-20  3221.219971  60.439999  25.540001  1474.699951       9.69
# 2019-12-23  3224.010010  60.520000  25.110001  1482.500000      10.56
# 2019-12-26  3239.909912  61.680000  24.080000  1509.300049      13.33
# 2019-12-27  3240.020020  61.720001  25.160000  1513.800049      12.32
# 2019-12-30  3221.290039  61.680000  25.860001  1514.500000      12.56

# %%
dataset = pd.DataFrame({
    'Close':df['close'],
    'Close_CL':df['close_cl'],
    'Close_OVX':df['close_ovx'],
    'Close_GC':df['close_gc'],
    'Close_GVZ':df['close_gvz'],
    'return': df['close'],
})

feature_names = list(dataset.columns[:-1])

# %%
print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)
# Out:
# before dropping NaN (2493, 6)
# after dropping NaN (2493, 6)

# %%
from sklearn.preprocessing import MinMaxScaler

ss = MinMaxScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
#dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()
# Out:
#              Close     Close_CL  ...    Close_GVZ       return
# count  2493.000000  2493.000000  ...  2493.000000  2493.000000
# mean      0.422965     0.527754  ...     0.261824     0.422965
# std       0.265162     0.249914  ...     0.156178     0.265162
# min       0.000000     0.000000  ...     0.000000     0.000000
# 25%       0.161118     0.298108  ...     0.142903     0.161118
# 50%       0.434046     0.514706  ...     0.246540     0.434046
# 75%       0.636121     0.767556  ...     0.347602     0.636121
# max       1.000000     1.000000  ...     1.000000     1.000000
#
# [8 rows x 6 columns]

# %%
from keras.utils import np_utils
#每張圖包含幾天的資料
time_period = 20
#預設幾日後的漲跌
day = 10

cnn_x = []
cnn_y = []
indexs = []
dataset_scaled_x= dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-time_period-1-day)):
    cnn_x.append(dataset_scaled_x.iloc[i:i+time_period].values)
    r = dataset_scaled['return'].iloc[i+time_period-1+day]/dataset_scaled['return'].iloc[i+time_period-1]
    if r > 1:
        r = 0
    else:
        r = 1
    rr = np_utils.to_categorical(r, num_classes=2)
    cnn_y.append(rr)
    indexs.append(dataset_scaled.index[i+time_period-1])
    
cnn_x = np.array(cnn_x)
cnn_y = np.array(cnn_y)
indexes = np.array(indexs)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# HBox(children=(IntProgress(value=0, max=2462), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars

# %%
#2010~2018年為訓練和測試，2019年則為驗證
import datetime
cnn_x_t = cnn_x[indexes < datetime.datetime(2019,1,1)]
cnn_y_t = cnn_y[indexes < datetime.datetime(2019,1,1)]
cnn_x_validation = cnn_x[indexes > datetime.datetime(2019,1,1)]
cnn_y_validation = cnn_y[indexes > datetime.datetime(2019,1,1)]

# %%
from sklearn.model_selection import train_test_split
cnn_x_train, cnn_x_test, cnn_y_train, cnn_y_test = train_test_split(cnn_x_t, cnn_y_t, test_size=0.2)

# %%
cnn_x_train = np.stack((cnn_x_train,)*3,axis=-1)
cnn_x_test = np.stack((cnn_x_test,)*3,axis=-1)
cnn_x_validation = np.stack((cnn_x_validation,)*3,axis=-1)

# %%
fig = plt.figure(figsize = (15,15))
columns = rows = 5
for i in range(1,columns*rows+1):
  index = np.random.randint(len(cnn_x_train))
  img = cnn_x_train[index]
  fig.add_subplot(rows,columns,i)
  plt.axis("off")
  plt.title(str(index)+' class = '+str(np.argmax(cnn_y_train[index])))
  plt.subplots_adjust(wspace=0.2,hspace=0.2)
  plt.imshow(img)
plt.show()

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.initializers import he_normal

input_shape = cnn_x_train[0].shape

model = Sequential()
model.add(layers.Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same",
                        input_shape=input_shape))
model.add(layers.Dropout(0.25))
#model.add(layers.MaxPooling2D(2))
model.add(layers.Conv2D(filters=64, 
                        kernel_size=(3,3), 
                        padding="same", 
                        activation='relu'))
model.add(layers.MaxPooling2D(2))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(units=100, activation='relu'))
model.add(layers.Dense(units=100, activation='relu'))
model.add(layers.Dense(units=2, activation='softmax'))

#adam = tensorflow.keras.optimizers.Adam(lr=0.0005)
#sgd = tensorflow.keras.optimizers.SGD(lr=0.0005)

model.compile(loss='mse',optimizer="Adam", metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 20, 5, 32)         896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 20, 5, 32)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 5, 64)         18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 2, 64)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10, 2, 64)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               128100
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 157,794
# Trainable params: 157,794
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

history = model.fit(cnn_x_train, cnn_y_train,
                    batch_size=100,
                    epochs=250,
                    verbose=1,
                    validation_data=(cnn_x_test,cnn_y_test),
                    callbacks=[earlystop],
                    )
# Out:
# Epoch 1/250
# 18/18 [==============================] - 0s 15ms/step - loss: 0.2367 - accuracy: 0.6270 - val_loss: 0.2383 - val_accuracy: 0.6143
# Epoch 2/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2333 - accuracy: 0.6348 - val_loss: 0.2378 - val_accuracy: 0.6143
# Epoch 3/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2325 - accuracy: 0.6348 - val_loss: 0.2384 - val_accuracy: 0.6143
# Epoch 4/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2313 - accuracy: 0.6348 - val_loss: 0.2376 - val_accuracy: 0.6143
# Epoch 5/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2308 - accuracy: 0.6348 - val_loss: 0.2350 - val_accuracy: 0.6143
# Epoch 6/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2307 - accuracy: 0.6348 - val_loss: 0.2331 - val_accuracy: 0.6143
# Epoch 7/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2297 - accuracy: 0.6348 - val_loss: 0.2330 - val_accuracy: 0.6143
# Epoch 8/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2289 - accuracy: 0.6331 - val_loss: 0.2351 - val_accuracy: 0.6143
# Epoch 9/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2268 - accuracy: 0.6331 - val_loss: 0.2308 - val_accuracy: 0.6143
# Epoch 10/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2263 - accuracy: 0.6337 - val_loss: 0.2278 - val_accuracy: 0.6166
# Epoch 11/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2250 - accuracy: 0.6331 - val_loss: 0.2289 - val_accuracy: 0.6211
# Epoch 12/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2236 - accuracy: 0.6399 - val_loss: 0.2279 - val_accuracy: 0.6323
# Epoch 13/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2212 - accuracy: 0.6438 - val_loss: 0.2267 - val_accuracy: 0.6368
# Epoch 14/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2215 - accuracy: 0.6365 - val_loss: 0.2259 - val_accuracy: 0.6233
# Epoch 15/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2207 - accuracy: 0.6461 - val_loss: 0.2250 - val_accuracy: 0.6368
# Epoch 16/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2203 - accuracy: 0.6388 - val_loss: 0.2232 - val_accuracy: 0.6256
# Epoch 17/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2185 - accuracy: 0.6483 - val_loss: 0.2254 - val_accuracy: 0.6704
# Epoch 18/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2181 - accuracy: 0.6534 - val_loss: 0.2230 - val_accuracy: 0.6614
# Epoch 19/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2178 - accuracy: 0.6506 - val_loss: 0.2229 - val_accuracy: 0.6390
# Epoch 20/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2135 - accuracy: 0.6691 - val_loss: 0.2174 - val_accuracy: 0.6771
# Epoch 21/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2123 - accuracy: 0.6702 - val_loss: 0.2170 - val_accuracy: 0.6861
# Epoch 22/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2124 - accuracy: 0.6545 - val_loss: 0.2199 - val_accuracy: 0.6368
# Epoch 23/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2122 - accuracy: 0.6680 - val_loss: 0.2205 - val_accuracy: 0.6233
# Epoch 24/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2070 - accuracy: 0.6674 - val_loss: 0.2162 - val_accuracy: 0.6726
# Epoch 25/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2077 - accuracy: 0.6809 - val_loss: 0.2128 - val_accuracy: 0.6906
# Epoch 26/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2095 - accuracy: 0.6702 - val_loss: 0.2120 - val_accuracy: 0.6637
# Epoch 27/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2081 - accuracy: 0.6809 - val_loss: 0.2174 - val_accuracy: 0.6480
# Epoch 28/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2018 - accuracy: 0.6893 - val_loss: 0.2130 - val_accuracy: 0.6659
# Epoch 29/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1999 - accuracy: 0.6916 - val_loss: 0.2121 - val_accuracy: 0.6816
# Epoch 30/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1938 - accuracy: 0.7084 - val_loss: 0.2112 - val_accuracy: 0.6906
# Epoch 31/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1999 - accuracy: 0.6944 - val_loss: 0.2061 - val_accuracy: 0.7063
# Epoch 32/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1899 - accuracy: 0.7118 - val_loss: 0.2183 - val_accuracy: 0.6637
# Epoch 33/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1994 - accuracy: 0.6910 - val_loss: 0.2044 - val_accuracy: 0.6928
# Epoch 34/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1893 - accuracy: 0.7096 - val_loss: 0.2042 - val_accuracy: 0.7085
# Epoch 35/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1864 - accuracy: 0.7247 - val_loss: 0.2054 - val_accuracy: 0.7040
# Epoch 36/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1894 - accuracy: 0.7163 - val_loss: 0.2005 - val_accuracy: 0.6973
# Epoch 37/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1825 - accuracy: 0.7292 - val_loss: 0.2033 - val_accuracy: 0.7040
# Epoch 38/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1828 - accuracy: 0.7253 - val_loss: 0.2087 - val_accuracy: 0.6704
# Epoch 39/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1849 - accuracy: 0.7225 - val_loss: 0.2117 - val_accuracy: 0.6794
# Epoch 40/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1827 - accuracy: 0.7309 - val_loss: 0.2034 - val_accuracy: 0.6973
# Epoch 41/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1789 - accuracy: 0.7348 - val_loss: 0.1969 - val_accuracy: 0.6996
# Epoch 42/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1816 - accuracy: 0.7376 - val_loss: 0.1989 - val_accuracy: 0.7018
# Epoch 43/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1826 - accuracy: 0.7376 - val_loss: 0.1962 - val_accuracy: 0.7085
# Epoch 44/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1771 - accuracy: 0.7348 - val_loss: 0.1959 - val_accuracy: 0.7085
# Epoch 45/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1726 - accuracy: 0.7494 - val_loss: 0.2047 - val_accuracy: 0.6951
# Epoch 46/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1795 - accuracy: 0.7225 - val_loss: 0.1976 - val_accuracy: 0.7040
# Epoch 47/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1682 - accuracy: 0.7522 - val_loss: 0.1977 - val_accuracy: 0.7063
# Epoch 48/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1655 - accuracy: 0.7567 - val_loss: 0.1928 - val_accuracy: 0.7175
# Epoch 49/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1665 - accuracy: 0.7534 - val_loss: 0.1881 - val_accuracy: 0.7197
# Epoch 50/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1675 - accuracy: 0.7522 - val_loss: 0.1864 - val_accuracy: 0.7242
# Epoch 51/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1624 - accuracy: 0.7635 - val_loss: 0.1856 - val_accuracy: 0.7040
# Epoch 52/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1619 - accuracy: 0.7646 - val_loss: 0.1801 - val_accuracy: 0.7220
# Epoch 53/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1598 - accuracy: 0.7685 - val_loss: 0.1869 - val_accuracy: 0.7242
# Epoch 54/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1594 - accuracy: 0.7685 - val_loss: 0.1799 - val_accuracy: 0.7287
# Epoch 55/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1599 - accuracy: 0.7758 - val_loss: 0.1838 - val_accuracy: 0.7287
# Epoch 56/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1584 - accuracy: 0.7674 - val_loss: 0.1856 - val_accuracy: 0.7130
# Epoch 57/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1572 - accuracy: 0.7685 - val_loss: 0.1726 - val_accuracy: 0.7780
# Epoch 58/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1576 - accuracy: 0.7635 - val_loss: 0.1697 - val_accuracy: 0.7422
# Epoch 59/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1537 - accuracy: 0.7730 - val_loss: 0.1729 - val_accuracy: 0.7534
# Epoch 60/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1557 - accuracy: 0.7702 - val_loss: 0.1774 - val_accuracy: 0.7399
# Epoch 61/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1474 - accuracy: 0.7966 - val_loss: 0.1711 - val_accuracy: 0.7578
# Epoch 62/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1519 - accuracy: 0.7803 - val_loss: 0.1738 - val_accuracy: 0.7466
# Epoch 63/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1414 - accuracy: 0.8022 - val_loss: 0.1640 - val_accuracy: 0.7556
# Epoch 64/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1455 - accuracy: 0.7843 - val_loss: 0.1715 - val_accuracy: 0.7534
# Epoch 65/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1476 - accuracy: 0.7899 - val_loss: 0.1676 - val_accuracy: 0.7646
# Epoch 66/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1477 - accuracy: 0.7860 - val_loss: 0.1769 - val_accuracy: 0.7422
# Epoch 67/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1515 - accuracy: 0.7860 - val_loss: 0.1684 - val_accuracy: 0.7556
# Epoch 68/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1500 - accuracy: 0.7888 - val_loss: 0.1725 - val_accuracy: 0.7309
# Epoch 69/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1420 - accuracy: 0.7938 - val_loss: 0.1646 - val_accuracy: 0.7691
# Epoch 70/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1421 - accuracy: 0.7994 - val_loss: 0.1589 - val_accuracy: 0.7825
# Epoch 71/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1366 - accuracy: 0.8124 - val_loss: 0.1595 - val_accuracy: 0.7915
# Epoch 72/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1387 - accuracy: 0.8039 - val_loss: 0.1610 - val_accuracy: 0.7780
# Epoch 73/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1345 - accuracy: 0.8135 - val_loss: 0.1562 - val_accuracy: 0.7892
# Epoch 74/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1359 - accuracy: 0.8118 - val_loss: 0.1544 - val_accuracy: 0.7937
# Epoch 75/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1345 - accuracy: 0.8096 - val_loss: 0.1535 - val_accuracy: 0.7960
# Epoch 76/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1271 - accuracy: 0.8225 - val_loss: 0.1499 - val_accuracy: 0.8161
# Epoch 77/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1329 - accuracy: 0.8191 - val_loss: 0.1536 - val_accuracy: 0.7982
# Epoch 78/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1336 - accuracy: 0.8163 - val_loss: 0.1499 - val_accuracy: 0.8117
# Epoch 79/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1274 - accuracy: 0.8230 - val_loss: 0.1509 - val_accuracy: 0.8004
# Epoch 80/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1289 - accuracy: 0.8090 - val_loss: 0.1524 - val_accuracy: 0.8094
# Epoch 81/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1295 - accuracy: 0.8180 - val_loss: 0.1537 - val_accuracy: 0.7960
# Epoch 82/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1289 - accuracy: 0.8163 - val_loss: 0.1463 - val_accuracy: 0.8117
# Epoch 83/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1242 - accuracy: 0.8270 - val_loss: 0.1420 - val_accuracy: 0.8274
# Epoch 84/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1224 - accuracy: 0.8309 - val_loss: 0.1551 - val_accuracy: 0.7803
# Epoch 85/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1283 - accuracy: 0.8169 - val_loss: 0.1480 - val_accuracy: 0.8004
# Epoch 86/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1264 - accuracy: 0.8247 - val_loss: 0.1498 - val_accuracy: 0.8049
# Epoch 87/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1218 - accuracy: 0.8242 - val_loss: 0.1486 - val_accuracy: 0.8004
# Epoch 88/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1289 - accuracy: 0.8213 - val_loss: 0.1476 - val_accuracy: 0.8206
# Epoch 89/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1267 - accuracy: 0.8180 - val_loss: 0.1484 - val_accuracy: 0.8072
# Epoch 90/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1282 - accuracy: 0.8219 - val_loss: 0.1447 - val_accuracy: 0.8072
# Epoch 91/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1277 - accuracy: 0.8174 - val_loss: 0.1478 - val_accuracy: 0.8004
# Epoch 92/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1225 - accuracy: 0.8315 - val_loss: 0.1418 - val_accuracy: 0.8027
# Epoch 93/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1228 - accuracy: 0.8331 - val_loss: 0.1415 - val_accuracy: 0.8161
# Epoch 94/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1181 - accuracy: 0.8287 - val_loss: 0.1405 - val_accuracy: 0.8274
# Epoch 95/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1213 - accuracy: 0.8253 - val_loss: 0.1437 - val_accuracy: 0.8139
# Epoch 96/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1154 - accuracy: 0.8449 - val_loss: 0.1438 - val_accuracy: 0.7960
# Epoch 97/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1201 - accuracy: 0.8242 - val_loss: 0.1458 - val_accuracy: 0.8184
# Epoch 98/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1152 - accuracy: 0.8410 - val_loss: 0.1465 - val_accuracy: 0.8072
# Epoch 99/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1158 - accuracy: 0.8331 - val_loss: 0.1336 - val_accuracy: 0.8430
# Epoch 100/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1108 - accuracy: 0.8433 - val_loss: 0.1390 - val_accuracy: 0.8229
# Epoch 101/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1111 - accuracy: 0.8500 - val_loss: 0.1358 - val_accuracy: 0.8251
# Epoch 102/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1130 - accuracy: 0.8444 - val_loss: 0.1326 - val_accuracy: 0.8251
# Epoch 103/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1158 - accuracy: 0.8404 - val_loss: 0.1396 - val_accuracy: 0.8094
# Epoch 104/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1156 - accuracy: 0.8376 - val_loss: 0.1344 - val_accuracy: 0.8296
# Epoch 105/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1142 - accuracy: 0.8461 - val_loss: 0.1354 - val_accuracy: 0.8139
# Epoch 106/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1132 - accuracy: 0.8354 - val_loss: 0.1327 - val_accuracy: 0.8318
# Epoch 107/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1078 - accuracy: 0.8500 - val_loss: 0.1356 - val_accuracy: 0.8139
# Epoch 108/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1084 - accuracy: 0.8478 - val_loss: 0.1372 - val_accuracy: 0.8274
# Epoch 109/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1174 - accuracy: 0.8410 - val_loss: 0.1375 - val_accuracy: 0.8296
# Epoch 110/250
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1096 - accuracy: 0.8449 - val_loss: 0.1341 - val_accuracy: 0.8296
# Epoch 111/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1169 - accuracy: 0.8427 - val_loss: 0.1359 - val_accuracy: 0.8341
# Epoch 112/250
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1071 - accuracy: 0.8556 - val_loss: 0.1363 - val_accuracy: 0.8318
# Epoch 00112: early stopping

# %%
o_loss,o_accuracy = model.evaluate(cnn_x_train,cnn_y_train)
print("對訓練資料的：\nLoss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
n_loss,n_accuracy = model.evaluate(cnn_x_test,cnn_y_test)
print("對測試資料的：\nLoss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
# Out:
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0899 - accuracy: 0.8803
# 對訓練資料的：
# Loss: 0.09, Accuracy: 0.88
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1339 - accuracy: 0.8318
# 對測試資料的：
# Loss: 0.13, Accuracy: 0.83

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(np.log(history.history['loss']), color = 'green', label='Loss')
plt.plot(np.log(history.history['val_loss']), color = 'blue', label='Val_Loss')
plt.legend()
plt.title('Training loss based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], color = 'green', label='accuracy')
plt.plot(history.history['val_accuracy'], color = 'blue', label='Val_accuracy')
plt.legend()
plt.title('Accuracy based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()

# %%
pre = model.predict_classes(cnn_x_test)
pre = pd.Series(pre)

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_test = np.argmax(cnn_y_test, axis=1)
xcnn_y_test = pd.Series(cnn_y_test)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_test, pre)

t_size = len(cnn_y_test)
t_size1 = (cnn_y_test<1).sum()
t_guess = ((cnn_y_test<1).sum())/(len(cnn_y_test))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 246.00, FN: 28.00, FP: 47.00, TN: 125.00
# 對訓練集資料的：Loss: 0.09, Accuracy: 0.88
# 對測試集資料的：Loss: 0.13, Accuracy: 0.83
#
# 測試資料總共：446.00 筆, 其中漲的筆數為: 274.00, 全部猜漲猜對的機率是: 0.61
# 該測試集資料的：
# Accuracy: 0.83, Precision: 0.84, Recall: 0.90
# F1 score: 0.87

# %%
pre = model.predict_classes(cnn_x_validation)
pre = pd.Series(pre)
pre.hist()

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_validation = np.argmax(cnn_y_validation, axis=1)
xcnn_y_validation = pd.Series(cnn_y_validation)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_validation, pre)

t_size = len(cnn_y_validation)
t_size1 = (cnn_y_validation<1).sum()
t_guess = ((cnn_y_validation<1).sum())/(len(cnn_y_validation))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 148.00, FN: 24.00, FP: 52.00, TN: 12.00
# 對訓練集資料的：Loss: 0.09, Accuracy: 0.88
# 對測試集資料的：Loss: 0.13, Accuracy: 0.83
#
# 測試資料總共：236.00 筆, 其中漲的筆數為: 172.00, 全部猜漲猜對的機率是: 0.73
# 該測試集資料的：
# Accuracy: 0.68, Precision: 0.74, Recall: 0.86
# F1 score: 0.80
