# %%
import pandas as pd
import numpy as np
import datetime
import tqdm #進度條
import talib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
data = pd.read_csv('data/1019_SP.csv')
data1 = pd.read_csv("data/1019_CL.csv").dropna()
data2 = pd.read_csv("data/1019_OVX.csv").dropna()
data3 = pd.read_csv("data/1019_GC.csv").dropna()
data4 = pd.read_csv("data/1019_GVZ.csv").dropna()
Date = data.get("Date")
Date = pd.to_datetime(Date)
Open = data.get("Open")
High = data.get("High")
Low = data.get("Low")
Close = data.get("Close")
Close_cl = data1.get("Close")
Close_ovx = data2.get("Close")
Close_gc = data3.get("Close")
Close_gvz = data4.get("Close")

dict = {"Date": Date,
        "open": Open,
        "high": High,
        "low": Low, 
        "close": Close,
        "close_cl": Close_cl, 
        "close_ovx": Close_ovx,
        "close_gc": Close_gc, 
        "close_gvz": Close_gvz,
        "return":0,
       }
df = pd.DataFrame(dict)
df.set_index('Date', inplace=True)
df = df.dropna()
print("總共:%d個交易時間點" % (len(Date)))
print("去除空白值後剩下:%d個交易時間點" % (len(df)))
df.tail(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# 總共:2493個交易時間點
# 去除空白值後剩下:2493個交易時間點
#                    open         high  ...  close_gvz  return
# Date                                  ...
# 2019-12-13  3166.649902  3182.679932  ...      10.39       0
# 2019-12-16  3183.629883  3197.709961  ...      10.39       0
# 2019-12-17  3195.399902  3198.219971  ...      10.03       0
# 2019-12-18  3195.209961  3198.479980  ...      10.04       0
# 2019-12-19  3192.320068  3205.479980  ...      10.39       0
# 2019-12-20  3223.330078  3225.649902  ...       9.69       0
# 2019-12-23  3226.050049  3227.780029  ...      10.56       0
# 2019-12-26  3227.199951  3240.080078  ...      13.33       0
# 2019-12-27  3247.229980  3247.929932  ...      12.32       0
# 2019-12-30  3240.090088  3240.919922  ...      12.56       0
#
# [10 rows x 9 columns]

# %%
def create_labels(df,col_name,window_size=11):
  row_counter = 0
  total_rows = len(df)
  labels = np.zeros(total_rows)
  labels[:]=np.nan
  #pbar = tqdm.tqdm(total=total_rows)
  while row_counter <total_rows:
    if row_counter>=window_size-1:
      window_begin=row_counter-(window_size-1)
      window_end=row_counter
      window_middle=(window_begin+window_end)/2
      min_=np.inf
      min_index=-1
      max_=-np.inf
      max_index=-1
      for i in range(window_begin,window_end+1):
        price = df.iloc[i][col_name]
        if price<min_:
          min_=price
          min_index=i
        elif price>max_:
          max_=price
          max_index=i
      if max_index == window_middle:
        labels[row_counter] = 2
      elif min_index == window_middle:
        labels[row_counter] = 0
      else:
        labels[row_counter] = 1
    row_counter = row_counter+1
    #pbar.update(1)
  #pbar.close()
  return labels
df['return'] = create_labels(df,'close')

# %%
ema = talib.EMA(df['close'])
sma = talib.SMA(df['close'])
roc = talib.ROC(df['close'])
macd, macdsignal, macdhist = talib.MACD(df['close'])
k, d = talib.STOCH (df['high'], df['low'], df['close'])
upper, middle, lower = talib.BBANDS(df['close'])
B = (df['close'] - lower)/(upper - lower)

dataset = pd.DataFrame({
    'Close':df['close'],    
    'EMA':ema,
    'SMA':sma,
    'ROC':roc,
    'MACD':macd,
    '%K':k,
    '%D':d,
    'Upper Band':upper,
    'Lower Band':lower,
    '%B':B,
    'Close_CL':df['close_cl'],
    'Close_OVX':df['close_ovx'],
    'Close_GC':df['close_gc'],
    'Close_GVZ':df['close_gvz'],
    'return': df['return'],
})

feature_names = list(dataset.columns[:-1])

# %%
print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)
# Out:
# before dropping NaN (2493, 15)
# after dropping NaN (2460, 15)

# %%
from sklearn.preprocessing import MinMaxScaler

ss = MinMaxScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()
# Out:
#              Close          EMA  ...    Close_GVZ       return
# count  2460.000000  2460.000000  ...  2460.000000  2460.000000
# mean      0.428129     0.424185  ...     0.258850     1.006504
# std       0.263129     0.278491  ...     0.154939     0.355000
# min       0.000000     0.000000  ...     0.000000     0.000000
# 25%       0.170140     0.147477  ...     0.141213     1.000000
# 50%       0.437414     0.435432  ...     0.243000     1.000000
# 75%       0.638417     0.647352  ...     0.343096     1.000000
# max       1.000000     1.000000  ...     1.000000     2.000000
#
# [8 rows x 15 columns]

# %%
result = pd.value_counts(dataset_scaled['return'])
print(result)
dataset_scaled['return'].hist()
# Out:
# 1.0    2150
# 2.0     163
# 0.0     147
# Name: return, dtype: int64

# %%
from keras.utils import np_utils
#每張圖包含幾天的資料
time_period = 20
#預設幾日後的漲跌
day = 1

cnn_x = []
cnn_y = []
indexs = []
dataset_scaled_x= dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-time_period-1-day)):
    cnn_x.append(dataset_scaled_x.iloc[i:i+time_period].values)
    r = dataset_scaled['return'].iloc[i+time_period-1+day]
    rr = np_utils.to_categorical(r, num_classes=3)
    cnn_y.append(rr)
    indexs.append(dataset_scaled.index[i+time_period-1])
    
cnn_x = np.array(cnn_x)
cnn_y = np.array(cnn_y)
indexes = np.array(indexs)
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# HBox(children=(IntProgress(value=0, max=2438), HTML(value='')))

# %%
#2010~2018年為訓練和測試，2019年則為驗證
import datetime
cnn_x_t = cnn_x[indexes < datetime.datetime(2019,1,1)]
cnn_y_t = cnn_y[indexes < datetime.datetime(2019,1,1)]
cnn_x_validation = cnn_x[indexes > datetime.datetime(2019,1,1)]
cnn_y_validation = cnn_y[indexes > datetime.datetime(2019,1,1)]

# %%
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
def get_sample_weights(y):
  y = y.astype(int)
  class_weight = compute_class_weight('balanced',np.unique(y),y)
  print("real class weight are{}".format(class_weight),np.unique(y))
  print("value_counts",np.unique(y,return_counts=True))
  sample_weights = y.copy().astype(float)
  for i in np.unique(y):
    sample_weights[sample_weights==i]=class_weight[i]
  return class_weight,sample_weights

# %%
#將onehot編碼轉回數組
lable = np.argmax(cnn_y_t, axis=1)
lable = np.array(lable)
class_weight,sample_weights = get_sample_weights(lable)
# Out:
# real class weight are[5.45522388 0.38272251 4.90604027] [0 1 2]
# value_counts (array([0, 1, 2]), array([ 134, 1910,  149]))

# %%
class_weight={0:class_weight[0],
              1:class_weight[1],
              2:class_weight[2],}
print(class_weight)
# Out:
# {0: 5.455223880597015, 1: 0.38272251308900523, 2: 4.906040268456376}

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential

def get_model(dropout1_rate=0.5, dropout2_rate=0.5):
  
    model = Sequential()
    model.add(layers.LSTM(128, return_sequences=True, input_shape=cnn_x_t[0].shape))
    model.add(layers.Dropout(dropout1_rate, name="dropout_1"))
    model.add(layers.LSTM(128))
    model.add(layers.Dropout(dropout2_rate, name="dropout_2"))
    model.add(layers.Dense(units=32, activation='relu'))
    model.add(layers.Dense(units=3, activation='softmax'))

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='loss', patience=10, verbose=1)

def fit_with(dropout1_rate, dropout2_rate, lr, batchsize):

    # batchsize只能是整數，強迫把浮點轉int
    batchsize = int(batchsize)

    # 使用指定的超參數創建模型。
    model = get_model(dropout1_rate, dropout2_rate)
    
    # 設定優化器、學習率並建模
    optimizer = tensorflow.keras.optimizers.Adam(lr=lr)
    model.compile(loss='categorical_crossentropy',optimizer=optimizer, metrics=['accuracy'])
    
    # 使用訓練數據集訓練模型。
    model.fit(cnn_x_t, cnn_y_t,
              batch_size = batchsize,
              epochs=250,
              verbose=0,
              validation_split = 0.2,
              callbacks=[earlystop],
              class_weight=class_weight,
              )
    # steps=10 = 評估階段結束之前的步驟總數（樣本批次）
    # score = model.evaluate(cnn_x_test,cnn_y_test, steps=10, verbose=0)
    # 使用測試數據集評估模型。
    score = model.evaluate(cnn_x_t, cnn_y_t, verbose=0)
    #print('Test loss:', score[0])
    #print('Test accuracy:', score[1])

    return score[1]

# %%
from bayes_opt import BayesianOptimization

optimizer = BayesianOptimization(
        fit_with,
        {'dropout1_rate': (0, 0.5),
        'dropout2_rate': (0, 0.5),
        'lr': (1e-5, 1e-2),
        'batchsize': (16,128)}
    )
optimizer.maximize(init_points=10, n_iter=20)
# Out:
# |   iter    |  target   | batchsize | dropou... | dropou... |    lr     |
# -------------------------------------------------------------------------
# Epoch 00035: early stopping
# |  1        |  0.871    |  103.2    |  0.1013   |  0.01756  |  0.007427 |
# Epoch 00072: early stopping
# |  2        |  0.8591   |  118.4    |  0.4968   |  0.1973   |  0.005682 |
# Epoch 00063: early stopping
# |  3        |  0.928    |  126.1    |  0.1182   |  0.1352   |  0.0044   |
# Epoch 00061: early stopping
# |  4        |  0.8842   |  111.2    |  0.3764   |  0.2759   |  0.009274 |
# Epoch 00032: early stopping
# |  5        |  0.0611   |  55.92    |  0.4681   |  0.1502   |  0.009565 |
# Epoch 00096: early stopping
# |  6        |  0.8399   |  59.88    |  0.05812  |  0.1262   |  0.008677 |
# Epoch 00086: early stopping
# |  7        |  0.7784   |  97.92    |  0.1657   |  0.4051   |  0.001367 |
# Epoch 00100: early stopping
# |  8        |  0.9763   |  95.92    |  0.2028   |  0.1125   |  0.001739 |
# Epoch 00076: early stopping
# |  9        |  0.9658   |  104.6    |  0.3535   |  0.04532  |  0.004272 |
# Epoch 00020: early stopping
# |  10       |  0.06794  |  41.8     |  0.3998   |  0.4277   |  0.007737 |
# Epoch 00065: early stopping
# |  11       |  0.1272   |  76.96    |  0.0      |  0.0      |  1e-05    |

# %%
print(optimizer.max)
print(optimizer.max['params']['dropout1_rate'])
print(optimizer.max['params']['dropout2_rate'])
print(optimizer.max['params']['lr'])
print(optimizer.max['params']['batchsize'])
##Bayesian Optimization 找到的最佳超參數值
dropout_rate1 = optimizer.max['params']['dropout1_rate']
dropout_rate2 = optimizer.max['params']['dropout2_rate']
learning_rate = optimizer.max['params']['lr']
batchsize = int(optimizer.max['params']['batchsize'])

# %%
dropout_rate1 = 0.2028
dropout_rate2 = 0.1125
learning_rate =  0.001739
batchsize = int(95.92)

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.initializers import he_normal

model = Sequential()
model.add(layers.LSTM(128, return_sequences=True, input_shape=cnn_x[0].shape))
model.add(layers.Dropout(dropout_rate1, name="dropout_1"))
model.add(layers.LSTM(128))
model.add(layers.Dropout(dropout_rate2, name="dropout_2"))
model.add(layers.Dense(units=32, activation='relu'))
model.add(layers.Dense(units=3, activation='softmax'))

adam = tensorflow.keras.optimizers.Adam(learning_rate)

model.compile(loss='categorical_crossentropy',optimizer=adam, metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 20, 128)           73216
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 209,027
# Trainable params: 209,027
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='loss', patience=10, verbose=1)

history = model.fit(cnn_x_t, cnn_y_t,
                    batch_size=batchsize,
                    epochs=250,
                    verbose=1,
                    validation_split = 0.2,
                    callbacks=[earlystop],
                    class_weight=class_weight,
                    )
# Out:
# Epoch 1/250
# 19/19 [==============================] - 1s 69ms/step - loss: 1.1479 - accuracy: 0.4823 - val_loss: 1.2426 - val_accuracy: 0.0547
# Epoch 2/250
# 19/19 [==============================] - 0s 20ms/step - loss: 1.1122 - accuracy: 0.4259 - val_loss: 1.1381 - val_accuracy: 0.0843
# Epoch 3/250
# 19/19 [==============================] - 0s 20ms/step - loss: 1.0935 - accuracy: 0.1796 - val_loss: 1.1608 - val_accuracy: 0.0979
# Epoch 4/250
# 19/19 [==============================] - 0s 20ms/step - loss: 1.0643 - accuracy: 0.3529 - val_loss: 1.0653 - val_accuracy: 0.1936
# Epoch 5/250
# 19/19 [==============================] - 0s 20ms/step - loss: 1.0329 - accuracy: 0.2873 - val_loss: 1.0195 - val_accuracy: 0.2733
# Epoch 6/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.9201 - accuracy: 0.2794 - val_loss: 1.2111 - val_accuracy: 0.2551
# Epoch 7/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.7117 - accuracy: 0.5000 - val_loss: 1.0584 - val_accuracy: 0.3759
# Epoch 8/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.6095 - accuracy: 0.5068 - val_loss: 0.7390 - val_accuracy: 0.6105
# Epoch 9/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.5645 - accuracy: 0.5582 - val_loss: 0.8097 - val_accuracy: 0.5740
# Epoch 10/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.5213 - accuracy: 0.5861 - val_loss: 0.7176 - val_accuracy: 0.6264
# Epoch 11/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.5134 - accuracy: 0.5918 - val_loss: 0.7659 - val_accuracy: 0.6333
# Epoch 12/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.4854 - accuracy: 0.6294 - val_loss: 0.7301 - val_accuracy: 0.6469
# Epoch 13/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.4708 - accuracy: 0.6574 - val_loss: 0.9056 - val_accuracy: 0.5763
# Epoch 14/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.4727 - accuracy: 0.6032 - val_loss: 0.7584 - val_accuracy: 0.6333
# Epoch 15/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.4562 - accuracy: 0.6288 - val_loss: 0.8259 - val_accuracy: 0.5877
# Epoch 16/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.4705 - accuracy: 0.6391 - val_loss: 0.8365 - val_accuracy: 0.5672
# Epoch 17/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.4559 - accuracy: 0.6055 - val_loss: 0.8180 - val_accuracy: 0.5923
# Epoch 18/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.4422 - accuracy: 0.6294 - val_loss: 0.9090 - val_accuracy: 0.5011
# Epoch 19/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.4670 - accuracy: 0.6055 - val_loss: 0.8424 - val_accuracy: 0.5763
# Epoch 20/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.4697 - accuracy: 0.6237 - val_loss: 0.6525 - val_accuracy: 0.6606
# Epoch 21/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.4310 - accuracy: 0.6414 - val_loss: 0.6541 - val_accuracy: 0.6743
# Epoch 22/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.4189 - accuracy: 0.6562 - val_loss: 0.7177 - val_accuracy: 0.6492
# Epoch 23/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.3999 - accuracy: 0.6847 - val_loss: 0.7542 - val_accuracy: 0.6651
# Epoch 24/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.4137 - accuracy: 0.6437 - val_loss: 0.6783 - val_accuracy: 0.6446
# Epoch 25/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.3957 - accuracy: 0.6745 - val_loss: 0.6570 - val_accuracy: 0.6469
# Epoch 26/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.4078 - accuracy: 0.6710 - val_loss: 0.6891 - val_accuracy: 0.6629
# Epoch 27/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.4044 - accuracy: 0.6556 - val_loss: 0.6995 - val_accuracy: 0.6697
# Epoch 28/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.3854 - accuracy: 0.6973 - val_loss: 0.7147 - val_accuracy: 0.6629
# Epoch 29/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.3995 - accuracy: 0.6631 - val_loss: 0.6102 - val_accuracy: 0.7062
# Epoch 30/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.4267 - accuracy: 0.6437 - val_loss: 0.7277 - val_accuracy: 0.6538
# Epoch 31/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.3908 - accuracy: 0.6596 - val_loss: 0.7086 - val_accuracy: 0.6446
# Epoch 32/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.3826 - accuracy: 0.6899 - val_loss: 0.7528 - val_accuracy: 0.6264
# Epoch 33/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.3477 - accuracy: 0.6802 - val_loss: 0.5869 - val_accuracy: 0.7130
# Epoch 34/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.3393 - accuracy: 0.7155 - val_loss: 0.6967 - val_accuracy: 0.7016
# Epoch 35/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.3256 - accuracy: 0.7360 - val_loss: 0.6203 - val_accuracy: 0.7130
# Epoch 36/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.3761 - accuracy: 0.6767 - val_loss: 0.6724 - val_accuracy: 0.6811
# Epoch 37/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.3438 - accuracy: 0.7229 - val_loss: 0.6635 - val_accuracy: 0.7084
# Epoch 38/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.3452 - accuracy: 0.7052 - val_loss: 0.6576 - val_accuracy: 0.6993
# Epoch 39/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.3169 - accuracy: 0.7366 - val_loss: 0.7393 - val_accuracy: 0.6697
# Epoch 40/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.3031 - accuracy: 0.7474 - val_loss: 0.6998 - val_accuracy: 0.6834
# Epoch 41/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.2942 - accuracy: 0.7560 - val_loss: 0.6642 - val_accuracy: 0.7175
# Epoch 42/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.3297 - accuracy: 0.7326 - val_loss: 0.6604 - val_accuracy: 0.7039
# Epoch 43/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.3118 - accuracy: 0.7605 - val_loss: 0.7125 - val_accuracy: 0.7084
# Epoch 44/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.3043 - accuracy: 0.7446 - val_loss: 0.6429 - val_accuracy: 0.6970
# Epoch 45/250
# 19/19 [==============================] - 0s 22ms/step - loss: 0.2798 - accuracy: 0.7742 - val_loss: 0.6977 - val_accuracy: 0.7175
# Epoch 46/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.2759 - accuracy: 0.7685 - val_loss: 0.6084 - val_accuracy: 0.7335
# Epoch 47/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.2611 - accuracy: 0.7936 - val_loss: 0.5882 - val_accuracy: 0.7494
# Epoch 48/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.2594 - accuracy: 0.7982 - val_loss: 0.6143 - val_accuracy: 0.7563
# Epoch 49/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.2522 - accuracy: 0.7993 - val_loss: 0.6274 - val_accuracy: 0.7426
# Epoch 50/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.2497 - accuracy: 0.8044 - val_loss: 0.6377 - val_accuracy: 0.7472
# Epoch 51/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.2540 - accuracy: 0.8084 - val_loss: 0.5735 - val_accuracy: 0.7608
# Epoch 52/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.2521 - accuracy: 0.7999 - val_loss: 0.6122 - val_accuracy: 0.7449
# Epoch 53/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.2117 - accuracy: 0.8204 - val_loss: 0.6042 - val_accuracy: 0.7472
# Epoch 54/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1991 - accuracy: 0.8506 - val_loss: 0.6406 - val_accuracy: 0.7517
# Epoch 55/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.2334 - accuracy: 0.8301 - val_loss: 0.6631 - val_accuracy: 0.7449
# Epoch 56/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.2065 - accuracy: 0.8358 - val_loss: 0.6195 - val_accuracy: 0.7585
# Epoch 57/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1791 - accuracy: 0.8575 - val_loss: 0.5771 - val_accuracy: 0.7790
# Epoch 58/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1899 - accuracy: 0.8552 - val_loss: 0.5382 - val_accuracy: 0.8018
# Epoch 59/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.2300 - accuracy: 0.8358 - val_loss: 0.6325 - val_accuracy: 0.7449
# Epoch 60/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1898 - accuracy: 0.8558 - val_loss: 0.5609 - val_accuracy: 0.7859
# Epoch 61/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1679 - accuracy: 0.8632 - val_loss: 0.5780 - val_accuracy: 0.7699
# Epoch 62/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1645 - accuracy: 0.8974 - val_loss: 0.6700 - val_accuracy: 0.7836
# Epoch 63/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.2076 - accuracy: 0.8575 - val_loss: 0.7686 - val_accuracy: 0.7039
# Epoch 64/250
# 19/19 [==============================] - 0s 19ms/step - loss: 0.1742 - accuracy: 0.8666 - val_loss: 0.5284 - val_accuracy: 0.7973
# Epoch 65/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1609 - accuracy: 0.8814 - val_loss: 0.5744 - val_accuracy: 0.7859
# Epoch 66/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1373 - accuracy: 0.9019 - val_loss: 0.5680 - val_accuracy: 0.7973
# Epoch 67/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1166 - accuracy: 0.9173 - val_loss: 0.5560 - val_accuracy: 0.8018
# Epoch 68/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0937 - accuracy: 0.9356 - val_loss: 0.5340 - val_accuracy: 0.8292
# Epoch 69/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1460 - accuracy: 0.9179 - val_loss: 0.7205 - val_accuracy: 0.7790
# Epoch 70/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.2531 - accuracy: 0.8506 - val_loss: 0.8997 - val_accuracy: 0.6970
# Epoch 71/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.2499 - accuracy: 0.8227 - val_loss: 0.6274 - val_accuracy: 0.7449
# Epoch 72/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1744 - accuracy: 0.8677 - val_loss: 0.6274 - val_accuracy: 0.7403
# Epoch 73/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1417 - accuracy: 0.8928 - val_loss: 0.5609 - val_accuracy: 0.7995
# Epoch 74/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1014 - accuracy: 0.9236 - val_loss: 0.4761 - val_accuracy: 0.8405
# Epoch 75/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0889 - accuracy: 0.9316 - val_loss: 0.4662 - val_accuracy: 0.8337
# Epoch 76/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0639 - accuracy: 0.9607 - val_loss: 0.4943 - val_accuracy: 0.8519
# Epoch 77/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0554 - accuracy: 0.9578 - val_loss: 0.4787 - val_accuracy: 0.8428
# Epoch 78/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0553 - accuracy: 0.9681 - val_loss: 0.5221 - val_accuracy: 0.8428
# Epoch 79/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0652 - accuracy: 0.9624 - val_loss: 0.5321 - val_accuracy: 0.8474
# Epoch 80/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0570 - accuracy: 0.9601 - val_loss: 0.4853 - val_accuracy: 0.8519
# Epoch 81/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0651 - accuracy: 0.9618 - val_loss: 0.5382 - val_accuracy: 0.8474
# Epoch 82/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.2016 - accuracy: 0.8877 - val_loss: 0.9097 - val_accuracy: 0.7403
# Epoch 83/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1477 - accuracy: 0.8991 - val_loss: 0.5373 - val_accuracy: 0.8064
# Epoch 84/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0945 - accuracy: 0.9190 - val_loss: 0.4217 - val_accuracy: 0.8474
# Epoch 85/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0808 - accuracy: 0.9578 - val_loss: 0.5072 - val_accuracy: 0.8542
# Epoch 86/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0679 - accuracy: 0.9481 - val_loss: 0.4981 - val_accuracy: 0.8519
# Epoch 87/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0533 - accuracy: 0.9675 - val_loss: 0.5191 - val_accuracy: 0.8474
# Epoch 88/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0544 - accuracy: 0.9607 - val_loss: 0.6097 - val_accuracy: 0.8360
# Epoch 89/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0469 - accuracy: 0.9664 - val_loss: 0.4891 - val_accuracy: 0.8565
# Epoch 90/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0639 - accuracy: 0.9664 - val_loss: 0.5184 - val_accuracy: 0.8474
# Epoch 91/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0619 - accuracy: 0.9532 - val_loss: 0.6419 - val_accuracy: 0.8246
# Epoch 92/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0554 - accuracy: 0.9652 - val_loss: 0.5484 - val_accuracy: 0.8497
# Epoch 93/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0316 - accuracy: 0.9766 - val_loss: 0.4727 - val_accuracy: 0.8747
# Epoch 94/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0237 - accuracy: 0.9863 - val_loss: 0.5338 - val_accuracy: 0.8747
# Epoch 95/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0187 - accuracy: 0.9886 - val_loss: 0.5349 - val_accuracy: 0.8770
# Epoch 96/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0188 - accuracy: 0.9903 - val_loss: 0.5736 - val_accuracy: 0.8679
# Epoch 97/250
# 19/19 [==============================] - 0s 22ms/step - loss: 0.0144 - accuracy: 0.9914 - val_loss: 0.5435 - val_accuracy: 0.8815
# Epoch 98/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0186 - accuracy: 0.9909 - val_loss: 0.5808 - val_accuracy: 0.8770
# Epoch 99/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0154 - accuracy: 0.9920 - val_loss: 0.5502 - val_accuracy: 0.8815
# Epoch 100/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0117 - accuracy: 0.9903 - val_loss: 0.6312 - val_accuracy: 0.8679
# Epoch 101/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0089 - accuracy: 0.9954 - val_loss: 0.5943 - val_accuracy: 0.8724
# Epoch 102/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.6280 - val_accuracy: 0.8747
# Epoch 103/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.5898 - val_accuracy: 0.8838
# Epoch 104/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0056 - accuracy: 0.9966 - val_loss: 0.5790 - val_accuracy: 0.8770
# Epoch 105/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0070 - accuracy: 0.9966 - val_loss: 0.6273 - val_accuracy: 0.8724
# Epoch 106/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0047 - accuracy: 0.9977 - val_loss: 0.6265 - val_accuracy: 0.8702
# Epoch 107/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.6319 - val_accuracy: 0.8770
# Epoch 108/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0050 - accuracy: 0.9971 - val_loss: 0.6243 - val_accuracy: 0.8793
# Epoch 109/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0058 - accuracy: 0.9971 - val_loss: 0.6554 - val_accuracy: 0.8838
# Epoch 110/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.7025 - val_accuracy: 0.8656
# Epoch 111/250
# 19/19 [==============================] - 0s 19ms/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.6607 - val_accuracy: 0.8747
# Epoch 112/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0027 - accuracy: 0.9983 - val_loss: 0.6890 - val_accuracy: 0.8633
# Epoch 113/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0035 - accuracy: 0.9977 - val_loss: 0.6637 - val_accuracy: 0.8633
# Epoch 114/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.6470 - val_accuracy: 0.8724
# Epoch 115/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.6542 - val_accuracy: 0.8724
# Epoch 116/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.7066 - val_accuracy: 0.8679
# Epoch 117/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0038 - accuracy: 0.9983 - val_loss: 0.6817 - val_accuracy: 0.8724
# Epoch 118/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.7035 - val_accuracy: 0.8679
# Epoch 119/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.6969 - val_accuracy: 0.8770
# Epoch 120/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6686 - val_accuracy: 0.8793
# Epoch 121/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.6963 - val_accuracy: 0.8679
# Epoch 122/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0021 - accuracy: 0.9983 - val_loss: 0.6876 - val_accuracy: 0.8793
# Epoch 123/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.7243 - val_accuracy: 0.8702
# Epoch 124/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7343 - val_accuracy: 0.8610
# Epoch 125/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0023 - accuracy: 0.9983 - val_loss: 0.7214 - val_accuracy: 0.8610
# Epoch 126/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7056 - val_accuracy: 0.8724
# Epoch 127/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.6966 - val_accuracy: 0.8747
# Epoch 128/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7437 - val_accuracy: 0.8679
# Epoch 129/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0020 - accuracy: 0.9989 - val_loss: 0.6800 - val_accuracy: 0.8793
# Epoch 130/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.7195 - val_accuracy: 0.8702
# Epoch 131/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0026 - accuracy: 0.9983 - val_loss: 0.7515 - val_accuracy: 0.8724
# Epoch 132/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.7316 - val_accuracy: 0.8724
# Epoch 133/250
# 19/19 [==============================] - 0s 20ms/step - loss: 9.5590e-04 - accuracy: 1.0000 - val_loss: 0.7347 - val_accuracy: 0.8702
# Epoch 134/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.7344 - val_accuracy: 0.8679
# Epoch 135/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.7556 - val_accuracy: 0.8588
# Epoch 136/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0029 - accuracy: 0.9977 - val_loss: 0.8193 - val_accuracy: 0.8702
# Epoch 137/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0021 - accuracy: 0.9983 - val_loss: 0.8554 - val_accuracy: 0.8633
# Epoch 138/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.7023 - val_accuracy: 0.8793
# Epoch 139/250
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 0.7311 - val_accuracy: 0.8747
# Epoch 140/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.8368 - val_accuracy: 0.8656
# Epoch 141/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0066 - accuracy: 0.9966 - val_loss: 0.7685 - val_accuracy: 0.8702
# Epoch 142/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0151 - accuracy: 0.9971 - val_loss: 0.6944 - val_accuracy: 0.8838
# Epoch 143/250
# 19/19 [==============================] - 0s 21ms/step - loss: 0.3192 - accuracy: 0.8911 - val_loss: 0.9885 - val_accuracy: 0.7813
# Epoch 00143: early stopping

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], color = 'green', label='Loss')
plt.plot(history.history['val_loss'], color = 'blue', label='Val_Loss')
plt.legend()
plt.title('Training loss based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], color = 'green', label='accuracy')
plt.plot(history.history['val_accuracy'], color = 'blue', label='val_accuracy')
plt.legend()
plt.title('Training accuracy based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()

# %%
#將onehot編碼轉回數組cnn_x_validation
cnn_y_validation = np.argmax(cnn_y_validation, axis=1)
xcnn_y_validation = pd.Series(cnn_y_validation)
#預測
pre = model.predict_classes(cnn_x_validation)
pre = pd.Series(pre)
pre.hist()
# Out:
# WARNING:tensorflow:From <ipython-input-20-0188eda651c6>:4: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
from sklearn.metrics import confusion_matrix

LABELS = ["Buy","Hold","Sell"]
conf_matrix = confusion_matrix(xcnn_y_validation, pre)

#原始資料
t_size = len(cnn_y_validation)
b_size = (cnn_y_validation>=2).sum()
s_size = (cnn_y_validation<=0).sum()
h_size = t_size-(b_size+s_size)
b_guess = b_size/t_size
s_guess = s_size/t_size
h_guess = h_size/t_size
#矩陣數字
c00 = conf_matrix[0][0]
c01 = conf_matrix[0][1]
c02 = conf_matrix[0][2]
c10 = conf_matrix[1][0]
c11 = conf_matrix[1][1]
c12 = conf_matrix[1][2]
c20 = conf_matrix[2][0]
c21 = conf_matrix[2][1]
c22 = conf_matrix[2][2]
#評估指標
accuracy = (c00+c11+c22)/t_size
precision_b = c00/(c00+c10+c20)
precision_h = c11/(c01+c11+c21)
precision_s = c22/(c02+c12+c22)
recall_b = c00/(c00+c01+c02)
recall_h = c11/(c10+c11+c12)
recall_s = c22/(c20+c21+c22)
F1_b = 2*((precision_b*recall_b)/(precision_b+recall_b))
F1_h = 2*((precision_h*recall_h)/(precision_h+recall_h))
F1_s = 2*((precision_s*recall_s)/(precision_s+recall_s))
#印出
#print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
#print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n驗證資料總共：%.2f 筆\n其中 Buy 的筆數為: %.2f, 全部猜 Buy 猜對的機率是: %.2f" % (t_size, b_size, b_guess))
print("其中 Hold 的筆數為: %.2f, 全部猜 Hold 猜對的機率是: %.2f" % (h_size, h_guess))
print("其中 Sell 的筆數為: %.2f, 全部猜 Sell 猜對的機率是: %.2f" % (s_size, s_guess))
print("\n該測試集資料的 Accuracy 為: %.2f \nPrecision(Buy): %.2f, Recall(Buy): %.2f, F1 score(Buy): %.2f" % (accuracy, precision_b, recall_b, F1_b))
print("Precision(Hold): %.2f, Recall(Hold): %.2f, F1 score(Hold): %.2f" % (precision_h, recall_h, F1_h))
print("Precision(Sell): %.2f, Recall(Sell): %.2f, F1 score(Sell): %.2f" % (precision_s, recall_s, F1_s))
#畫圖
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# 驗證資料總共：245.00 筆
# 其中 Buy 的筆數為: 13.00, 全部猜 Buy 猜對的機率是: 0.05
# 其中 Hold 的筆數為: 220.00, 全部猜 Hold 猜對的機率是: 0.90
# 其中 Sell 的筆數為: 12.00, 全部猜 Sell 猜對的機率是: 0.05
#
# 該測試集資料的 Accuracy 為: 0.80
# Precision(Buy): 0.32, Recall(Buy): 0.58, F1 score(Buy): 0.41
# Precision(Hold): 0.95, Recall(Hold): 0.81, F1 score(Hold): 0.88
# Precision(Sell): 0.26, Recall(Sell): 0.69, F1 score(Sell): 0.37

# %%
result = pd.value_counts(xcnn_y_validation)
print(result)
# Out:
# 1    220
# 2     13
# 0     12
# dtype: int64

# %%
f = df['close'][2248:]
a = []
b = []
for i in range(len(f)):
  a.append(f[i])
  b.append(pre[i])
  #b.append(xcnn_y_validation[i])
a = np.array(a)
b = np.array(b)

S_dataset = pd.DataFrame({
    'price':a,    
    'signal':b,
})

# %%
#起始資金10000美金，每次交易手續費9美金(以eToro為例)，stock是現在持有的股票數，previous上一部的狀態一樣則不動作。
total_money = 10000
Handling_fee = 9
stock = 0
previous = 1
for i in range(len(S_dataset)):
  total_money = total_money
  stock = stock
  previous = previous
  now = S_dataset['signal'][i]
  if now == previous:
    previous = now
  else:
    if now == 2:
      if stock!=0:
        total_money = total_money+(S_dataset['price'][i]*stock)
        total_money = total_money-Handling_fee
        stock=0
    elif now == 0:
      if total_money>S_dataset['price'][i]:
        stock = int(total_money/S_dataset['price'][i])
        total_money = total_money-(stock*S_dataset['price'][i])
    previous = now

# %%
total = total_money+(S_dataset['price'][len(S_dataset)-1]*stock)-Handling_fee

# %%
#Return on investment (%)
print(((total-10000)/10000)*100)
# Out:
# 11.061892170000101
