# %%
import pandas as pd
import numpy as np
import datetime
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
data0 = pd.read_csv("data/1019_SP.csv").dropna()
data1 = pd.read_csv("data/1019_CL.csv").dropna()
data2 = pd.read_csv("data/1019_OVX.csv").dropna()
data3 = pd.read_csv("data/1019_GC.csv").dropna()
data4 = pd.read_csv("data/1019_GVZ.csv").dropna()
Date = data0.get("Date")
Date = pd.to_datetime(Date)
Close = data0.get("Close")
Close_cl = data1.get("Close")
Close_ovx = data2.get("Close")
Close_gc = data3.get("Close")
Close_gvz = data4.get("Close")
dict = {"Date": Date,
        "close": Close, 
        "close_cl": Close_cl, 
        "close_ovx": Close_ovx,
        "close_gc": Close_gc, 
        "close_gvz": Close_gvz,
       }
df = pd.DataFrame(dict)
df.set_index('Date', inplace=True)
df = df.dropna()
print("總共:%d個交易時間點" % (len(Date)))
print("去除空白值後剩下:%d個交易時間點" % (len(df)))
df.tail(10)
# Out:
# 總共:2493個交易時間點
# 去除空白值後剩下:2493個交易時間點
#                   close   close_cl  close_ovx     close_gc  close_gvz
# Date
# 2019-12-13  3168.800049  60.070000  26.760000  1475.599976      10.39
# 2019-12-16  3191.449951  60.209999  26.510000  1475.000000      10.39
# 2019-12-17  3192.520020  60.939999  26.330000  1474.599976      10.03
# 2019-12-18  3191.139893  60.930000  26.770000  1472.599976      10.04
# 2019-12-19  3205.370117  61.220001  24.799999  1478.199951      10.39
# 2019-12-20  3221.219971  60.439999  25.540001  1474.699951       9.69
# 2019-12-23  3224.010010  60.520000  25.110001  1482.500000      10.56
# 2019-12-26  3239.909912  61.680000  24.080000  1509.300049      13.33
# 2019-12-27  3240.020020  61.720001  25.160000  1513.800049      12.32
# 2019-12-30  3221.290039  61.680000  25.860001  1514.500000      12.56

# %%
dataset = pd.DataFrame({
    'Close':df['close'],
    #'Close_CL':df['close_cl'],
    #'Close_OVX':df['close_ovx'],
    'Close_GC':df['close_gc'],
    'Close_GVZ':df['close_gvz'],
    'return': df['close'],
})

feature_names = list(dataset.columns[:-1])

# %%
print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)
# Out:
# before dropping NaN (2493, 4)
# after dropping NaN (2493, 4)

# %%
from sklearn.preprocessing import MinMaxScaler

ss = MinMaxScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
#dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()
# Out:
#              Close     Close_GC    Close_GVZ       return
# count  2493.000000  2493.000000  2493.000000  2493.000000
# mean      0.422965     0.353032     0.261824     0.422965
# std       0.265162     0.213666     0.156178     0.265162
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.161118     0.207304     0.142903     0.161118
# 50%       0.434046     0.289533     0.246540     0.434046
# 75%       0.636121     0.457453     0.347602     0.636121
# max       1.000000     1.000000     1.000000     1.000000

# %%
from keras.utils import np_utils
#每張圖包含幾天的資料
time_period = 20
#預設幾日後的漲跌
day = 10

cnn_x = []
cnn_y = []
indexs = []
dataset_scaled_x= dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-time_period-1-day)):
    cnn_x.append(dataset_scaled_x.iloc[i:i+time_period].values)
    r = dataset_scaled['return'].iloc[i+time_period-1+day]/dataset_scaled['return'].iloc[i+time_period-1]
    if r > 1:
        r = 0
    else:
        r = 1
    rr = np_utils.to_categorical(r, num_classes=2)
    cnn_y.append(rr)
    indexs.append(dataset_scaled.index[i+time_period-1])
    
cnn_x = np.array(cnn_x)
cnn_y = np.array(cnn_y)
indexes = np.array(indexs)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# HBox(children=(IntProgress(value=0, max=2462), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars

# %%
#2010~2018年為訓練和測試，2019年則為驗證
import datetime
cnn_x_t = cnn_x[indexes < datetime.datetime(2019,1,1)]
cnn_y_t = cnn_y[indexes < datetime.datetime(2019,1,1)]
cnn_x_validation = cnn_x[indexes > datetime.datetime(2019,1,1)]
cnn_y_validation = cnn_y[indexes > datetime.datetime(2019,1,1)]

# %%
from sklearn.model_selection import train_test_split
cnn_x_train, cnn_x_test, cnn_y_train, cnn_y_test = train_test_split(cnn_x_t, cnn_y_t, 
                                                                    test_size=0.2,
                                                                    random_state =7,
                                                                    stratify=cnn_y_t,
                                                                    shuffle = True)

# %%
cnn_x_train = np.stack((cnn_x_train,)*3,axis=-1)
cnn_x_test = np.stack((cnn_x_test,)*3,axis=-1)
cnn_x_validation = np.stack((cnn_x_validation,)*3,axis=-1)

# %%
fig = plt.figure(figsize = (15,15))
columns = rows = 5
for i in range(1,columns*rows+1):
  index = np.random.randint(len(cnn_x_train))
  img = cnn_x_train[index]
  fig.add_subplot(rows,columns,i)
  plt.axis("off")
  plt.title(str(index)+' class = '+str(np.argmax(cnn_y_train[index])))
  plt.subplots_adjust(wspace=0.2,hspace=0.2)
  plt.imshow(img)
plt.show()

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.initializers import he_normal

input_shape = cnn_x_train[0].shape

model = Sequential()
model.add(layers.Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same",
                        input_shape=input_shape))
model.add(layers.Conv2D(filters=64, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same"))
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Dropout(0.25))
model.add(layers.Flatten())
model.add(layers.Dense(units=128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=2, activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer="Adam", metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 20, 3, 32)         896
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 3, 64)         18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 1, 64)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 10, 1, 64)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               82048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 101,698
# Trainable params: 101,698
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

history = model.fit(cnn_x_train, cnn_y_train,
                    batch_size=100,
                    epochs=250,
                    verbose=1,
                    validation_data=(cnn_x_test,cnn_y_test),
                    callbacks=[earlystop],
                    )
# Out:
# Epoch 1/250
# 18/18 [==============================] - 0s 17ms/step - loss: 0.6651 - accuracy: 0.6242 - val_loss: 0.6546 - val_accuracy: 0.6300
# Epoch 2/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6608 - accuracy: 0.6309 - val_loss: 0.6520 - val_accuracy: 0.6300
# Epoch 3/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6607 - accuracy: 0.6309 - val_loss: 0.6504 - val_accuracy: 0.6300
# Epoch 4/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6596 - accuracy: 0.6298 - val_loss: 0.6479 - val_accuracy: 0.6300
# Epoch 5/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6597 - accuracy: 0.6320 - val_loss: 0.6531 - val_accuracy: 0.6300
# Epoch 6/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6570 - accuracy: 0.6326 - val_loss: 0.6483 - val_accuracy: 0.6390
# Epoch 7/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6513 - accuracy: 0.6354 - val_loss: 0.6430 - val_accuracy: 0.6457
# Epoch 8/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6491 - accuracy: 0.6393 - val_loss: 0.6434 - val_accuracy: 0.6300
# Epoch 9/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6538 - accuracy: 0.6388 - val_loss: 0.6389 - val_accuracy: 0.6457
# Epoch 10/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6489 - accuracy: 0.6449 - val_loss: 0.6385 - val_accuracy: 0.6457
# Epoch 11/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6447 - accuracy: 0.6421 - val_loss: 0.6391 - val_accuracy: 0.6413
# Epoch 12/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6431 - accuracy: 0.6404 - val_loss: 0.6376 - val_accuracy: 0.6457
# Epoch 13/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6390 - accuracy: 0.6461 - val_loss: 0.6332 - val_accuracy: 0.6457
# Epoch 14/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6405 - accuracy: 0.6421 - val_loss: 0.6436 - val_accuracy: 0.6345
# Epoch 15/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6396 - accuracy: 0.6393 - val_loss: 0.6345 - val_accuracy: 0.6323
# Epoch 16/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6399 - accuracy: 0.6427 - val_loss: 0.6314 - val_accuracy: 0.6390
# Epoch 17/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6336 - accuracy: 0.6404 - val_loss: 0.6296 - val_accuracy: 0.6413
# Epoch 18/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6318 - accuracy: 0.6449 - val_loss: 0.6249 - val_accuracy: 0.6435
# Epoch 19/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6254 - accuracy: 0.6416 - val_loss: 0.6219 - val_accuracy: 0.6368
# Epoch 20/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6231 - accuracy: 0.6449 - val_loss: 0.6193 - val_accuracy: 0.6435
# Epoch 21/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6256 - accuracy: 0.6455 - val_loss: 0.6178 - val_accuracy: 0.6413
# Epoch 22/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6192 - accuracy: 0.6449 - val_loss: 0.6129 - val_accuracy: 0.6413
# Epoch 23/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6151 - accuracy: 0.6404 - val_loss: 0.6136 - val_accuracy: 0.6457
# Epoch 24/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6164 - accuracy: 0.6438 - val_loss: 0.6123 - val_accuracy: 0.6480
# Epoch 25/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6152 - accuracy: 0.6494 - val_loss: 0.6115 - val_accuracy: 0.6457
# Epoch 26/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6013 - accuracy: 0.6618 - val_loss: 0.5998 - val_accuracy: 0.6502
# Epoch 27/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6093 - accuracy: 0.6590 - val_loss: 0.6033 - val_accuracy: 0.6637
# Epoch 28/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6062 - accuracy: 0.6472 - val_loss: 0.6001 - val_accuracy: 0.6502
# Epoch 29/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6046 - accuracy: 0.6629 - val_loss: 0.5999 - val_accuracy: 0.6457
# Epoch 30/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6018 - accuracy: 0.6545 - val_loss: 0.6081 - val_accuracy: 0.6345
# Epoch 31/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6016 - accuracy: 0.6528 - val_loss: 0.5951 - val_accuracy: 0.6256
# Epoch 32/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6024 - accuracy: 0.6567 - val_loss: 0.5888 - val_accuracy: 0.6592
# Epoch 33/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5907 - accuracy: 0.6652 - val_loss: 0.5894 - val_accuracy: 0.6726
# Epoch 34/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5915 - accuracy: 0.6725 - val_loss: 0.5875 - val_accuracy: 0.6839
# Epoch 35/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5839 - accuracy: 0.6921 - val_loss: 0.5926 - val_accuracy: 0.6525
# Epoch 36/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5844 - accuracy: 0.6747 - val_loss: 0.5803 - val_accuracy: 0.6794
# Epoch 37/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5781 - accuracy: 0.6781 - val_loss: 0.5801 - val_accuracy: 0.6794
# Epoch 38/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5735 - accuracy: 0.6871 - val_loss: 0.5876 - val_accuracy: 0.6659
# Epoch 39/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5785 - accuracy: 0.7107 - val_loss: 0.5764 - val_accuracy: 0.6816
# Epoch 40/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5673 - accuracy: 0.6966 - val_loss: 0.5727 - val_accuracy: 0.6816
# Epoch 41/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5641 - accuracy: 0.6843 - val_loss: 0.5802 - val_accuracy: 0.6861
# Epoch 42/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5697 - accuracy: 0.6938 - val_loss: 0.5663 - val_accuracy: 0.6682
# Epoch 43/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5657 - accuracy: 0.6938 - val_loss: 0.5674 - val_accuracy: 0.6704
# Epoch 44/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5516 - accuracy: 0.7067 - val_loss: 0.5647 - val_accuracy: 0.6794
# Epoch 45/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5540 - accuracy: 0.7096 - val_loss: 0.5470 - val_accuracy: 0.6816
# Epoch 46/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5616 - accuracy: 0.6949 - val_loss: 0.5637 - val_accuracy: 0.6906
# Epoch 47/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5538 - accuracy: 0.7079 - val_loss: 0.5784 - val_accuracy: 0.6547
# Epoch 48/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5570 - accuracy: 0.7112 - val_loss: 0.5570 - val_accuracy: 0.6704
# Epoch 49/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5401 - accuracy: 0.7320 - val_loss: 0.5680 - val_accuracy: 0.6839
# Epoch 50/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5440 - accuracy: 0.7152 - val_loss: 0.5669 - val_accuracy: 0.6816
# Epoch 51/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5531 - accuracy: 0.7107 - val_loss: 0.5586 - val_accuracy: 0.6816
# Epoch 52/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5497 - accuracy: 0.7112 - val_loss: 0.5539 - val_accuracy: 0.6794
# Epoch 53/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5452 - accuracy: 0.7281 - val_loss: 0.5439 - val_accuracy: 0.7040
# Epoch 54/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5267 - accuracy: 0.7315 - val_loss: 0.5496 - val_accuracy: 0.7040
# Epoch 55/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5286 - accuracy: 0.7275 - val_loss: 0.5328 - val_accuracy: 0.7085
# Epoch 56/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5164 - accuracy: 0.7421 - val_loss: 0.5418 - val_accuracy: 0.6816
# Epoch 57/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5179 - accuracy: 0.7410 - val_loss: 0.5443 - val_accuracy: 0.7040
# Epoch 58/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5219 - accuracy: 0.7393 - val_loss: 0.5535 - val_accuracy: 0.7085
# Epoch 59/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5179 - accuracy: 0.7393 - val_loss: 0.5222 - val_accuracy: 0.7175
# Epoch 60/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5224 - accuracy: 0.7427 - val_loss: 0.5247 - val_accuracy: 0.7108
# Epoch 61/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5109 - accuracy: 0.7517 - val_loss: 0.5253 - val_accuracy: 0.7242
# Epoch 62/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5138 - accuracy: 0.7466 - val_loss: 0.5323 - val_accuracy: 0.6973
# Epoch 63/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5156 - accuracy: 0.7365 - val_loss: 0.5241 - val_accuracy: 0.7152
# Epoch 64/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5009 - accuracy: 0.7612 - val_loss: 0.5272 - val_accuracy: 0.7130
# Epoch 65/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4893 - accuracy: 0.7663 - val_loss: 0.5148 - val_accuracy: 0.7444
# Epoch 66/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5018 - accuracy: 0.7433 - val_loss: 0.5121 - val_accuracy: 0.7265
# Epoch 67/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4922 - accuracy: 0.7730 - val_loss: 0.5196 - val_accuracy: 0.7377
# Epoch 68/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4846 - accuracy: 0.7596 - val_loss: 0.5087 - val_accuracy: 0.7287
# Epoch 69/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4892 - accuracy: 0.7573 - val_loss: 0.5081 - val_accuracy: 0.7466
# Epoch 70/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4919 - accuracy: 0.7646 - val_loss: 0.5120 - val_accuracy: 0.7354
# Epoch 71/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4868 - accuracy: 0.7697 - val_loss: 0.5154 - val_accuracy: 0.7354
# Epoch 72/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4810 - accuracy: 0.7691 - val_loss: 0.5128 - val_accuracy: 0.7601
# Epoch 73/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4806 - accuracy: 0.7680 - val_loss: 0.5205 - val_accuracy: 0.7309
# Epoch 74/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4922 - accuracy: 0.7657 - val_loss: 0.5252 - val_accuracy: 0.7377
# Epoch 75/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4809 - accuracy: 0.7612 - val_loss: 0.5140 - val_accuracy: 0.7332
# Epoch 76/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4737 - accuracy: 0.7646 - val_loss: 0.5113 - val_accuracy: 0.7377
# Epoch 77/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4810 - accuracy: 0.7787 - val_loss: 0.5058 - val_accuracy: 0.7511
# Epoch 78/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4587 - accuracy: 0.7843 - val_loss: 0.4997 - val_accuracy: 0.7354
# Epoch 79/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4583 - accuracy: 0.7989 - val_loss: 0.5035 - val_accuracy: 0.7623
# Epoch 80/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4541 - accuracy: 0.7758 - val_loss: 0.5040 - val_accuracy: 0.7309
# Epoch 81/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4734 - accuracy: 0.7753 - val_loss: 0.4895 - val_accuracy: 0.7511
# Epoch 82/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4574 - accuracy: 0.7826 - val_loss: 0.5021 - val_accuracy: 0.7556
# Epoch 83/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4473 - accuracy: 0.7854 - val_loss: 0.4937 - val_accuracy: 0.7511
# Epoch 84/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4468 - accuracy: 0.7876 - val_loss: 0.4888 - val_accuracy: 0.7578
# Epoch 85/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4478 - accuracy: 0.7955 - val_loss: 0.4781 - val_accuracy: 0.7780
# Epoch 86/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4520 - accuracy: 0.7848 - val_loss: 0.4832 - val_accuracy: 0.7578
# Epoch 87/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4325 - accuracy: 0.8096 - val_loss: 0.4842 - val_accuracy: 0.7825
# Epoch 88/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4469 - accuracy: 0.8022 - val_loss: 0.4739 - val_accuracy: 0.7668
# Epoch 89/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4281 - accuracy: 0.8022 - val_loss: 0.4765 - val_accuracy: 0.7578
# Epoch 90/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4458 - accuracy: 0.7961 - val_loss: 0.4734 - val_accuracy: 0.7578
# Epoch 91/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4333 - accuracy: 0.7966 - val_loss: 0.4855 - val_accuracy: 0.7623
# Epoch 92/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4396 - accuracy: 0.7921 - val_loss: 0.4909 - val_accuracy: 0.7623
# Epoch 93/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4390 - accuracy: 0.8022 - val_loss: 0.4895 - val_accuracy: 0.7713
# Epoch 94/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4292 - accuracy: 0.7966 - val_loss: 0.4636 - val_accuracy: 0.7915
# Epoch 95/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4169 - accuracy: 0.8118 - val_loss: 0.4648 - val_accuracy: 0.7892
# Epoch 96/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4293 - accuracy: 0.7927 - val_loss: 0.4699 - val_accuracy: 0.7780
# Epoch 97/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4239 - accuracy: 0.7983 - val_loss: 0.4609 - val_accuracy: 0.7825
# Epoch 98/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4172 - accuracy: 0.8051 - val_loss: 0.4713 - val_accuracy: 0.7848
# Epoch 99/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4238 - accuracy: 0.8034 - val_loss: 0.4669 - val_accuracy: 0.7758
# Epoch 100/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4208 - accuracy: 0.8090 - val_loss: 0.4652 - val_accuracy: 0.7758
# Epoch 101/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4215 - accuracy: 0.8140 - val_loss: 0.4716 - val_accuracy: 0.7758
# Epoch 102/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4126 - accuracy: 0.8140 - val_loss: 0.4644 - val_accuracy: 0.7758
# Epoch 103/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3982 - accuracy: 0.8253 - val_loss: 0.4688 - val_accuracy: 0.7870
# Epoch 104/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4131 - accuracy: 0.8208 - val_loss: 0.4611 - val_accuracy: 0.7960
# Epoch 105/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4098 - accuracy: 0.8174 - val_loss: 0.4604 - val_accuracy: 0.7892
# Epoch 106/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4032 - accuracy: 0.8124 - val_loss: 0.4760 - val_accuracy: 0.7556
# Epoch 107/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4022 - accuracy: 0.8101 - val_loss: 0.4413 - val_accuracy: 0.8094
# Epoch 108/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3953 - accuracy: 0.8191 - val_loss: 0.4560 - val_accuracy: 0.7870
# Epoch 109/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4065 - accuracy: 0.8169 - val_loss: 0.4665 - val_accuracy: 0.7892
# Epoch 110/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4042 - accuracy: 0.8174 - val_loss: 0.4532 - val_accuracy: 0.7780
# Epoch 111/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4013 - accuracy: 0.8191 - val_loss: 0.4603 - val_accuracy: 0.7601
# Epoch 112/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3972 - accuracy: 0.8230 - val_loss: 0.4662 - val_accuracy: 0.7892
# Epoch 113/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3849 - accuracy: 0.8236 - val_loss: 0.4617 - val_accuracy: 0.7735
# Epoch 114/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3799 - accuracy: 0.8309 - val_loss: 0.4657 - val_accuracy: 0.7892
# Epoch 115/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3925 - accuracy: 0.8208 - val_loss: 0.4490 - val_accuracy: 0.7982
# Epoch 116/250
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3892 - accuracy: 0.8163 - val_loss: 0.4455 - val_accuracy: 0.7803
# Epoch 117/250
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3958 - accuracy: 0.8124 - val_loss: 0.4805 - val_accuracy: 0.7735
# Epoch 00117: early stopping

# %%
o_loss,o_accuracy = model.evaluate(cnn_x_train,cnn_y_train)
print("對訓練資料的：\nLoss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
n_loss,n_accuracy = model.evaluate(cnn_x_test,cnn_y_test)
print("對測試資料的：\nLoss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
# Out:
# 56/56 [==============================] - 0s 3ms/step - loss: 0.3592 - accuracy: 0.8483
# 對訓練資料的：
# Loss: 0.36, Accuracy: 0.85
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4969 - accuracy: 0.7735
# 對測試資料的：
# Loss: 0.50, Accuracy: 0.77

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(np.log(history.history['loss']), color = 'green', label='Loss')
plt.plot(np.log(history.history['val_loss']), color = 'blue', label='Val_Loss')
plt.legend()
plt.title('Training loss based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], color = 'green', label='accuracy')
plt.plot(history.history['val_accuracy'], color = 'blue', label='Val_accuracy')
plt.legend()
plt.title('Accuracy based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()

# %%
pre = model.predict_classes(cnn_x_test)
pre = pd.Series(pre)

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_test = np.argmax(cnn_y_test, axis=1)
xcnn_y_test = pd.Series(cnn_y_test)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_test, pre)

t_size = len(cnn_y_test)
t_size1 = (cnn_y_test<1).sum()
t_guess = ((cnn_y_test<1).sum())/(len(cnn_y_test))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 231.00, FN: 50.00, FP: 51.00, TN: 114.00
# 對訓練集資料的：Loss: 0.36, Accuracy: 0.85
# 對測試集資料的：Loss: 0.50, Accuracy: 0.77
#
# 測試資料總共：446.00 筆, 其中漲的筆數為: 281.00, 全部猜漲猜對的機率是: 0.63
# 該測試集資料的：
# Accuracy: 0.77, Precision: 0.82, Recall: 0.82
# F1 score: 0.82

# %%
pre = model.predict_classes(cnn_x_validation)
pre = pd.Series(pre)
pre.hist()

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_validation = np.argmax(cnn_y_validation, axis=1)
xcnn_y_validation = pd.Series(cnn_y_validation)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_validation, pre)

t_size = len(cnn_y_validation)
t_size1 = (cnn_y_validation<1).sum()
t_guess = ((cnn_y_validation<1).sum())/(len(cnn_y_validation))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 123.00, FN: 49.00, FP: 45.00, TN: 19.00
# 對訓練集資料的：Loss: 0.36, Accuracy: 0.85
# 對測試集資料的：Loss: 0.50, Accuracy: 0.77
#
# 測試資料總共：236.00 筆, 其中漲的筆數為: 172.00, 全部猜漲猜對的機率是: 0.73
# 該測試集資料的：
# Accuracy: 0.60, Precision: 0.73, Recall: 0.72
# F1 score: 0.72
