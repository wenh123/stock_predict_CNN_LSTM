# %%
import pandas as pd
import numpy as np
import datetime
import tqdm #進度條
import talib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
data = pd.read_csv('data/1019_SP.csv')
Date = data.get("Date")
Date = pd.to_datetime(Date)
Open = data.get("Open")
High = data.get("High")
Low = data.get("Low")
Close = data.get("Close")

dict = {"Date": Date,
        "open": Open,
        "high": High,
        "low": Low, 
        "close": Close
       }
df = pd.DataFrame(dict)
df.set_index('Date', inplace=True)
df = df.dropna()
print("總共:%d個交易時間點" % (len(Date)))
print("去除空白值後剩下:%d個交易時間點" % (len(df)))
df.tail(10)
# Out:
# 總共:2493個交易時間點
# 去除空白值後剩下:2493個交易時間點
#                    open         high          low        close
# Date
# 2019-12-13  3166.649902  3182.679932  3156.510010  3168.800049
# 2019-12-16  3183.629883  3197.709961  3183.629883  3191.449951
# 2019-12-17  3195.399902  3198.219971  3191.030029  3192.520020
# 2019-12-18  3195.209961  3198.479980  3191.139893  3191.139893
# 2019-12-19  3192.320068  3205.479980  3192.320068  3205.370117
# 2019-12-20  3223.330078  3225.649902  3216.030029  3221.219971
# 2019-12-23  3226.050049  3227.780029  3222.300049  3224.010010
# 2019-12-26  3227.199951  3240.080078  3227.199951  3239.909912
# 2019-12-27  3247.229980  3247.929932  3234.370117  3240.020020
# 2019-12-30  3240.090088  3240.919922  3216.570068  3221.290039

# %%
ema = talib.EMA(df['close'])
sma = talib.SMA(df['close'])
roc = talib.ROC(df['close'])
macd, macdsignal, macdhist = talib.MACD(df['close'])
k, d = talib.STOCH (df['high'], df['low'], df['close'])
upper, middle, lower = talib.BBANDS(df['close'])
B = (df['close'] - lower)/(upper - lower)

dataset = pd.DataFrame({
    'Close':df['close'],    
    'EMA':ema,
    'SMA':sma,
    'ROC':roc,
    'MACD':macd,
    '%K':k,
    '%D':d,
    'Upper Band':upper,
    'Lower Band':lower,
    '%B':B,
    'return': df['close']
})

feature_names = list(dataset.columns[:-1])

# %%
print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)
# Out:
# before dropping NaN (2493, 11)
# after dropping NaN (2460, 11)

# %%
from sklearn.preprocessing import MinMaxScaler

ss = MinMaxScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
#dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()
# Out:
#              Close          EMA  ...           %B       return
# count  2460.000000  2460.000000  ...  2460.000000  2460.000000
# mean      0.428129     0.424185  ...     0.557574     0.428129
# std       0.263129     0.278491  ...     0.287313     0.263129
# min       0.000000     0.000000  ...     0.000000     0.000000
# 25%       0.170140     0.147477  ...     0.297806     0.170140
# 50%       0.437414     0.435432  ...     0.629983     0.437414
# 75%       0.638417     0.647352  ...     0.802273     0.638417
# max       1.000000     1.000000  ...     1.000000     1.000000
#
# [8 rows x 11 columns]

# %%
from keras.utils import np_utils
#每張圖包含幾天的資料
time_period = 20
#預設幾日後的漲跌
day = 10

cnn_x = []
cnn_y = []
indexs = []
dataset_scaled_x= dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-time_period-1-day)):
    cnn_x.append(dataset_scaled_x.iloc[i:i+time_period].values)
    r = dataset_scaled['return'].iloc[i+time_period-1+day]/dataset_scaled['return'].iloc[i+time_period-1]
    if r > 1.007:
        r = 0
    else:
        r = 1
    rr = np_utils.to_categorical(r, num_classes=2)
    cnn_y.append(rr)
    indexs.append(dataset_scaled.index[i+time_period-1])
    
cnn_x = np.array(cnn_x)
cnn_y = np.array(cnn_y)
indexes = np.array(indexs)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# HBox(children=(IntProgress(value=0, max=2429), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars

# %%
#2010~2018年為訓練和測試，2019年則為驗證
import datetime
cnn_x_t = cnn_x[indexes < datetime.datetime(2019,1,1)]
cnn_y_t = cnn_y[indexes < datetime.datetime(2019,1,1)]
cnn_x_validation = cnn_x[indexes > datetime.datetime(2019,1,1)]
cnn_y_validation = cnn_y[indexes > datetime.datetime(2019,1,1)]

# %%
from sklearn.model_selection import train_test_split
cnn_x_train, cnn_x_test, cnn_y_train, cnn_y_test = train_test_split(cnn_x_t, cnn_y_t, test_size=0.2,random_state = 0)

# %%
import random
f = []
for i in range(len(cnn_x_train)):
  a = cnn_x_train[i]
  b = cnn_y_train[i]
  f.append([a,b])
random.shuffle(f)

# %%
cnn_x_train = []
cnn_y_train = []
for i in range(len(f)):
  cnn_x_train.append(f[i][0])
  cnn_y_train.append(f[i][1])
cnn_x_train = np.array(cnn_x_train)
cnn_y_train = np.array(cnn_y_train)

# %%
cnn_x_train = np.stack((cnn_x_train,)*3,axis=-1)
cnn_x_test = np.stack((cnn_x_test,)*3,axis=-1)
cnn_x_validation = np.stack((cnn_x_validation,)*3,axis=-1)

# %%
fig = plt.figure(figsize = (15,15))
columns = rows = 5
for i in range(1,columns*rows+1):
  index = np.random.randint(len(cnn_x_train))
  img = cnn_x_train[index]
  fig.add_subplot(rows,columns,i)
  plt.axis("off")
  plt.title(str(index)+' class = '+str(np.argmax(cnn_y_train[index])))
  plt.subplots_adjust(wspace=0.2,hspace=0.2)
  plt.imshow(img)
plt.show()

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.initializers import he_normal

input_shape = cnn_x_train[0].shape

model = Sequential()
model.add(layers.Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu',
                        padding="same",
                        input_shape=input_shape))
#model.add(layers.MaxPooling2D(2))
model.add(layers.Dropout(0.25))
model.add(layers.Conv2D(filters=64, 
                        kernel_size=(3,3), 
                        padding="same", 
                        activation='relu'))
model.add(layers.MaxPooling2D(1))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(units=100, activation='relu'))
model.add(layers.Dense(units=100, activation='relu'))
model.add(layers.Dense(units=2, activation='softmax'))

#adam = tensorflow.keras.optimizers.Adam(lr=0.0005)
#sgd = tensorflow.keras.optimizers.SGD(lr=0.0005)

#model.compile(loss='mse',optimizer="Adam", metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',optimizer="Adam", metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 20, 10, 32)        896
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 20, 10, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 20, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 20, 10, 64)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 20, 10, 64)        0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_27 (Dense)             (None, 100)               1280100
# _________________________________________________________________
# dense_28 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_29 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 1,309,794
# Trainable params: 1,309,794
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

history = model.fit(cnn_x_train, cnn_y_train,
                    batch_size=100,
                    epochs=250,
                    verbose=1,
                    #validation_split = 0.2,
                    validation_data=(cnn_x_test,cnn_y_test),
                    #callbacks=[earlystop],
                    )
# Out:
# Epoch 1/250
# 18/18 [==============================] - 0s 22ms/step - loss: 0.7126 - accuracy: 0.5331 - val_loss: 0.6808 - val_accuracy: 0.5900
# Epoch 2/250
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6875 - accuracy: 0.5542 - val_loss: 0.6810 - val_accuracy: 0.5900
# Epoch 3/250
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6875 - accuracy: 0.5542 - val_loss: 0.6791 - val_accuracy: 0.5900
# Epoch 4/250
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6850 - accuracy: 0.5542 - val_loss: 0.6734 - val_accuracy: 0.5900
# Epoch 5/250
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6840 - accuracy: 0.5542 - val_loss: 0.6762 - val_accuracy: 0.5900
# Epoch 6/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6831 - accuracy: 0.5587 - val_loss: 0.6695 - val_accuracy: 0.5809
# Epoch 7/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6804 - accuracy: 0.5661 - val_loss: 0.6712 - val_accuracy: 0.5740
# Epoch 8/250
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6798 - accuracy: 0.5690 - val_loss: 0.6745 - val_accuracy: 0.5923
# Epoch 9/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6765 - accuracy: 0.5867 - val_loss: 0.6745 - val_accuracy: 0.5854
# Epoch 10/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6762 - accuracy: 0.5872 - val_loss: 0.6813 - val_accuracy: 0.5945
# Epoch 11/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6786 - accuracy: 0.5792 - val_loss: 0.6745 - val_accuracy: 0.6082
# Epoch 12/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6712 - accuracy: 0.5906 - val_loss: 0.6659 - val_accuracy: 0.5968
# Epoch 13/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6685 - accuracy: 0.6032 - val_loss: 0.6676 - val_accuracy: 0.5991
# Epoch 14/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6662 - accuracy: 0.6015 - val_loss: 0.6680 - val_accuracy: 0.6036
# Epoch 15/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6624 - accuracy: 0.6072 - val_loss: 0.6790 - val_accuracy: 0.5513
# Epoch 16/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6602 - accuracy: 0.6214 - val_loss: 0.6590 - val_accuracy: 0.6196
# Epoch 17/250
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6477 - accuracy: 0.6209 - val_loss: 0.6559 - val_accuracy: 0.6082
# Epoch 18/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6475 - accuracy: 0.6203 - val_loss: 0.6523 - val_accuracy: 0.6105
# Epoch 19/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6330 - accuracy: 0.6545 - val_loss: 0.6587 - val_accuracy: 0.6287
# Epoch 20/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6315 - accuracy: 0.6448 - val_loss: 0.6543 - val_accuracy: 0.6105
# Epoch 21/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6233 - accuracy: 0.6448 - val_loss: 0.6471 - val_accuracy: 0.6150
# Epoch 22/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6195 - accuracy: 0.6494 - val_loss: 0.6374 - val_accuracy: 0.6446
# Epoch 23/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.5965 - accuracy: 0.6773 - val_loss: 0.6553 - val_accuracy: 0.6173
# Epoch 24/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0
250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0932 - accuracy: 0.9624 - val_loss: 1.1151 - val_accuracy: 0.6902
# Epoch 82/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0812 - accuracy: 0.9704 - val_loss: 1.2397 - val_accuracy: 0.6993
# Epoch 83/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0853 - accuracy: 0.9704 - val_loss: 1.3089 - val_accuracy: 0.6674
# Epoch 84/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0869 - accuracy: 0.9664 - val_loss: 1.2122 - val_accuracy: 0.6879
# Epoch 85/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0911 - accuracy: 0.9652 - val_loss: 1.2570 - val_accuracy: 0.6856
# Epoch 86/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0798 - accuracy: 0.9692 - val_loss: 1.2968 - val_accuracy: 0.6925
# Epoch 87/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0862 - accuracy: 0.9698 - val_loss: 1.3028 - val_accuracy: 0.7016
# Epoch 88/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0898 - accuracy: 0.9658 - val_loss: 1.2694 - val_accuracy: 0.6788
# Epoch 89/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0931 - accuracy: 0.9635 - val_loss: 1.2121 - val_accuracy: 0.6856
# Epoch 90/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0723 - accuracy: 0.9686 - val_loss: 1.3017 - val_accuracy: 0.6948
# Epoch 91/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0973 - accuracy: 0.9629 - val_loss: 1.1657 - val_accuracy: 0.7107
# Epoch 92/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0762 - accuracy: 0.9755 - val_loss: 1.1349 - val_accuracy: 0.7153
# Epoch 93/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0719 - accuracy: 0.9738 - val_loss: 1.2280 - val_accuracy: 0.7039
# Epoch 94/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0756 - accuracy: 0.9721 - val_loss: 1.2695 - val_accuracy: 0.6948
# Epoch 95/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0661 - accuracy: 0.9761 - val_loss: 1.1715 - val_accuracy: 0.7016
# Epoch 96/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0593 - accuracy: 0.9795 - val_loss: 1.2910 - val_accuracy: 0.7039
# Epoch 97/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0484 - accuracy: 0.9840 - val_loss: 1.2815 - val_accuracy: 0.6970
# Epoch 98/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0656 - accuracy: 0.9761 - val_loss: 1.3384 - val_accuracy: 0.6834
# Epoch 99/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0615 - accuracy: 0.9772 - val_loss: 1.4313 - val_accuracy: 0.6993
# Epoch 100/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0695 - accuracy: 0.9778 - val_loss: 1.3154 - val_accuracy: 0.6970
# Epoch 101/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0561 - accuracy: 0.9772 - val_loss: 1.3321 - val_accuracy: 0.6970
# Epoch 102/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0568 - accuracy: 0.9812 - val_loss: 1.2996 - val_accuracy: 0.7107
# Epoch 103/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0540 - accuracy: 0.9840 - val_loss: 1.3002 - val_accuracy: 0.6993
# Epoch 104/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0538 - accuracy: 0.9772 - val_loss: 1.3611 - val_accuracy: 0.7039
# Epoch 105/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0505 - accuracy: 0.9835 - val_loss: 1.4638 - val_accuracy: 0.7175
# Epoch 106/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0625 - accuracy: 0.9715 - val_loss: 1.3717 - val_accuracy: 0.6993
# Epoch 107/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0826 - accuracy: 0.9743 - val_loss: 1.3634 - val_accuracy: 0.6834
# Epoch 108/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0530 - accuracy: 0.9783 - val_loss: 1.3615 - val_accuracy: 0.6879
# Epoch 109/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0497 - accuracy: 0.9806 - val_loss: 1.3402 - val_accuracy: 0.7107
# Epoch 110/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0429 - accuracy: 0.9840 - val_loss: 1.3825 - val_accuracy: 0.7062
# Epoch 111/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.
250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0338 - accuracy: 0.9857 - val_loss: 1.5384 - val_accuracy: 0.7039
# Epoch 142/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0305 - accuracy: 0.9932 - val_loss: 1.5132 - val_accuracy: 0.7016
# Epoch 143/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0438 - accuracy: 0.9846 - val_loss: 1.5763 - val_accuracy: 0.6856
# Epoch 144/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0395 - accuracy: 0.9857 - val_loss: 1.7405 - val_accuracy: 0.6970
# Epoch 145/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0299 - accuracy: 0.9903 - val_loss: 1.7593 - val_accuracy: 0.6970
# Epoch 146/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0274 - accuracy: 0.9886 - val_loss: 1.7557 - val_accuracy: 0.7062
# Epoch 147/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0372 - accuracy: 0.9869 - val_loss: 1.6371 - val_accuracy: 0.7153
# Epoch 148/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0368 - accuracy: 0.9869 - val_loss: 1.6936 - val_accuracy: 0.6902
# Epoch 149/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0297 - accuracy: 0.9892 - val_loss: 1.8668 - val_accuracy: 0.6970
# Epoch 150/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0257 - accuracy: 0.9920 - val_loss: 1.6991 - val_accuracy: 0.7084
# Epoch 151/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0244 - accuracy: 0.9920 - val_loss: 1.6526 - val_accuracy: 0.7267
# Epoch 152/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0293 - accuracy: 0.9909 - val_loss: 1.6781 - val_accuracy: 0.7267
# Epoch 153/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0265 - accuracy: 0.9892 - val_loss: 1.6666 - val_accuracy: 0.7107
# Epoch 154/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0352 - accuracy: 0.9869 - val_loss: 1.6243 - val_accuracy: 0.6970
# Epoch 155/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 1.6607 - val_accuracy: 0.7153
# Epoch 156/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0346 - accuracy: 0.9892 - val_loss: 1.6399 - val_accuracy: 0.6993
# Epoch 157/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0379 - accuracy: 0.9863 - val_loss: 1.6161 - val_accuracy: 0.6993
# Epoch 158/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0354 - accuracy: 0.9857 - val_loss: 1.7207 - val_accuracy: 0.6948
# Epoch 159/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0463 - accuracy: 0.9857 - val_loss: 1.5794 - val_accuracy: 0.6948
# Epoch 160/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0318 - accuracy: 0.9926 - val_loss: 1.5104 - val_accuracy: 0.7107
# Epoch 161/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0301 - accuracy: 0.9932 - val_loss: 1.5226 - val_accuracy: 0.6856
# Epoch 162/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0242 - accuracy: 0.9920 - val_loss: 1.6646 - val_accuracy: 0.7107
# Epoch 163/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0172 - accuracy: 0.9960 - val_loss: 1.6805 - val_accuracy: 0.6948
# Epoch 164/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 1.6842 - val_accuracy: 0.6811
# Epoch 165/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0155 - accuracy: 0.9954 - val_loss: 1.7391 - val_accuracy: 0.6970
# Epoch 166/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0395 - accuracy: 0.9863 - val_loss: 1.7059 - val_accuracy: 0.7084
# Epoch 167/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0490 - accuracy: 0.9892 - val_loss: 1.6629 - val_accuracy: 0.6856
# Epoch 168/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0320 - accuracy: 0.9897 - val_loss: 1.6653 - val_accuracy: 0.6856
# Epoch 169/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0376 - accuracy: 0.9863 - val_loss: 1.7459 - val_accuracy: 0.6856
# Epoch 170/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0416 - accuracy: 0.9869 - val_loss: 1.6378 - val_accuracy: 0.6902
# Epoch 171/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0358 - accuracy: 0.9903 - val_loss: 1.6333 - val_accuracy: 0.6834
# Epoch 172/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0283 - accuracy: 0.9914 - val_loss: 1.5532 - val_accuracy: 0.6856
# Epoch 173/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0399 - accuracy: 0.9875 - val_loss: 1.6758 - val_accuracy: 0.7107
# Epoch 174/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0306 - accuracy: 0.9880 - val_loss: 1.6293 - val_accuracy: 0.7198
# Epoch 175/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 1.6479 - val_accuracy: 0.7175
# Epoch 176/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0214 - accuracy: 0.9903 - val_loss: 1.7802 - val_accuracy: 0.6948
# Epoch 177/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0248 - accuracy: 0.9932 - val_loss: 1.7468 - val_accuracy: 0.6879
# Epoch 178/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0341 - accuracy: 0.9897 - val_loss: 1.6423 - val_accuracy: 0.7084
# Epoch 179/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0213 - accuracy: 0.9920 - val_loss: 1.7187 - val_accuracy: 0.6925
# Epoch 180/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0160 - accuracy: 0.9937 - val_loss: 1.6647 - val_accuracy: 0.7062
# Epoch 181/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0280 - accuracy: 0.9892 - val_loss: 1.8591 - val_accuracy: 0.6629
# Epoch 182/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0340 - accuracy: 0.9886 - val_loss: 1.8317 - val_accuracy: 0.6948
# Epoch 183/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 1.8674 - val_accuracy: 0.7016
# Epoch 184/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0265 - accuracy: 0.9892 - val_loss: 1.8878 - val_accuracy: 0.7084
# Epoch 185/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0182 - accuracy: 0.9926 - val_loss: 1.8879 - val_accuracy: 0.6788
# Epoch 186/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0271 - accuracy: 0.9897 - val_loss: 1.8634 - val_accuracy: 0.6948
# Epoch 187/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0261 - accuracy: 0.9909 - val_loss: 1.7947 - val_accuracy: 0.6879
# Epoch 188/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0243 - accuracy: 0.9920 - val_loss: 1.7113 - val_accuracy: 0.6993
# Epoch 189/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0224 - accuracy: 0.9920 - val_loss: 1.8336 - val_accuracy: 0.6856
# Epoch 190/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0189 - accuracy: 0.9943 - val_loss: 1.7579 - val_accuracy: 0.7107
# Epoch 191/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0181 - accuracy: 0.9920 - val_loss: 1.7486 - val_accuracy: 0.7062
# Epoch 192/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0292 - accuracy: 0.9920 - val_loss: 1.7962 - val_accuracy: 0.7039
# Epoch 193/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0288 - accuracy: 0.9920 - val_loss: 1.7131 - val_accuracy: 0.6970
# Epoch 194/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0211 - accuracy: 0.9932 - val_loss: 1.7392 - val_accuracy: 0.6970
# Epoch 195/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0319 - accuracy: 0.9875 - val_loss: 1.7334 - val_accuracy: 0.7016
# Epoch 196/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0399 - accuracy: 0.9869 - val_loss: 1.8367 - val_accuracy: 0.6811
# Epoch 197/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0249 - accuracy: 0.9903 - val_loss: 1.8860 - val_accuracy: 0.6970
# Epoch 198/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0106 - accuracy: 0.9977 - val_loss: 1.8882 - val_accuracy: 0.7130
# Epoch 199/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0159 - accuracy: 0.9954 - val_loss: 1.8410 - val_accuracy: 0.6993
# Epoch 200/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0191 - accuracy: 0.9937 - val_loss: 1.8282 - val_accuracy: 0.7084
# Epoch 201/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0171 - accuracy: 0.9949 - val_loss: 1.9546 - val_accuracy: 0.6970
# Epoch 202/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0288 - accuracy: 0.9909 - val_loss: 1.9301 - val_accuracy: 0.6856
# Epoch 203/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0226 - accuracy: 0.9897 - val_loss: 1.9917 - val_accuracy: 0.7016
# Epoch 204/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 1.9294 - val_accuracy: 0.7016
# Epoch 205/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0251 - accuracy: 0.9926 - val_loss: 1.8661 - val_accuracy: 0.7084
# Epoch 206/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0214 - accuracy: 0.9949 - val_loss: 2.0498 - val_accuracy: 0.7084
# Epoch 207/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0241 - accuracy: 0.9897 - val_loss: 1.9828 - val_accuracy: 0.7084
# Epoch 208/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0473 - accuracy: 0.9840 - val_loss: 1.7907 - val_accuracy: 0.6925
# Epoch 209/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0288 - accuracy: 0.9914 - val_loss: 1.7641 - val_accuracy: 0.6993
# Epoch 210/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0314 - accuracy: 0.9909 - val_loss: 1.7911 - val_accuracy: 0.6902
# Epoch 211/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0271 - accuracy: 0.9920 - val_loss: 1.7804 - val_accuracy: 0.7107
# Epoch 212/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0206 - accuracy: 0.9932 - val_loss: 1.7577 - val_accuracy: 0.6788
# Epoch 213/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0250 - accuracy: 0.9932 - val_loss: 1.7355 - val_accuracy: 0.6948
# Epoch 214/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0308 - accuracy: 0.9897 - val_loss: 1.7255 - val_accuracy: 0.6993
# Epoch 215/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0211 - accuracy: 0.9920 - val_loss: 1.9132 - val_accuracy: 0.6970
# Epoch 216/250
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0229 - accuracy: 0.9920 - val_loss: 1.7860 - val_accuracy: 0.6788
# Epoch 217/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0211 - accuracy: 0.9920 - val_loss: 1.9058 - val_accuracy: 0.6902
# Epoch 218/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0203 - accuracy: 0.9926 - val_loss: 1.8773 - val_accuracy: 0.7175
# Epoch 219/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 1.8476 - val_accuracy: 0.6811
# Epoch 220/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0160 - accuracy: 0.9932 - val_loss: 1.9782 - val_accuracy: 0.6925
# Epoch 221/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0151 - accuracy: 0.9943 - val_loss: 1.8763 - val_accuracy: 0.7198
# Epoch 222/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 1.9784 - val_accuracy: 0.6902
# Epoch 223/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 1.8095 - val_accuracy: 0.6925
# Epoch 224/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0133 - accuracy: 0.9943 - val_loss: 1.8084 - val_accuracy: 0.7153
# Epoch 225/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 1.8248 - val_accuracy: 0.6948
# Epoch 226/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0140 - accuracy: 0.9966 - val_loss: 1.9218 - val_accuracy: 0.6993
# Epoch 227/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0220 - accuracy: 0.9943 - val_loss: 1.7572 - val_accuracy: 0.7130
# Epoch 228/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0230 - accuracy: 0.9920 - val_loss: 1.7819 - val_accuracy: 0.6993
# Epoch 229/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 1.7407 - val_accuracy: 0.6834
# Epoch 230/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0176 - accuracy: 0.9932 - val_loss: 2.0093 - val_accuracy: 0.6925
# Epoch 231/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0270 - accuracy: 0.9914 - val_loss: 2.0992 - val_accuracy: 0.6674
# Epoch 232/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0304 - accuracy: 0.9897 - val_loss: 1.9185 - val_accuracy: 0.6879
# Epoch 233/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0332 - accuracy: 0.9903 - val_loss: 1.7038 - val_accuracy: 0.6651
# Epoch 234/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0296 - accuracy: 0.9903 - val_loss: 1.7697 - val_accuracy: 0.6970
# Epoch 235/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0179 - accuracy: 0.9932 - val_loss: 1.8094 - val_accuracy: 0.6856
# Epoch 236/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0141 - accuracy: 0.9966 - val_loss: 1.8488 - val_accuracy: 0.7084
# Epoch 237/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0224 - accuracy: 0.9914 - val_loss: 1.7723 - val_accuracy: 0.6993
# Epoch 238/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0168 - accuracy: 0.9932 - val_loss: 1.8155 - val_accuracy: 0.7130
# Epoch 239/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0256 - accuracy: 0.9909 - val_loss: 1.7981 - val_accuracy: 0.6834
# Epoch 240/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0211 - accuracy: 0.9943 - val_loss: 1.9143 - val_accuracy: 0.6856
# Epoch 241/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0093 - accuracy: 0.9960 - val_loss: 1.9060 - val_accuracy: 0.7039
# Epoch 242/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0109 - accuracy: 0.9954 - val_loss: 1.8529 - val_accuracy: 0.7084
# Epoch 243/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0127 - accuracy: 0.9966 - val_loss: 1.9470 - val_accuracy: 0.6902
# Epoch 244/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0136 - accuracy: 0.9943 - val_loss: 2.0476 - val_accuracy: 0.6674
# Epoch 245/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0122 - accuracy: 0.9954 - val_loss: 2.0233 - val_accuracy: 0.6834
# Epoch 246/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0128 - accuracy: 0.9977 - val_loss: 2.0149 - val_accuracy: 0.7016
# Epoch 247/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0201 - accuracy: 0.9943 - val_loss: 2.0733 - val_accuracy: 0.6788
# Epoch 248/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0122 - accuracy: 0.9954 - val_loss: 1.9963 - val_accuracy: 0.6970
# Epoch 249/250
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0142 - accuracy: 0.9966 - val_loss: 1.9356 - val_accuracy: 0.6651
# Epoch 250/250
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0303 - accuracy: 0.9909 - val_loss: 1.9413 - val_accuracy: 0.6925

# %%
o_loss,o_accuracy = model.evaluate(cnn_x_train,cnn_y_train)
print("對訓練資料的：\nLoss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
n_loss,n_accuracy = model.evaluate(cnn_x_test,cnn_y_test)
print("對測試資料的：\nLoss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
# Out:
# 55/55 [==============================] - 0s 3ms/step - loss: 8.1559e-04 - accuracy: 1.0000
# 對訓練資料的：
# Loss: 0.00, Accuracy: 1.00
# 14/14 [==============================] - 0s 3ms/step - loss: 1.9498 - accuracy: 0.6925
# 對測試資料的：
# Loss: 1.95, Accuracy: 0.69

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(np.log(history.history['loss']), color = 'green', label='Loss')
plt.plot(np.log(history.history['val_loss']), color = 'blue', label='Val_Loss')
plt.legend()
plt.title('Training loss based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], color = 'green', label='accuracy')
plt.plot(history.history['val_accuracy'], color = 'blue', label='Val_accuracy')
plt.legend()
plt.title('Accuracy based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()

# %%
pre = model.predict_classes(cnn_x_test)
pre = pd.Series(pre)

# %%
from sklearn.metrics import confusion_matrix

#將onehot編碼轉回數組cnn_x_validation
cnn_y_test = np.argmax(cnn_y_test, axis=1)
xcnn_y_test = pd.Series(cnn_y_test)

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_test, pre)

t_size = len(cnn_y_test)
t_size1 = (cnn_y_test<1).sum()
t_guess = ((cnn_y_test<1).sum())/(len(cnn_y_test))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 180.00, FN: 79.00, FP: 56.00, TN: 124.00
# 對訓練集資料的：Loss: 0.00, Accuracy: 1.00
# 對測試集資料的：Loss: 1.95, Accuracy: 0.69
#
# 測試資料總共：439.00 筆, 其中漲的筆數為: 259.00, 全部猜漲猜對的機率是: 0.59
# 該測試集資料的：
# Accuracy: 0.69, Precision: 0.76, Recall: 0.69
# F1 score: 0.73

# %%
#將onehot編碼轉回數組cnn_x_validation
cnn_y_validation = np.argmax(cnn_y_validation, axis=1)
xcnn_y_validation = pd.Series(cnn_y_validation)

# %%
pre = model.predict_classes(cnn_x_validation)
pre = pd.Series(pre)
pre.hist()

# %%
from sklearn.metrics import confusion_matrix

LABELS = ["Rise","Fall"]
conf_matrix = confusion_matrix(xcnn_y_validation, pre)

t_size = len(cnn_y_validation)
t_size1 = (cnn_y_validation<1).sum()
t_guess = ((cnn_y_validation<1).sum())/(len(cnn_y_validation))

TP = conf_matrix[0][0]
FN = conf_matrix[0][1]
FP = conf_matrix[1][0]
TN = conf_matrix[1][1]
accuracy = (TP+TN)/(TP+FN+FP+TN)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*((precision*recall)/(precision+recall))
print("TP: %.2f, FN: %.2f, FP: %.2f, TN: %.2f" % (TP,FN,FP,TN))
print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n測試資料總共：%.2f 筆, 其中漲的筆數為: %.2f, 全部猜漲猜對的機率是: %.2f" % (t_size, t_size1, t_guess))
print("該測試集資料的：\nAccuracy: %.2f, Precision: %.2f, Recall: %.2f\nF1 score: %.2f" % (accuracy, precision,recall,F1))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# TP: 60.00, FN: 100.00, FP: 34.00, TN: 42.00
# 對訓練集資料的：Loss: 0.00, Accuracy: 1.00
# 對測試集資料的：Loss: 1.95, Accuracy: 0.69
#
# 測試資料總共：236.00 筆, 其中漲的筆數為: 160.00, 全部猜漲猜對的機率是: 0.68
# 該測試集資料的：
# Accuracy: 0.43, Precision: 0.64, Recall: 0.38
# F1 score: 0.47
