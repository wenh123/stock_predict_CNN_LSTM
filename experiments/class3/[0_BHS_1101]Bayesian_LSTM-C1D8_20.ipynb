# %%
import pandas as pd
import numpy as np
import datetime
import tqdm #進度條
import talib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
data = pd.read_csv('data/1019_SP.csv')
data1 = pd.read_csv("data/1019_CL.csv").dropna()
data2 = pd.read_csv("data/1019_OVX.csv").dropna()
data3 = pd.read_csv("data/1019_GC.csv").dropna()
data4 = pd.read_csv("data/1019_GVZ.csv").dropna()
Date = data.get("Date")
Date = pd.to_datetime(Date)
Open = data.get("Open")
High = data.get("High")
Low = data.get("Low")
Close = data.get("Close")
Close_cl = data1.get("Close")
Close_ovx = data2.get("Close")
Close_gc = data3.get("Close")
Close_gvz = data4.get("Close")

dict = {"Date": Date,
        "open": Open,
        "high": High,
        "low": Low, 
        "close": Close,
        "close_cl": Close_cl, 
        "close_ovx": Close_ovx,
        "close_gc": Close_gc, 
        "close_gvz": Close_gvz,
        "return":0,
       }
df = pd.DataFrame(dict)
df.set_index('Date', inplace=True)
df = df.dropna()
print("總共:%d個交易時間點" % (len(Date)))
print("去除空白值後剩下:%d個交易時間點" % (len(df)))
df.tail(10)
# Out:
# 總共:2493個交易時間點
# 去除空白值後剩下:2493個交易時間點
#                    open         high  ...  close_gvz  return
# Date                                  ...
# 2019-12-13  3166.649902  3182.679932  ...      10.39       0
# 2019-12-16  3183.629883  3197.709961  ...      10.39       0
# 2019-12-17  3195.399902  3198.219971  ...      10.03       0
# 2019-12-18  3195.209961  3198.479980  ...      10.04       0
# 2019-12-19  3192.320068  3205.479980  ...      10.39       0
# 2019-12-20  3223.330078  3225.649902  ...       9.69       0
# 2019-12-23  3226.050049  3227.780029  ...      10.56       0
# 2019-12-26  3227.199951  3240.080078  ...      13.33       0
# 2019-12-27  3247.229980  3247.929932  ...      12.32       0
# 2019-12-30  3240.090088  3240.919922  ...      12.56       0
#
# [10 rows x 9 columns]

# %%
def create_labels(df,col_name,window_size=11):
  row_counter = 0
  total_rows = len(df)
  labels = np.zeros(total_rows)
  labels[:]=np.nan
  #pbar = tqdm.tqdm(total=total_rows)
  while row_counter <total_rows:
    if row_counter>=window_size-1:
      window_begin=row_counter-(window_size-1)
      window_end=row_counter
      window_middle=(window_begin+window_end)/2
      min_=np.inf
      min_index=-1
      max_=-np.inf
      max_index=-1
      for i in range(window_begin,window_end+1):
        price = df.iloc[i][col_name]
        if price<min_:
          min_=price
          min_index=i
        elif price>max_:
          max_=price
          max_index=i
      if max_index == window_middle:
        labels[row_counter] = 2
      elif min_index == window_middle:
        labels[row_counter] = 0
      else:
        labels[row_counter] = 1
    row_counter = row_counter+1
    #pbar.update(1)
  #pbar.close()
  return labels
df['return'] = create_labels(df,'close')

# %%
ema = talib.EMA(df['close'])
sma = talib.SMA(df['close'])
roc = talib.ROC(df['close'])
macd, macdsignal, macdhist = talib.MACD(df['close'])
k, d = talib.STOCH (df['high'], df['low'], df['close'])
upper, middle, lower = talib.BBANDS(df['close'])
B = (df['close'] - lower)/(upper - lower)

dataset = pd.DataFrame({
    'Close':df['close'],    
    'EMA':ema,
    'SMA':sma,
    'ROC':roc,
    'MACD':macd,
    '%K':k,
    '%D':d,
    'Upper Band':upper,
    'Lower Band':lower,
    '%B':B,
    'Close_CL':df['close_cl'],
    'Close_OVX':df['close_ovx'],
    'Close_GC':df['close_gc'],
    'Close_GVZ':df['close_gvz'],
    'return': df['return'],
})

feature_names = list(dataset.columns[:-1])

# %%
print("before dropping NaN", dataset.shape)
dataset = dataset.dropna()
print("after dropping NaN", dataset.shape)
# Out:
# before dropping NaN (2493, 15)
# after dropping NaN (2460, 15)

# %%
from sklearn.preprocessing import MinMaxScaler

ss = MinMaxScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
dataset_scaled['return'] = dataset['return']
dataset_scaled.describe()
# Out:
#              Close          EMA  ...    Close_GVZ       return
# count  2460.000000  2460.000000  ...  2460.000000  2460.000000
# mean      0.428129     0.424185  ...     0.258850     1.006504
# std       0.263129     0.278491  ...     0.154939     0.355000
# min       0.000000     0.000000  ...     0.000000     0.000000
# 25%       0.170140     0.147477  ...     0.141213     1.000000
# 50%       0.437414     0.435432  ...     0.243000     1.000000
# 75%       0.638417     0.647352  ...     0.343096     1.000000
# max       1.000000     1.000000  ...     1.000000     2.000000
#
# [8 rows x 15 columns]

# %%
result = pd.value_counts(dataset_scaled['return'])
print(result)
dataset_scaled['return'].hist()
# Out:
# 1.0    2150
# 2.0     163
# 0.0     147
# Name: return, dtype: int64

# %%
from keras.utils import np_utils
#每張圖包含幾天的資料
time_period = 20
#預設幾日後的漲跌
day = 1

cnn_x = []
cnn_y = []
indexs = []
dataset_scaled_x= dataset_scaled[feature_names]

for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-time_period-1-day)):
    cnn_x.append(dataset_scaled_x.iloc[i:i+time_period].values)
    r = dataset_scaled['return'].iloc[i+time_period-1+day]
    rr = np_utils.to_categorical(r, num_classes=3)
    cnn_y.append(rr)
    indexs.append(dataset_scaled.index[i+time_period-1])
    
cnn_x = np.array(cnn_x)
cnn_y = np.array(cnn_y)
indexes = np.array(indexs)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# HBox(children=(IntProgress(value=0, max=2438), HTML(value='')))

# %%
#2010~2018年為訓練和測試，2019年則為驗證
import datetime
cnn_x_t = cnn_x[indexes < datetime.datetime(2019,1,1)]
cnn_y_t = cnn_y[indexes < datetime.datetime(2019,1,1)]
cnn_x_validation = cnn_x[indexes > datetime.datetime(2019,1,1)]
cnn_y_validation = cnn_y[indexes > datetime.datetime(2019,1,1)]

# %%
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
def get_sample_weights(y):
  y = y.astype(int)
  class_weight = compute_class_weight('balanced',np.unique(y),y)
  print("real class weight are{}".format(class_weight),np.unique(y))
  print("value_counts",np.unique(y,return_counts=True))
  sample_weights = y.copy().astype(float)
  for i in np.unique(y):
    sample_weights[sample_weights==i]=class_weight[i]
  return class_weight,sample_weights

# %%
#將onehot編碼轉回數組
lable = np.argmax(cnn_y_t, axis=1)
lable = np.array(lable)
class_weight,sample_weights = get_sample_weights(lable)
# Out:
# real class weight are[5.45522388 0.38272251 4.90604027] [0 1 2]
# value_counts (array([0, 1, 2]), array([ 134, 1910,  149]))

# %%
class_weight={0:class_weight[0],
              1:class_weight[1],
              2:class_weight[2],}
print(class_weight)
# Out:
# {0: 5.455223880597015, 1: 0.38272251308900523, 2: 4.906040268456376}

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential

def get_model(dropout1_rate=0.5, dropout2_rate=0.5):
  
    model = Sequential()
    model.add(layers.Conv1D(100, 10, activation='relu', input_shape=cnn_x_t[0].shape))
    model.add(layers.MaxPooling1D(2))
    model.add(layers.LSTM(128, return_sequences=True))
    model.add(layers.Dropout(dropout1_rate, name="dropout_1"))
    model.add(layers.LSTM(128))
    model.add(layers.Dropout(dropout2_rate, name="dropout_2"))
    model.add(layers.Dense(units=32, activation='relu'))
    model.add(layers.Dense(units=3, activation='softmax'))

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='loss', patience=10, verbose=1)

def fit_with(dropout1_rate, dropout2_rate, lr, batchsize):

    # batchsize只能是整數，強迫把浮點轉int
    batchsize = int(batchsize)

    # 使用指定的超參數創建模型。
    model = get_model(dropout1_rate, dropout2_rate)
    
    # 設定優化器、學習率並建模
    optimizer = tensorflow.keras.optimizers.Adam(lr=lr)
    model.compile(loss='categorical_crossentropy',optimizer=optimizer, metrics=['accuracy'])
    
    # 使用訓練數據集訓練模型。
    model.fit(cnn_x_t, cnn_y_t,
              batch_size = batchsize,
              epochs=250,
              verbose=0,
              validation_split = 0.2,
              callbacks=[earlystop],
              class_weight=class_weight,
              )
    # steps=10 = 評估階段結束之前的步驟總數（樣本批次）
    # score = model.evaluate(cnn_x_test,cnn_y_test, steps=10, verbose=0)
    # 使用測試數據集評估模型。
    score = model.evaluate(cnn_x_t, cnn_y_t, verbose=0)
    #print('Test loss:', score[0])
    #print('Test accuracy:', score[1])

    return score[1]

# %%
from bayes_opt import BayesianOptimization

optimizer = BayesianOptimization(
        fit_with,
        {'dropout1_rate': (0, 0.5),
        'dropout2_rate': (0, 0.5),
        'lr': (1e-5, 1e-2),
        'batchsize': (16,128)}
    )
optimizer.maximize(init_points=10, n_iter=20)
# Out:
# |   iter    |  target   | batchsize | dropou... | dropou... |    lr     |
# -------------------------------------------------------------------------
# Epoch 00014: early stopping
# |  1        |  0.0611   |  63.36    |  0.2584   |  0.01182  |  0.008248 |
# Epoch 00018: early stopping
# |  2        |  0.0611   |  80.32    |  0.2999   |  0.3229   |  0.008521 |
# Epoch 00015: early stopping
# |  3        |  0.0611   |  122.6    |  0.1845   |  0.1446   |  0.00904  |
# Epoch 00020: early stopping
# |  4        |  0.0611   |  20.72    |  0.2889   |  0.2213   |  0.00663  |
# Epoch 00014: early stopping
# |  5        |  0.0611   |  114.3    |  0.07909  |  0.1252   |  0.006545 |
# Epoch 00023: early stopping
# |  6        |  0.0611   |  46.47    |  0.02212  |  0.3244   |  0.004398 |
# Epoch 00037: early stopping
# |  7        |  0.0611   |  30.12    |  0.3819   |  0.2614   |  0.007415 |
# Epoch 00055: early stopping
# |  8        |  0.6443   |  115.0    |  0.1115   |  0.4771   |  0.00465  |
# Epoch 00025: early stopping
# |  9        |  0.0611   |  117.5    |  0.3562   |  0.2324   |  0.00515  |
# Epoch 00013: early stopping
# |  10       |  0.0611   |  51.38    |  0.01903  |  0.2706   |  0.004497 |
# Epoch 00013: early stopping
# |  11       |  0.06794  |  96.46    |  0.432    |  0.3762   |  0.002854 |
# Epoch 00018: early stopping
# |  12       |  0.06794  |  71.86    |  0.4792   |  0.4899   |  0.006439 |
# Epoch 00019: early stopping
# |  13       |  0.06794  |  38.33    |  0.4657   |  0.08973  |  0.006572 |
# Epoch 00047: early stopping
# |  14       |  0.871    |  88.47    |  0.01359  |  0.2035   |  0.008593 |
# Epoch 00026: early stopping
# |  15       |  0.0611   |  86.36    |  0.3635   |  0.06168  |  0.004438 |
# Epoch 00016: early stopping
# |  16       |  0.06794  |  90.59    |  0.1164   |  0.2933   |  0.009136 |
# Epoch 00115: early stopping
# |  17       |  0.8021   |  104.6    |  0.4753   |  0.4685   |  0.002171 |
# Epoch 00018: early stopping
# |  18       |  0.2435   |  106.7    |  0.0      |  0.0      |  1e-05    |
# Epoch 00024: early stopping
# |  19       |  0.1674   |  102.2    |  0.0      |  0.0      |  1e-05    |
# Epoch 00023: early stopping
# |  20       |  0.0611   |  128.0    |  0.5      |  0.0      |  1e-05    |
# Epoch 00015: early stopping
# |  21       |  0.0611   |  57.3     |  0.4734   |  0.4761   |  0.004004 |
# Epoch 00020: early stopping
# |  22       |  0.871    |  16.0     |  0.05397  |  0.2682   |  0.007682 |
# Epoch 00020: early stopping
# |  23       |  0.07114  |  25.45    |  0.0      |  0.5      |  1e-05    |
# Epoch 00016: early stopping
# |  24       |  0.06794  |  67.7     |  0.001514 |  0.07802  |  0.007608 |
# Epoch 00012: early stopping
# |  25       |  0.07068  |  76.07    |  0.5      |  0.0      |  1e-05    |
# Epoch 00013: early stopping
# |  26       |  0.0611   |  34.25    |  0.02798  |  0.2393   |  0.004563 |
# Epoch 00018: early stopping
# |  27       |  0.0611   |  42.36    |  0.0      |  0.5      |  0.01     |
# Epoch 00025: early stopping
# |  28       |  0.0611   |  17.91    |  0.4864   |  0.1464   |  0.003417 |
# Epoch 00014: early stopping
# |  29       |  0.7857   |  110.0    |  0.5      |  0.5      |  1e-05    |
# Epoch 00070: early stopping
# |  30       |  0.2047   |  60.29    |  0.0      |  0.0      |  1e-05    |
# =========================================================================

# %%
print(optimizer.max)
print(optimizer.max['params']['dropout1_rate'])
print(optimizer.max['params']['dropout2_rate'])
print(optimizer.max['params']['lr'])
print(optimizer.max['params']['batchsize'])
##Bayesian Optimization 找到的最佳超參數值
dropout_rate1 = optimizer.max['params']['dropout1_rate']
dropout_rate2 = optimizer.max['params']['dropout2_rate']
learning_rate = optimizer.max['params']['lr']
batchsize = int(optimizer.max['params']['batchsize'])
# Out:
# {'target': 0.8709530234336853, 'params': {'batchsize': 88.46720839005762, 'dropout1_rate': 0.013593513591900419, 'dropout2_rate': 0.2034667691330277, 'lr': 0.008593036447150655}}
# 0.013593513591900419
# 0.2034667691330277
# 0.008593036447150655
# 88.46720839005762

# %%
dropout_rate1 = 0.01359
dropout_rate2 = 0.2035
learning_rate =  0.008593
batchsize = int(88.47)

# %%
import tensorflow.keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.initializers import he_normal

model = Sequential()
model.add(layers.Conv1D(100, 10, activation='relu', input_shape=cnn_x_t[0].shape))
model.add(layers.MaxPooling1D(2))
model.add(layers.LSTM(128, return_sequences=True, input_shape=cnn_x[0].shape))
model.add(layers.Dropout(dropout_rate1, name="dropout_1"))
model.add(layers.LSTM(128))
model.add(layers.Dropout(dropout_rate2, name="dropout_2"))
model.add(layers.Dense(units=32, activation='relu'))
model.add(layers.Dense(units=3, activation='softmax'))

adam = tensorflow.keras.optimizers.Adam(learning_rate)

model.compile(loss='categorical_crossentropy',optimizer=adam, metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_34 (Conv1D)           (None, 11, 100)           14100
# _________________________________________________________________
# max_pooling1d_34 (MaxPooling (None, 5, 100)            0
# _________________________________________________________________
# lstm_68 (LSTM)               (None, 5, 128)            117248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_69 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_68 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dense_69 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 267,159
# Trainable params: 267,159
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping 
earlystop = EarlyStopping(monitor='loss', patience=10, verbose=1)

history = model.fit(cnn_x_t, cnn_y_t,
                    batch_size=batchsize,
                    epochs=250,
                    verbose=1,
                    validation_split = 0.2,
                    #callbacks=[earlystop],
                    class_weight=class_weight,
                    )
# Out:
# Epoch 1/250
# 20/20 [==============================] - 1s 38ms/step - loss: 1.1470 - accuracy: 0.3216 - val_loss: 1.0207 - val_accuracy: 0.8793
# Epoch 2/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1224 - accuracy: 0.2691 - val_loss: 1.0963 - val_accuracy: 0.0661
# Epoch 3/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1134 - accuracy: 0.7811 - val_loss: 1.0968 - val_accuracy: 0.8793
# Epoch 4/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1107 - accuracy: 0.0992 - val_loss: 1.1130 - val_accuracy: 0.0547
# Epoch 5/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1106 - accuracy: 0.0627 - val_loss: 1.1066 - val_accuracy: 0.0547
# Epoch 6/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1102 - accuracy: 0.0627 - val_loss: 1.1153 - val_accuracy: 0.0547
# Epoch 7/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1109 - accuracy: 0.0627 - val_loss: 1.1140 - val_accuracy: 0.0547
# Epoch 8/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1096 - accuracy: 0.0627 - val_loss: 1.1102 - val_accuracy: 0.0547
# Epoch 9/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1112 - accuracy: 0.0627 - val_loss: 1.1036 - val_accuracy: 0.0547
# Epoch 10/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1095 - accuracy: 0.0627 - val_loss: 1.1157 - val_accuracy: 0.0547
# Epoch 11/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1093 - accuracy: 0.0627 - val_loss: 1.1149 - val_accuracy: 0.0547
# Epoch 12/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1117 - accuracy: 0.1334 - val_loss: 1.0955 - val_accuracy: 0.8793
# Epoch 13/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1122 - accuracy: 0.2218 - val_loss: 1.1127 - val_accuracy: 0.0547
# Epoch 14/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1102 - accuracy: 0.0587 - val_loss: 1.1052 - val_accuracy: 0.0547
# Epoch 15/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1091 - accuracy: 0.0627 - val_loss: 1.1168 - val_accuracy: 0.0547
# Epoch 16/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1097 - accuracy: 0.0599 - val_loss: 1.1050 - val_accuracy: 0.0661
# Epoch 17/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1103 - accuracy: 0.0604 - val_loss: 1.1148 - val_accuracy: 0.0547
# Epoch 18/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1104 - accuracy: 0.2121 - val_loss: 1.1036 - val_accuracy: 0.0547
# Epoch 19/250
# 20/20 [==============================] - 0s 8ms/step - loss: 1.1109 - accuracy: 0.5735 - val_loss: 1.0996 - val_accuracy: 0.0547
# Epoch 20/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1110 - accuracy: 0.0627 - val_loss: 1.1249 - val_accuracy: 0.0547
# Epoch 21/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1120 - accuracy: 0.0627 - val_loss: 1.1072 - val_accuracy: 0.0547
# Epoch 22/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1100 - accuracy: 0.0633 - val_loss: 1.1095 - val_accuracy: 0.0547
# Epoch 23/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1109 - accuracy: 0.0627 - val_loss: 1.1104 - val_accuracy: 0.0547
# Epoch 24/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1109 - accuracy: 0.0627 - val_loss: 1.1113 - val_accuracy: 0.0547
# Epoch 25/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1104 - accuracy: 0.0627 - val_loss: 1.1070 - val_accuracy: 0.0547
# Epoch 26/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1111 - accuracy: 0.0633 - val_loss: 1.1098 - val_accuracy: 0.0547
# Epoch 27/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1108 - accuracy: 0.0616 - val_loss: 1.1101 - val_accuracy: 0.0547
# Epoch 28/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1106 - accuracy: 0.0593 - val_loss: 1.1165 - val_accuracy: 0.0547
# Epoch 29/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1106 - accuracy: 0.0627 - val_loss: 1.1085 - val_accuracy: 0.0547
# Epoch 30/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1100 - accuracy: 0.0627 - val_loss: 1.1072 - val_accuracy: 0.0547
# Epoch 31/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1107 - accuracy: 0.0621 - val_loss: 1.1088 - val_accuracy: 0.0661
# Epoch 32/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1124 - accuracy: 0.0610 - val_loss: 1.0994 - val_accuracy: 0.0547
# Epoch 33/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1112 - accuracy: 0.0587 - val_loss: 1.1139 - val_accuracy: 0.0547
# Epoch 34/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1103 - accuracy: 0.0627 - val_loss: 1.1200 - val_accuracy: 0.0547
# Epoch 35/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1107 - accuracy: 0.0599 - val_loss: 1.1059 - val_accuracy: 0.0547
# Epoch 36/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1117 - accuracy: 0.0627 - val_loss: 1.1117 - val_accuracy: 0.0547
# Epoch 37/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1097 - accuracy: 0.0627 - val_loss: 1.1068 - val_accuracy: 0.0547
# Epoch 38/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1100 - accuracy: 0.0582 - val_loss: 1.1076 - val_accuracy: 0.0547
# Epoch 39/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1090 - accuracy: 0.0627 - val_loss: 1.1197 - val_accuracy: 0.0547
# Epoch 40/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1103 - accuracy: 0.0627 - val_loss: 1.1017 - val_accuracy: 0.0547
# Epoch 41/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1113 - accuracy: 0.1357 - val_loss: 1.1005 - val_accuracy: 0.0547
# Epoch 42/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1126 - accuracy: 0.0627 - val_loss: 1.1035 - val_accuracy: 0.0547
# Epoch 43/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1111 - accuracy: 0.0627 - val_loss: 1.1172 - val_accuracy: 0.0547
# Epoch 44/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1097 - accuracy: 0.0627 - val_loss: 1.1247 - val_accuracy: 0.0547
# Epoch 45/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1107 - accuracy: 0.0627 - val_loss: 1.1078 - val_accuracy: 0.0547
# Epoch 46/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1099 - accuracy: 0.0627 - val_loss: 1.1074 - val_accuracy: 0.0547
# Epoch 47/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1092 - accuracy: 0.0627 - val_loss: 1.1152 - val_accuracy: 0.0547
# Epoch 48/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1104 - accuracy: 0.0627 - val_loss: 1.1075 - val_accuracy: 0.0547
# Epoch 49/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1118 - accuracy: 0.3330 - val_loss: 1.0892 - val_accuracy: 0.8793
# Epoch 50/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1101 - accuracy: 0.1842 - val_loss: 1.1054 - val_accuracy: 0.0547
# Epoch 51/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1108 - accuracy: 0.0627 - val_loss: 1.1189 - val_accuracy: 0.0547
# Epoch 52/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1108 - accuracy: 0.0570 - val_loss: 1.1139 - val_accuracy: 0.0661
# Epoch 53/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1108 - accuracy: 0.1083 - val_loss: 1.1151 - val_accuracy: 0.0547
# Epoch 54/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1115 - accuracy: 0.2469 - val_loss: 1.1148 - val_accuracy: 0.0547
# Epoch 55/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1106 - accuracy: 0.0582 - val_loss: 1.1120 - val_accuracy: 0.0547
# Epoch 56/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1103 - accuracy: 0.0553 - val_loss: 1.1107 - val_accuracy: 0.0661
# Epoch 57/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1112 - accuracy: 0.0610 - val_loss: 1.1140 - val_accuracy: 0.0547
# Epoch 58/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1114 - accuracy: 0.0627 - val_loss: 1.1082 - val_accuracy: 0.0547
# Epoch 59/250
# 20/20 [==============================] - 0s 8ms/step - loss: 1.1107 - accuracy: 0.0627 - val_loss: 1.1088 - val_accuracy: 0.0547
# Epoch 60/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1120 - accuracy: 0.1944 - val_loss: 1.0555 - val_accuracy: 0.8793
# Epoch 61/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1315 - accuracy: 0.1368 - val_loss: 1.1247 - val_accuracy: 0.0547
# Epoch 62/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1099 - accuracy: 0.0627 - val_loss: 1.1024 - val_accuracy: 0.0547
# Epoch 63/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1106 - accuracy: 0.0627 - val_loss: 1.1087 - val_accuracy: 0.0547
# Epoch 64/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1105 - accuracy: 0.0627 - val_loss: 1.1090 - val_accuracy: 0.0547
# Epoch 65/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1104 - accuracy: 0.0627 - val_loss: 1.1064 - val_accuracy: 0.0547
# Epoch 66/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1103 - accuracy: 0.0604 - val_loss: 1.1091 - val_accuracy: 0.0547
# Epoch 67/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1096 - accuracy: 0.0627 - val_loss: 1.1165 - val_accuracy: 0.0547
# Epoch 68/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1111 - accuracy: 0.2976 - val_loss: 1.0977 - val_accuracy: 0.0547
# Epoch 69/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1108 - accuracy: 0.0593 - val_loss: 1.1079 - val_accuracy: 0.0661
# Epoch 70/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1113 - accuracy: 0.0553 - val_loss: 1.1092 - val_accuracy: 0.0547
# Epoch 71/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1111 - accuracy: 0.0627 - val_loss: 1.1054 - val_accuracy: 0.0547
# Epoch 72/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1094 - accuracy: 0.0627 - val_loss: 1.1071 - val_accuracy: 0.0547
# Epoch 73/250
# 20/20 [==============================] - 0s 8ms/step - loss: 1.1102 - accuracy: 0.0627 - val_loss: 1.1224 - val_accuracy: 0.0547
# Epoch 74/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1099 - accuracy: 0.0627 - val_loss: 1.1116 - val_accuracy: 0.0547
# Epoch 75/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1092 - accuracy: 0.0627 - val_loss: 1.1182 - val_accuracy: 0.0547
# Epoch 76/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1097 - accuracy: 0.0627 - val_loss: 1.1173 - val_accuracy: 0.0547
# Epoch 77/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1098 - accuracy: 0.0627 - val_loss: 1.1072 - val_accuracy: 0.0547
# Epoch 78/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1111 - accuracy: 0.0627 - val_loss: 1.0929 - val_accuracy: 0.0547
# Epoch 79/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1106 - accuracy: 0.0627 - val_loss: 1.1146 - val_accuracy: 0.0547
# Epoch 80/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1102 - accuracy: 0.0627 - val_loss: 1.1021 - val_accuracy: 0.0547
# Epoch 81/250
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1109 - accuracy: 0.0639 - val_loss: 1.1106 - val_accuracy: 0.0661
# Epoch 82/250
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1110 - accuracy: 0.0684 - val_loss: 1.1141 - val_accuracy: 0.0661
# Epoch 83/250
#  1/20 [>.............................] - ETA: 0s - loss: 1.3051 - accuracy: 0.1023

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], color = 'green', label='Loss')
plt.plot(history.history['val_loss'], color = 'blue', label='Val_Loss')
plt.legend()
plt.title('Training loss based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()
plt.style.use("ggplot")
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], color = 'green', label='accuracy')
plt.plot(history.history['val_accuracy'], color = 'blue', label='val_accuracy')
plt.legend()
plt.title('Training accuracy based on CNN')
plt.ylabel('Value')
plt.xlabel('Number of epochs')
plt.show()

# %%
#將onehot編碼轉回數組cnn_x_validation
cnn_y_validation = np.argmax(cnn_y_validation, axis=1)
xcnn_y_validation = pd.Series(cnn_y_validation)
#預測
pre = model.predict_classes(cnn_x_validation)
pre = pd.Series(pre)
pre.hist()
# Out:
# WARNING:tensorflow:From <ipython-input-61-0188eda651c6>:4: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
from sklearn.metrics import confusion_matrix

LABELS = ["Buy","Hold","Sell"]
conf_matrix = confusion_matrix(xcnn_y_validation, pre)

#原始資料
t_size = len(cnn_y_validation)
b_size = (cnn_y_validation>=2).sum()
s_size = (cnn_y_validation<=0).sum()
h_size = t_size-(b_size+s_size)
b_guess = b_size/t_size
s_guess = s_size/t_size
h_guess = h_size/t_size
#矩陣數字
c00 = conf_matrix[0][0]
c01 = conf_matrix[0][1]
c02 = conf_matrix[0][2]
c10 = conf_matrix[1][0]
c11 = conf_matrix[1][1]
c12 = conf_matrix[1][2]
c20 = conf_matrix[2][0]
c21 = conf_matrix[2][1]
c22 = conf_matrix[2][2]
#評估指標
accuracy = (c00+c11+c22)/t_size
precision_b = c00/(c00+c10+c20)
precision_h = c11/(c01+c11+c21)
precision_s = c22/(c02+c12+c22)
recall_b = c00/(c00+c01+c02)
recall_h = c11/(c10+c11+c12)
recall_s = c22/(c20+c21+c22)
F1_b = 2*((precision_b*recall_b)/(precision_b+recall_b))
F1_h = 2*((precision_h*recall_h)/(precision_h+recall_h))
F1_s = 2*((precision_s*recall_s)/(precision_s+recall_s))
#印出
#print("對訓練集資料的：Loss: %.2f, Accuracy: %.2f" % (o_loss, o_accuracy))
#print("對測試集資料的：Loss: %.2f, Accuracy: %.2f" % (n_loss, n_accuracy))
print("\n驗證資料總共：%.2f 筆\n其中 Buy 的筆數為: %.2f, 全部猜 Buy 猜對的機率是: %.2f" % (t_size, b_size, b_guess))
print("其中 Hold 的筆數為: %.2f, 全部猜 Hold 猜對的機率是: %.2f" % (h_size, h_guess))
print("其中 Sell 的筆數為: %.2f, 全部猜 Sell 猜對的機率是: %.2f" % (s_size, s_guess))
print("\n該測試集資料的 Accuracy 為: %.2f \nPrecision(Buy): %.2f, Recall(Buy): %.2f, F1 score(Buy): %.2f" % (accuracy, precision_b, recall_b, F1_b))
print("Precision(Hold): %.2f, Recall(Hold): %.2f, F1 score(Hold): %.2f" % (precision_h, recall_h, F1_h))
print("Precision(Sell): %.2f, Recall(Sell): %.2f, F1 score(Sell): %.2f" % (precision_s, recall_s, F1_s))
#畫圖
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",center=0.7,cmap = 'GnBu');
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# 驗證資料總共：245.00 筆
# 其中 Buy 的筆數為: 13.00, 全部猜 Buy 猜對的機率是: 0.05
# 其中 Hold 的筆數為: 220.00, 全部猜 Hold 猜對的機率是: 0.90
# 其中 Sell 的筆數為: 12.00, 全部猜 Sell 猜對的機率是: 0.05
#
# 該測試集資料的 Accuracy 為: 0.05
# Precision(Buy): nan, Recall(Buy): 0.00, F1 score(Buy): nan
# Precision(Hold): nan, Recall(Hold): 0.00, F1 score(Hold): nan
# Precision(Sell): 0.05, Recall(Sell): 1.00, F1 score(Sell): 0.10
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in long_scalars

# %%
result = pd.value_counts(xcnn_y_validation)
print(result)
# Out:
# 1    220
# 2     13
# 0     12
# dtype: int64

# %%
f = df['close'][2248:]
a = []
b = []
for i in range(len(f)):
  a.append(f[i])
  b.append(pre[i])
  #b.append(xcnn_y_validation[i])
a = np.array(a)
b = np.array(b)

S_dataset = pd.DataFrame({
    'price':a,    
    'signal':b,
})

# %%
#起始資金10000美金，每次交易手續費9美金(以eToro為例)，stock是現在持有的股票數，previous上一部的狀態一樣則不動作。
total_money = 10000
Handling_fee = 9
stock = 0
previous = 1
for i in range(len(S_dataset)):
  total_money = total_money
  stock = stock
  previous = previous
  now = S_dataset['signal'][i]
  if now == previous:
    previous = now
  else:
    if now == 2:
      if stock!=0:
        total_money = total_money+(S_dataset['price'][i]*stock)
        total_money = total_money-Handling_fee
        stock=0
    elif now == 0:
      if total_money>S_dataset['price'][i]:
        stock = int(total_money/S_dataset['price'][i])
        total_money = total_money-(stock*S_dataset['price'][i])
    previous = now

# %%
total = total_money+(S_dataset['price'][len(S_dataset)-1]*stock)-Handling_fee

# %%
#Return on investment (%)
print(((total-10000)/10000)*100)
# Out:
# -0.09
